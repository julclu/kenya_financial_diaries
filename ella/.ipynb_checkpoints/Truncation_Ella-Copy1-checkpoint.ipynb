# %%
import pandas as pd
import numpy as np
import math as math
import matplotlib.pyplot as plt
import seaborn as sns
import random
# %matplotlib inline

# %%
# to see all the columns when using head() or describe()
pd.set_option('display.max_columns',60)

# %%
df = pd.read_csv("kenya_data/diaries_transactions_all.csv", dtype={'account_startclose_balance': str})
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-54b9999aa904> in <module>()
# ----> 1 df = pd.read_csv("kenya_data/diaries_transactions_all.csv", dtype={'account_startclose_balance': str})
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     707                     skip_blank_lines=skip_blank_lines)
#     708
# --> 709         return _read(filepath_or_buffer, kwds)
#     710
#     711     parser_f.__name__ = name
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     447
#     448     # Create the parser.
# --> 449     parser = TextFileReader(filepath_or_buffer, **kwds)
#     450
#     451     if chunksize or iterator:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     816             self.options['has_index_names'] = kwds['has_index_names']
#     817
# --> 818         self._make_engine(self.engine)
#     819
#     820     def close(self):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1047     def _make_engine(self, engine='c'):
#    1048         if engine == 'c':
# -> 1049             self._engine = CParserWrapper(self.f, **self.options)
#    1050         else:
#    1051             if engine == 'python':
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1693         kwds['allow_leading_cols'] = self.index_col is not False
#    1694
# -> 1695         self._reader = parsers.TextReader(src, **kwds)
#    1696
#    1697         # XXX
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'kenya_data/diaries_transactions_all.csv' does not exist

# %%
dfb = df[(df["trx_family_code"]=="FRMLN")&((df["trx_type_code"]==2760)|(df["trx_type_code"]==3247))]

# %% [markdown]
# # Get rid of loans of with unexplained balance adjustments

# %%
dfb["trx_prx_purpose"].unique()

# %% [markdown]
# We insert a new column that is 0 if there is no unexplained balance adjustment for this account and a 1 if there is one. The column in 1 or 0 for all entries that correspond to that account.

# %%
dfb.insert(dfb.shape[1], "acc_unexplained_trx", np.zeros(dfb.shape[0]))

# %% [markdown]
# This program goes through all unique accounts, checks whether it has an unexplained balance adjustment and if yes sets the variable u to 1. Then it goes through another for-loop and sets the entries of that column 0 for all accounts that have an unexplained balance adjustment.

# %%
for acc in dfb["account_ids"].unique():
    u = 0
    for index,row in dfb[dfb["account_ids"]==acc].iterrows():
        if row["trx_prx_purpose"]=="DECREASE--Unexplained balance adjustment" or row["trx_prx_purpose"]=="INCREASE--Unexplained balance adjustment":
            u = 1
    for index,row in dfb[dfb["account_ids"]==acc].iterrows():
        dfb.at[index,"acc_unexplained_trx"] = u

# %% [markdown]
# ### Let us check if it worked.

# %%
s = set()
for acc in dfb[dfb["acc_unexplained_trx"]==0]["account_ids"].unique():
     for i in dfb[dfb["account_ids"]==acc]["trx_prx_purpose"].unique():
            s.add(i)
print(s)
# Out:
# {'4. Any known fees', '2. New borrowing', '3. Payments', '5. Interest accruing', '7. Refund from lender', '6. Closing Balance--End of last DQ', '1. Starting balance (today)', '2. New borrowinng (individual portion)'}

# %% [markdown]
# ### Let's now only use the loans that have no unexplained balance adjustments.

# %%
dfb = dfb[dfb["acc_unexplained_trx"]==0]

# %% [markdown]
# # Truncation into chunks with no new borrowing

# %% [markdown]
# We first insert a column for the new account numbers. These will be like the old account numbers but with a .1 or .2 for each sequence after a new borrowing.

# %%
del dfb["new_account_ids"]

# %%
dfb.insert(df.columns.get_loc("account_ids")+1,"new_account_ids", ["-"]*(dfb.shape[0]))

# %%
dfb.sample(1)
# Out:
#          hh_ids  unique_hhs first_trx_date_hh last_trx_date_hh  \
# 398120  KVIHK40         NaN         10sep2012        03oct2013
#
#         tot_hh_daysofobs  tot_hh_monthsofobs interview_designation   int_date  \
# 398120               388                  13  04=Diaries Interview  19mar2013
#
#         int_month  int_year int_yr_mo first_int_date        account_ids  \
# 398120          3      2013   2013_03      04sep2012  60134978362300000
#
#        new_account_ids  unique_accnts        m_ids_owner  unique_hm_owner  \
# 398120               -            NaN  60134547419200000              NaN
#
#        account_bsheet_desig account_startclose_balance account_formal  \
# 398120            Liability                        NaN         Formal
#
#        account_liquid first_trx_date_acc last_trx_date_acc  tot_acc_daysofobs  \
# 398120            NaN          02oct2012         03oct2013                366
#
#         tot_acc_monthsofobs             trx_id          m_ids_trx   trx_date  \
# 398120                   12  60136369687100000  60134547419200000  08mar2013
#
#         trx_month  trx_year trx_yr_mo  trx_dq_round  trx_stdtime_days_hh  \
# 398120          3      2013   2013_03           9.0                  179
#
#         trx_stdtime_mnths_hh  trx_stdtime_days_acc  trx_stdtime_mnths_acc  \
# 398120                     6                   157                      5
#
#        trx_class_code                                     trx_class_desc  \
# 398120         findev  Borrowing, lending, savings or insurance media...
#
#        trx_family_code trx_family_desc  trx_type_code  \
# 398120           FRMLN     Formal loan           2760
#
#                                   trx_type_desc trx_prx_purpose  \
# 398120  Individual Business or Agriculture Loan     3. Payments
#
#                       trx_prx_purpose_fd  trx_fee trx_bsheet_direction  \
# 398120  Repayment on financial liability      0.0             Decrease
#
#         trx_mode_code trx_mode_desc  trx_place_incommunity  trx_distance_km  \
# 398120            1.0          Cash                    1.0              0.0
#
#               trx_outlet trx_direction  trx_value_kes  trx_value_usd  \
# 398120  07=Group meeting       Outflow         5500.0       64.70588
#
#         ddd_gift trx_inkind_units  trx_inkind_value_usd  trx_inkind_value_kes  \
# 398120         0              NaN                   NaN                   NaN
#
#         trx_stdtime_mnths_hh_nr  acc_unexplained_trx
# 398120                 6.172414                  0.0

# %%
acc = random.choice(dfb[dfb["trx_prx_purpose"]=="2. New borrowing"]["account_ids"].unique())

# %%
print(acc)
# Out:
# 59134942469700000

# %% [markdown]
# acc = 59135900709000000

# %%
lna = dfb[dfb["account_ids"]==acc]

# %%
lna = lna.sort_values("trx_stdtime_days_acc")

# %%
lna
# Out:
#          hh_ids  unique_hhs first_trx_date_hh last_trx_date_hh  \
# 23025   KVIHC35         NaN         05aug2012        22sep2013
# 277437  KVIHC35         NaN         05aug2012        22sep2013
# 149656  KVIHC35         NaN         05aug2012        22sep2013
# 19200   KVIHC35         NaN         05aug2012        22sep2013
# 427271  KVIHC35         NaN         05aug2012        22sep2013
# 260728  KVIHC35         NaN         05aug2012        22sep2013
# 288513  KVIHC35         NaN         05aug2012        22sep2013
# 288508  KVIHC35         NaN         05aug2012        22sep2013
# 248010  KVIHC35         NaN         05aug2012        22sep2013
# 208412  KVIHC35         NaN         05aug2012        22sep2013
# 105122  KVIHC35         NaN         05aug2012        22sep2013
# 426300  KVIHC35         NaN         05aug2012        22sep2013
# 242426  KVIHC35         NaN         05aug2012        22sep2013
# 426114  KVIHC35         NaN         05aug2012        22sep2013
# 314426  KVIHC35         NaN         05aug2012        22sep2013
# 21202   KVIHC35         NaN         05aug2012        22sep2013
#
#         tot_hh_daysofobs  tot_hh_monthsofobs  interview_designation  \
# 23025                413                  14   04=Diaries Interview
# 277437               413                  14   04=Diaries Interview
# 149656               413                  14   04=Diaries Interview
# 19200                413                  14  06=Cleaning interview
# 427271               413                  14  06=Cleaning interview
# 260728               413                  14   04=Diaries Interview
# 288513               413                  14   04=Diaries Interview
# 288508               413                  14   04=Diaries Interview
# 248010               413                  14   04=Diaries Interview
# 427271                     4                    67                      2
# 260728                     4                    72                      2
# 288513                     5                   100                      3
# 288508                     6                   135                      4
# 248010                     7                   163                      5
# 208412                     8                   191                      6
# 105122                     9                   219                      7
# 426300                    11                   254                      8
# 242426                    11                   282                      9
# 426114                    13                   313                     10
# 314426                    14                   345                     11
# 21202                     14                   346                     11
#
#        trx_class_code                                     trx_class_desc  \
# 23025          findev  Borrowing, lending, savings or insurance media...
# 277437         findev  Borrowing, lending, savings or insurance media...
# 149656         findev  Borrowing, lending, savings or insurance media...
# 19200          findev  Borrowing, lending, savings or insurance media...
# 427271         findev  Borrowing, lending, savings or insurance media...
# 260728         findev  Borrowing, lending, savings or insurance media...
# 288513         findev  Borrowing, lending, savings or insurance media...
# 288508         findev  Borrowing, lending, savings or insurance media...
# 248010         findev  Borrowing, lending, savings or insurance media...
# 208412         findev  Borrowing, lending, savings or insurance media...
# 105122         findev  Borrowing, lending, savings or insurance media...
# 426300         findev  Borrowing, lending, savings or insurance media...
# 242426         findev  Borrowing, lending, savings or insurance media...
# 426114         findev  Borrowing, lending, savings or insurance media...
# 314426         findev  Borrowing, lending, savings or insurance media...
# 21202          findev  Borrowing, lending, savings or insurance media...
#
#        trx_family_code trx_family_desc  trx_type_code  \
# 23025            FRMLN     Formal loan           2760
# 277437           FRMLN     Formal loan           2760
# 149656           FRMLN     Formal loan           2760
# 19200            FRMLN     Formal loan           2760
# 427271           FRMLN     Formal loan           2760
# 260728           FRMLN     Formal loan           2760
# 288513           FRMLN     Formal loan           2760
# 288508           FRMLN     Formal loan           2760
# 248010           FRMLN     Formal loan           2760
# 208412           FRMLN     Formal loan           2760
# 105122           FRMLN     Formal loan           2760
# 426300           FRMLN     Formal loan           2760
# 242426           FRMLN     Formal loan           2760
# 426114           FRMLN     Formal loan           2760
# 314426           FRMLN     Formal loan           2760
# 21202            FRMLN     Formal loan           2760
#
#                                   trx_type_desc  \
# 23025   Individual Business or Agriculture Loan
# 277437  Individual Business or Agriculture Loan
# 149656  Individual Business or Agriculture Loan
# 19200   Individual Business or Agriculture Loan
# 427271  Individual Business or Agriculture Loan
# 260728  Individual Business or Agriculture Loan
# 288513  Individual Business or Agriculture Loan
# 288508  Individual Business or Agriculture Loan
# 248010  Individual Business or Agriculture Loan
# 208412  Individual Business or Agriculture Loan
# 105122  Individual Business or Agriculture Loan
# 426300  Individual Business or Agriculture Loan
# 242426  Individual Business or Agriculture Loan
# 426114  Individual Business or Agriculture Loan
# 314426  Individual Business or Agriculture Loan
# 21202   Individual Business or Agriculture Loan
#
#                            trx_prx_purpose  \
# 23025          1. Starting balance (today)
# 277437                         3. Payments
# 149656                         3. Payments
# 19200                 5. Interest accruing
# 427271                    2. New borrowing
# 260728                         3. Payments
# 288513                         3. Payments
# 288508                         3. Payments
# 248010                         3. Payments
# 208412                         3. Payments
# 105122                         3. Payments
# 426300                         3. Payments
# 242426                         3. Payments
# 426114                         3. Payments
# 314426                         3. Payments
# 21202   6. Closing Balance--End of last DQ
#
#                           trx_prx_purpose_fd  trx_fee trx_bsheet_direction  \
# 23025                                    NaN      0.0             Increase
# 277437      Repayment on financial liability      0.0             Decrease
# 149656      Repayment on financial liability      0.0             Decrease
# 19200                                    NaN      0.0             Increase
# 427271  New borrowing on financial liability      0.0             Increase
# 260728      Repayment on financial liability      0.0             Decrease
# 288513      Repayment on financial liability      0.0             Decrease
# 288508      Repayment on financial liability      0.0             Decrease
# 248010      Repayment on financial liability      0.0             Decrease
# 208412      Repayment on financial liability      0.0             Decrease
# 105122      Repayment on financial liability      0.0             Decrease
# 426300      Repayment on financial liability      0.0             Decrease
# 242426      Repayment on financial liability      0.0             Decrease
# 426114      Repayment on financial liability      0.0             Decrease
# 314426      Repayment on financial liability      0.0             Decrease
# 21202                                    NaN      0.0                  NaN
#
#         trx_mode_code                              trx_mode_desc  \
# 23025            18.0                           STARTING BALANCE
# 277437            1.0                                       Cash
# 149656            1.0                                       Cash
# 19200            16.0                                  Automatic
# 427271            3.0  Transfer into bank, SACCO, or MFI account
# 260728            1.0                                       Cash
# 288513            1.0                                       Cash
# 288508            1.0                                       Cash
# 248010            1.0                                       Cash
# 208412            1.0                                       Cash
# 105122            1.0                                       Cash
# 426300            1.0                                       Cash
# 242426            1.0                                       Cash
# 426114            1.0                                       Cash
# 314426            1.0                                       Cash
# 21202            19.0                            CLOSING BALANCE
#
#         trx_place_incommunity  trx_distance_km  \
# 23025                     NaN              NaN
# 277437                    1.0         0.000000
# 149656                    1.0         0.000000
# 19200                     NaN              NaN
# 427271                    0.0         2.189854
# 260728                    1.0         0.000000
# 288513                    1.0         0.000000
# 288508                    1.0         0.000000
# 248010                    1.0         0.000000
# 208412                    1.0         0.000000
# 105122                    1.0         0.000000
# 426300                    0.0         2.189854
# 242426                    1.0         0.000000
# 426114                    0.0         2.189854
# 314426                    1.0         0.000000
# 21202                     NaN              NaN
#
#                                                trx_outlet trx_direction  \
# 23025                                                 NaN           NaN
# 277437                                   07=Group meeting       Outflow
# 149656                                   07=Group meeting       Outflow
# 19200                                                 NaN           NaN
# 427271  06=Direct deposit, payroll deduction, or stand...        Inflow
# 260728                                   07=Group meeting       Outflow
# 288513                                   07=Group meeting       Outflow
# 288508                                   07=Group meeting       Outflow
# 248010                                   07=Group meeting       Outflow
# 208412                                   07=Group meeting       Outflow
# 105122                                   07=Group meeting       Outflow
# 426300              01=Bank, MFI, SACCO, insurance branch       Outflow
# 242426                                   07=Group meeting       Outflow
# 426114              01=Bank, MFI, SACCO, insurance branch       Outflow
# 314426                                   07=Group meeting       Outflow
# 21202                                                 NaN           NaN
#
#         trx_value_kes  trx_value_usd  ddd_gift trx_inkind_units  \
# 23025        108000.0     1270.58800         0              NaN
# 277437        12000.0      141.17650         0              NaN
# 149656        12000.0      141.17650         0              NaN
# 19200          2000.0       23.52941         0              NaN
# 427271        10000.0      117.64710         0              NaN
# 260728        12350.0      145.29410         0              NaN
# 288513        12350.0      145.29410         0              NaN
# 288508        13000.0      152.94120         0              NaN
# 248010        12000.0      141.17650         0              NaN
# 208412        12000.0      141.17650         0              NaN
# 105122        12000.0      141.17650         0              NaN
# 426300        12000.0      141.17650         0              NaN
# 242426         1700.0       20.00000         0              NaN
# 426114         1700.0       20.00000         0              NaN
# 314426         2250.0       26.47059         0              NaN
# 21202          4650.0       54.70588         0              NaN
#
#         trx_inkind_value_usd  trx_inkind_value_kes  trx_stdtime_mnths_hh_nr  \
# 23025                    NaN                   NaN                 2.241379
# 277437                   NaN                   NaN                 2.551724
# 149656                   NaN                   NaN                 3.620690
# 19200                    NaN                   NaN                 4.551724
# 427271                   NaN                   NaN                 4.551724
# 260728                   NaN                   NaN                 4.724138
# 288513                   NaN                   NaN                 5.689655
# 288508                   NaN                   NaN                 6.896552
# 248010                   NaN                   NaN                 7.862069
# 208412                   NaN                   NaN                 8.827586
# 105122                   NaN                   NaN                 9.793103
# 426300                   NaN                   NaN                11.000000
# 242426                   NaN                   NaN                11.965520
# 426114                   NaN                   NaN                13.034480
# 314426                   NaN                   NaN                14.137930
# 21202                    NaN                   NaN                14.172410
#
#         acc_unexplained_trx
# 23025                   0.0
# 277437                  0.0
# 149656                  0.0
# 19200                   0.0
# 427271                  0.0
# 260728                  0.0
# 288513                  0.0
# 288508                  0.0
# 248010                  0.0
# 208412                  0.0
# 105122                  0.0
# 426300                  0.0
# 242426                  0.0
# 426114                  0.0
# 314426                  0.0
# 21202                   0.0

# %% [markdown]
# ## Now that I see this account I realize that we actually need to consider that there might be transactions on the same day. So we need to check whether there is a new borrowing on any given day, not any given row.

# %%
a = lna["account_ids"].unique()[0]
print(type(a))
a = a+".1"
print(a)
print('{:.20f}'.format(float(a)))
# Out:
# <class 'str'>
# 60135893778700000.1
# 60135893778700000.00000000000000000000

# %% [markdown]
# For some reason the program does not account for the .1 in the float. Maybe it cannot handle that many digits? But I guess it is fine if we have the account numbers as strings.

# %%
dfb["trx_prx_purpose"].unique()
# Out:
# array(['6. Closing Balance--End of last DQ',
#        '1. Starting balance (today)', '5. Interest accruing',
#        '2. New borrowinng (individual portion)', '3. Payments',
#        '4. Any known fees', '7. Refund from lender', '2. New borrowing'],
#       dtype=object)

# %%
# we set the first account number to be the old account number.1
# the subsequent chunks will be called #.2, #.3, etc
i=1
acc = lna["account_ids"].unique()[0]
a = lna["account_ids"].unique()[0]+".1"
for index, row in lna.iterrows():
    if row["trx_prx_purpose"] == "2. New borrowinng (individual portion)" or row["trx_prx_purpose"] == "2. New borrowing":
        i +=1
        a = acc+"."+str(i)
        lna.at[index,"new_account_ids"]=a
    else:
         lna.at[index,"new_account_ids"]=a

# %%
lna[["account_ids","new_account_ids","trx_stdtime_days_acc","trx_prx_purpose","acc_unexplained_trx"]]
# Out:
#               account_ids      new_account_ids  trx_stdtime_days_acc  \
# 260932  60135893778700000  60135893778700000.1                     0
# 281777  60135893778700000  60135893778700000.2                     0
# 400489  60135893778700000  60135893778700000.2                    56
# 194824  60135893778700000  60135893778700000.2                   119
# 275798  60135893778700000  60135893778700000.2                   168
# 15825   60135893778700000  60135893778700000.2                   260
#
#                            trx_prx_purpose  acc_unexplained_trx
# 260932                         3. Payments                  0.0
# 281777                    2. New borrowing                  0.0
# 400489                         3. Payments                  0.0
# 194824                         3. Payments                  0.0
# 275798                         3. Payments                  0.0
# 15825   6. Closing Balance--End of last DQ                  0.0

# %%
lna["new_account_ids"].unique()
# Out:
# array(['60135893778700000.1', '60135893778700000.2'], dtype=object)

# %% [markdown]
# ### Now let's adjust this such that new borrowings are always the first thing on one day.

# %%
for acc in dfb["account_ids"]:
    i=0
    indices = []
    index_bor = 0
    lna = dfb[dfb["account_ids"]==acc]
    lna = lna.sort_values("trx_stdtime_days_acc")
    for d in lna["trx_stdtime_days_acc"].unique():
        if lna[lna["trx_stdtime_days_acc"]==d].shape[0]==1:
            indices.append(lna[lna["trx_stdtime_days_acc"]==d].index[0])
        elif lna[lna["trx_stdtime_days_acc"]==d].shape[0]>1:
            if lna[(lna["trx_stdtime_days_acc"]==d)&((lna["trx_prx_purpose"]=="2. New borrowing")|(lna["trx_prx_purpose"]=="2. New borrowing (individual portion)")|(lna["trx_prx_purpose"]=="1. Starting balance (today)"))].shape[0]>1:
                print("Check manually: several new borrowings on the same day.")
            elif lna[(lna["trx_stdtime_days_acc"]==d)&((lna["trx_prx_purpose"]=="2. New borrowing")|(lna["trx_prx_purpose"]=="2. New borrowing (individual portion)")|(lna["trx_prx_purpose"]=="1. Starting balance (today)"))].shape[0]==1:
                for kind in ["2. New borrowing","2. New borrowing (individual portion)","1. Starting balance (today)"]:
                    if kind in lna[lna["trx_stdtime_days_acc"]==d]["trx_prx_purpose"].unique():
                        index_bor = lna[(lna["trx_stdtime_days_acc"]==d) & (lna["trx_prx_purpose"]==kind)].index[0]
                        indices.append(index_bor)
                        for i in lna[lna["trx_stdtime_days_acc"]==d].index.drop(index_bor):
                           indices.append(i)
            else:
                for i in lna[lna["trx_stdtime_days_acc"]==d].index:
                    indices.append(i)
    # here we reindex only the lna dataset, it would be nice if we could reindex the whole dataset. 
    # But maybe it does not matter actually.
    lna = lna.loc[indices,]
    v=1
    acc = lna["account_ids"].unique()[0]
    a = lna["account_ids"].unique()[0]+".1"
    for index, row in lna.iterrows():
        if row["trx_prx_purpose"] == "2. New borrowinng (individual portion)" or row["trx_prx_purpose"] == "2. New borrowing":
            v +=1
            a = acc+"."+str(v)
            dfb.at[index,"new_account_ids"]=a
        else:
             dfb.at[index,"new_account_ids"]=a
    if acc == "59134942469700000":
        break

# %%
lna["trx_prx_purpose"]=="2. New borrowing"
# Out:
# 23025     False
# 277437    False
# 149656    False
# 427271     True
# 19200     False
# 260728    False
# 288513    False
# 288508    False
# 248010    False
# 208412    False
# 105122    False
# 426300    False
# 242426    False
# 426114    False
# 314426    False
# 21202     False
# Name: trx_prx_purpose, dtype: bool

# %%
dfb[dfb["account_ids"]=="59134942469700000"].sort_values("trx_stdtime_days_acc")
# Out:
#          hh_ids  unique_hhs first_trx_date_hh last_trx_date_hh  \
#
# 288508           FRMLN     Formal loan           2760
# 248010           FRMLN     Formal loan           2760
# 208412           FRMLN     Formal loan           2760
# 105122           FRMLN     Formal loan           2760
# 426300           FRMLN     Formal loan           2760
# 242426           FRMLN     Formal loan           2760
# 426114           FRMLN     Formal loan           2760
# 314426           FRMLN     Formal loan           2760
# 21202            FRMLN     Formal loan           2760
#
#                                   trx_type_desc  \
# 23025   Individual Business or Agriculture Loan
# 277437  Individual Business or Agriculture Loan
# 149656  Individual Business or Agriculture Loan
# 19200   Individual Business or Agriculture Loan
# 427271  Individual Business or Agriculture Loan
# 260728  Individual Business or Agriculture Loan
# 288513  Individual Business or Agriculture Loan
# 288508  Individual Business or Agriculture Loan
# 248010  Individual Business or Agriculture Loan
# 208412  Individual Business or Agriculture Loan
# 105122  Individual Business or Agriculture Loan
# 426300  Individual Business or Agriculture Loan
# 242426  Individual Business or Agriculture Loan
# 426114  Individual Business or Agriculture Loan
# 314426  Individual Business or Agriculture Loan
# 21202   Individual Business or Agriculture Loan
#
#                            trx_prx_purpose  \
# 23025          1. Starting balance (today)
# 277437                         3. Payments
# 149656                         3. Payments
# 19200                 5. Interest accruing
# 427271                    2. New borrowing
# 260728                         3. Payments
# 288513                         3. Payments
# 288508                         3. Payments
# 248010                         3. Payments
# 208412                         3. Payments
# 105122                         3. Payments
# 426300                         3. Payments
# 242426                         3. Payments
# 426114                         3. Payments
# 314426                         3. Payments
# 21202   6. Closing Balance--End of last DQ
#
#                           trx_prx_purpose_fd  trx_fee trx_bsheet_direction  \
# 23025                                    NaN      0.0             Increase
# 277437      Repayment on financial liability      0.0             Decrease
# 149656      Repayment on financial liability      0.0             Decrease
# 19200                                    NaN      0.0             Increase
# 427271  New borrowing on financial liability      0.0             Increase
# 260728      Repayment on financial liability      0.0             Decrease
# 288513      Repayment on financial liability      0.0             Decrease
# 288508      Repayment on financial liability      0.0             Decrease
# 248010      Repayment on financial liability      0.0             Decrease
# 208412      Repayment on financial liability      0.0             Decrease
# 105122      Repayment on financial liability      0.0             Decrease
# 426300      Repayment on financial liability      0.0             Decrease
# 242426      Repayment on financial liability      0.0             Decrease
# 426114      Repayment on financial liability      0.0             Decrease
# 314426      Repayment on financial liability      0.0             Decrease
# 21202                                    NaN      0.0                  NaN
#
#         trx_mode_code                              trx_mode_desc  \
# 23025            18.0                           STARTING BALANCE
# 277437            1.0                                       Cash
# 149656            1.0                                       Cash
# 19200            16.0                                  Automatic
# 427271            3.0  Transfer into bank, SACCO, or MFI account
# 260728            1.0                                       Cash
# 288513            1.0                                       Cash
# 288508            1.0                                       Cash
# 248010            1.0                                       Cash
# 208412            1.0                                       Cash
# 105122            1.0                                       Cash
# 426300            1.0                                       Cash
# 242426            1.0                                       Cash
# 426114            1.0                                       Cash
# 314426            1.0                                       Cash
# 21202            19.0                            CLOSING BALANCE
#
#         trx_place_incommunity  trx_distance_km  \
# 23025                     NaN              NaN
# 277437                    1.0         0.000000
# 149656                    1.0         0.000000
# 19200                     NaN              NaN
# 427271                    0.0         2.189854
# 260728                    1.0         0.000000
# 288513                    1.0         0.000000
# 288508                    1.0         0.000000
# 248010                    1.0         0.000000
# 208412                    1.0         0.000000
# 105122                    1.0         0.000000
# 426300                    0.0         2.189854
# 242426                    1.0         0.000000
# 426114                    0.0         2.189854
# 314426                    1.0         0.000000
# 21202                     NaN              NaN
#
#                                                trx_outlet trx_direction  \
# 23025                                                 NaN           NaN
# 277437                                   07=Group meeting       Outflow
# 149656                                   07=Group meeting       Outflow
# 19200                                                 NaN           NaN
# 427271  06=Direct deposit, payroll deduction, or stand...        Inflow
# 260728                                   07=Group meeting       Outflow
# 288513                                   07=Group meeting       Outflow
# 288508                                   07=Group meeting       Outflow
# 248010                                   07=Group meeting       Outflow
# 208412                                   07=Group meeting       Outflow
# 105122                                   07=Group meeting       Outflow
# 426300              01=Bank, MFI, SACCO, insurance branch       Outflow
# 242426                                   07=Group meeting       Outflow
# 426114              01=Bank, MFI, SACCO, insurance branch       Outflow
# 314426                                   07=Group meeting       Outflow
# 21202                                                 NaN           NaN
#
#         trx_value_kes  trx_value_usd  ddd_gift trx_inkind_units  \
# 23025        108000.0     1270.58800         0              NaN
# 277437        12000.0      141.17650         0              NaN
# 149656        12000.0      141.17650         0              NaN
# 19200          2000.0       23.52941         0              NaN
# 427271        10000.0      117.64710         0              NaN
# 260728        12350.0      145.29410         0              NaN
# 288513        12350.0      145.29410         0              NaN
# 288508        13000.0      152.94120         0              NaN
# 248010        12000.0      141.17650         0              NaN
# 208412        12000.0      141.17650         0              NaN
# 105122        12000.0      141.17650         0              NaN
# 426300        12000.0      141.17650         0              NaN
# 242426         1700.0       20.00000         0              NaN
# 426114         1700.0       20.00000         0              NaN
# 314426         2250.0       26.47059         0              NaN
# 21202          4650.0       54.70588         0              NaN
#
#         trx_inkind_value_usd  trx_inkind_value_kes  trx_stdtime_mnths_hh_nr  \
# 23025                    NaN                   NaN                 2.241379
# 277437                   NaN                   NaN                 2.551724
# 149656                   NaN                   NaN                 3.620690
# 19200                    NaN                   NaN                 4.551724
# 427271                   NaN                   NaN                 4.551724
# 260728                   NaN                   NaN                 4.724138
# 288513                   NaN                   NaN                 5.689655
# 288508                   NaN                   NaN                 6.896552
# 248010                   NaN                   NaN                 7.862069
# 208412                   NaN                   NaN                 8.827586
# 105122                   NaN                   NaN                 9.793103
# 426300                   NaN                   NaN                11.000000
# 242426                   NaN                   NaN                11.965520
# 426114                   NaN                   NaN                13.034480
# 314426                   NaN                   NaN                14.137930
# 21202                    NaN                   NaN                14.172410
#
#         acc_unexplained_trx
# 23025                   0.0
# 277437                  0.0
# 149656                  0.0
# 19200                   0.0
# 427271                  0.0
# 260728                  0.0
# 288513                  0.0
# 288508                  0.0
# 248010                  0.0
# 208412                  0.0
# 105122                  0.0
# 426300                  0.0
# 242426                  0.0
# 426114                  0.0
# 314426                  0.0
# 21202                   0.0
