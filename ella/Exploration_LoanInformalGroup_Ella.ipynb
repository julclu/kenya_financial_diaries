# %% [markdown]
# # Informal Loan Exploration

# %%
import pandas as pd
import numpy as np
import math as math
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# to see all the columns when using head() or describe()
pd.set_option('display.max_columns',60)

# %%
df = pd.read_csv("kenya_data/diaries_transactions_all.csv", dtype={'account_startclose_balance': str})

# %% [markdown]
# ### I first want to at least get the transaction date in the right format, I believe that we should do this for all dates and then save the new data in a csv format.

# %%
from datetime import date

# %% [markdown]
# ### It would be good to first check in which format the entries in the columns are.

# %%
df.dtypes
# Out:
# hh_ids                         object
# unique_hhs                    float64
# first_trx_date_hh              object
# last_trx_date_hh               object
# tot_hh_daysofobs                int64
# tot_hh_monthsofobs              int64
# interview_designation          object
# int_date                       object
# int_month                       int64
# int_year                        int64
# int_yr_mo                      object
# first_int_date                 object
# account_ids                    object
# unique_accnts                 float64
# m_ids_owner                    object
# unique_hm_owner               float64
# account_bsheet_desig           object
# account_startclose_balance     object
# account_formal                 object
# account_liquid                 object
# first_trx_date_acc             object
# last_trx_date_acc              object
# tot_acc_daysofobs               int64
# tot_acc_monthsofobs             int64
# trx_id                          int64
# m_ids_trx                      object
# trx_date                       object
# trx_date2                      object
# trx_month                       int64
# trx_year                        int64
# trx_yr_mo                      object
# trx_dq_round                  float64
# trx_stdtime_days_hh             int64
# trx_stdtime_mnths_hh            int64
# trx_stdtime_days_acc            int64
# trx_stdtime_mnths_acc           int64
# trx_class_code                 object
# trx_class_desc                 object
# trx_family_code                object
# trx_family_desc                object
# trx_type_code                   int64
# trx_type_desc                  object
# trx_prx_purpose                object
# trx_prx_purpose_fd             object
# trx_fee                       float64
# trx_bsheet_direction           object
# trx_mode_code                 float64
# trx_mode_desc                  object
# trx_place_incommunity         float64
# trx_distance_km               float64
# trx_outlet                     object
# trx_direction                  object
# trx_value_kes                 float64
# trx_value_usd                 float64
# ddd_gift                        int64
# trx_inkind_units               object
# trx_inkind_value_usd          float64
# trx_inkind_value_kes          float64
# trx_stdtime_mnths_hh_nr       float64
# dtype: object

# %% [markdown]
# ### We only have floats, integers and objects. Not sure what objects mean. Let's look at one of the entries.

# %%
type(df.loc[1,"trx_date"])
# Out:
# str

# %% [markdown]
# ### Interesting, why would the type then not be str in the list of types above?

# %%
df.head()
# Out:
#     hh_ids  unique_hhs first_trx_date_hh last_trx_date_hh  tot_hh_daysofobs  \
# 0  KELDL02         NaN         03sep2012        02oct2013               394
# 1  KVIHC16         NaN         24sep2012        19sep2013               360
# 2  KELDK21         NaN         20sep2012        22oct2013               397
# 3  KMOMT22         NaN         21sep2012        01nov2013               406
# 4  KMOMT32         NaN         20sep2012        18oct2013               393
#
#    tot_hh_monthsofobs interview_designation   int_date  int_month  int_year  \
# 0                  13  04=Diaries Interview  02oct2013         10      2013
# 1                  12  04=Diaries Interview  22apr2013          4      2013
# 2                  13  04=Diaries Interview  02oct2013         10      2013
# 3                  14  04=Diaries Interview  21feb2013          2      2013
# 4                  13  04=Diaries Interview  02may2013          5      2013
#
#   int_yr_mo first_int_date        account_ids  unique_accnts  \
# 0   2013_10      08sep2012  58134738501900000            1.0
# 1   2013_04      20aug2012                 HH            NaN
# 2   2013_10      05sep2012  56134804374600000            NaN
# 3   2013_02      07sep2012  61135001772200000            NaN
# 4   2013_05      29aug2012                 HH            NaN
#
#          m_ids_owner  unique_hm_owner account_bsheet_desig  \
# 0  58134383397900000              NaN                Asset
# 1                 HH              NaN                  NaN
# 2  65134441430300000              NaN            Liability
# 3  61134425330400000              NaN                Asset
# 4                 HH              NaN                  NaN
#
#   account_startclose_balance account_formal account_liquid first_trx_date_acc  \
# 0                      Close       Informal    Less liquid          02oct2013
# 1                        NaN            NaN            NaN          16aug2012
# 2                      Close       Informal            NaN          17oct2012
# 3                        NaN       Informal    More liquid          12oct2012
# 4                        NaN            NaN            NaN          16aug2012
#
#   last_trx_date_acc  tot_acc_daysofobs  tot_acc_monthsofobs  \
# 0         02oct2013                  0                    0
# 1         31dec2013                502                   17
# 2         02oct2013                350                   12
# 3         02oct2013                355                   12
# 4         31dec2013                502                   17
#
#                trx_id          m_ids_trx   trx_date  trx_month  trx_year  \
# 0  108138072959900000  58134383397900000  02oct2013         10      2013
# 1   59136660314000000  59134423954300000  21apr2013          4      2013
# 2  105138073330800000  65134441430300000  02oct2013         10      2013
# 3   61136151231700000  61134425330400000  07feb2013          2      2013
# 4   61136746749000000  61134468689200000  28mar2013          3      2013
#
#   trx_yr_mo  trx_dq_round  trx_stdtime_days_hh  trx_stdtime_mnths_hh  \
# 0   2013_10          18.0                  394                    13
# 1   2013_04          10.0                  209                     7
# 2   2013_10          17.0                  377                    13
# 3   2013_02           6.0                  139                     4
# 4   2013_03           8.0                  189                     6
#
#    trx_stdtime_days_acc  trx_stdtime_mnths_acc trx_class_code  \
# 0                     0                      0         findev
# 1                   248                      8           cash
# 2                   350                     12         findev
# 3                   118                      4         findev
# 4                   224                      7           opex
#
#                                       trx_class_desc trx_family_code  \
# 0  Borrowing, lending, savings or insurance media...          INFP2P
# 1  Cash (Cash on hand; cash lost, stolen or missing)            CASH
# 2  Borrowing, lending, savings or insurance media...          INFGRP
# 3  Borrowing, lending, savings or insurance media...       INFSAVHOM
# 4  Operational (Personal or household) expenditur...            COMM
#
#                         trx_family_desc  trx_type_code  \
# 0                          Informal P2P           2731
# 1                                  Cash           3499
# 2                        Informal group           3395
# 3  Informal savings: keep money at home           3405
# 4                        Communications           2787
#
#                             trx_type_desc                     trx_prx_purpose  \
# 0             Friends and Family: Lending  7. Closing Balance--End of last DQ
# 1                        Cash on hand now    Cash on hand now (end of period)
# 2        Borrowing from an informal Group  7. Closing Balance--End of last DQ
# 3            Keeping Money (Cash) at Home                      3. Withdrawals
# 4  Pre-paid phone credit and data bundles                           Purchases
#
#               trx_prx_purpose_fd  trx_fee trx_bsheet_direction  trx_mode_code  \
# 0                            NaN      0.0                  NaN           19.0
# 1                            NaN      NaN                  NaN            NaN
# 2                            NaN      0.0                  NaN           19.0
# 3  Withdrawal on financial asset      0.0             Decrease            1.0
# 4                            NaN      NaN                  NaN            1.0
#
#      trx_mode_desc  trx_place_incommunity  trx_distance_km trx_outlet  \
# 0  CLOSING BALANCE                    NaN              NaN        NaN
# 1              NaN                    NaN              NaN        NaN
# 2  CLOSING BALANCE                    NaN              NaN        NaN
# 3             Cash                    NaN              NaN        NaN
# 4             Cash                    NaN              NaN        NaN
#
#   trx_direction  trx_value_kes  trx_value_usd  ddd_gift trx_inkind_units  \
# 0           NaN            0.0       0.000000         0              NaN
# 1       Outflow          100.0       1.176471         0              NaN
# 2           NaN            0.0       0.000000         0              NaN
# 3        Inflow          710.0       8.352942         0              NaN
# 4       Outflow          100.0       1.176471         0              NaN
#
#    trx_inkind_value_usd  trx_inkind_value_kes  trx_stdtime_mnths_hh_nr
# 0                   NaN                   NaN                13.586210
# 1                   NaN                   NaN                 7.206897
# 2                   NaN                   NaN                13.000000
# 3                   NaN                   NaN                 4.793103
# 4                   NaN                   NaN                 6.517241

# %%
df.insert(df.columns.get_loc("trx_date")+1,"trx_date2",[date(2000,1,1)]*df.shape[0])

# %%
df.head()
# Out:
#     hh_ids  unique_hhs first_trx_date_hh last_trx_date_hh  tot_hh_daysofobs  \
# 0  KELDL02         NaN         03sep2012        02oct2013               394
# 1  KVIHC16         NaN         24sep2012        19sep2013               360
# 2  KELDK21         NaN         20sep2012        22oct2013               397
# 3  KMOMT22         NaN         21sep2012        01nov2013               406
# 4  KMOMT32         NaN         20sep2012        18oct2013               393
#
#    tot_hh_monthsofobs interview_designation   int_date  int_month  int_year  \
# 0                  13  04=Diaries Interview  02oct2013         10      2013
# 1                  12  04=Diaries Interview  22apr2013          4      2013
# 2                  13  04=Diaries Interview  02oct2013         10      2013
# 3                  14  04=Diaries Interview  21feb2013          2      2013
# 4                  13  04=Diaries Interview  02may2013          5      2013
#
#   int_yr_mo first_int_date        account_ids  unique_accnts  \
# 0   2013_10      08sep2012  58134738501900000            1.0
# 1   2013_04      20aug2012                 HH            NaN
# 2   2013_10      05sep2012  56134804374600000            NaN
# 3   2013_02      07sep2012  61135001772200000            NaN
# 4   2013_05      29aug2012                 HH            NaN
#
#          m_ids_owner  unique_hm_owner account_bsheet_desig  \
# 0  58134383397900000              NaN                Asset
# 1                 HH              NaN                  NaN
# 2  65134441430300000              NaN            Liability
# 3  61134425330400000              NaN                Asset
# 4                 HH              NaN                  NaN
#
#   account_startclose_balance account_formal account_liquid first_trx_date_acc  \
# 0                      Close       Informal    Less liquid          02oct2013
# 1                        NaN            NaN            NaN          16aug2012
# 2                      Close       Informal            NaN          17oct2012
# 3                        NaN       Informal    More liquid          12oct2012
# 4                        NaN            NaN            NaN          16aug2012
#
#   last_trx_date_acc  tot_acc_daysofobs  tot_acc_monthsofobs  \
# 0         02oct2013                  0                    0
# 1         31dec2013                502                   17
# 2         02oct2013                350                   12
# 3         02oct2013                355                   12
# 4         31dec2013                502                   17
#
#                trx_id          m_ids_trx   trx_date   trx_date2  trx_month  \
# 0  108138072959900000  58134383397900000  02oct2013  2000-01-01         10
# 1   59136660314000000  59134423954300000  21apr2013  2000-01-01          4
# 2  105138073330800000  65134441430300000  02oct2013  2000-01-01         10
# 3   61136151231700000  61134425330400000  07feb2013  2000-01-01          2
# 4   61136746749000000  61134468689200000  28mar2013  2000-01-01          3
#
#    trx_year trx_yr_mo  trx_dq_round  trx_stdtime_days_hh  \
# 0      2013   2013_10          18.0                  394
# 1      2013   2013_04          10.0                  209
# 2      2013   2013_10          17.0                  377
# 3      2013   2013_02           6.0                  139
# 4      2013   2013_03           8.0                  189
#
#    trx_stdtime_mnths_hh  trx_stdtime_days_acc  trx_stdtime_mnths_acc  \
# 0                    13                     0                      0
# 1                     7                   248                      8
# 2                    13                   350                     12
# 3                     4                   118                      4
# 4                     6                   224                      7
#
#   trx_class_code                                     trx_class_desc  \
# 0         findev  Borrowing, lending, savings or insurance media...
# 1           cash  Cash (Cash on hand; cash lost, stolen or missing)
# 2         findev  Borrowing, lending, savings or insurance media...
# 3         findev  Borrowing, lending, savings or insurance media...
# 4           opex  Operational (Personal or household) expenditur...
#
#   trx_family_code                       trx_family_desc  trx_type_code  \
# 0          INFP2P                          Informal P2P           2731
# 1            CASH                                  Cash           3499
# 2          INFGRP                        Informal group           3395
# 3       INFSAVHOM  Informal savings: keep money at home           3405
# 4            COMM                        Communications           2787
#
#                             trx_type_desc                     trx_prx_purpose  \
# 0             Friends and Family: Lending  7. Closing Balance--End of last DQ
# 1                        Cash on hand now    Cash on hand now (end of period)
# 2        Borrowing from an informal Group  7. Closing Balance--End of last DQ
# 3            Keeping Money (Cash) at Home                      3. Withdrawals
# 4  Pre-paid phone credit and data bundles                           Purchases
#
#               trx_prx_purpose_fd  trx_fee trx_bsheet_direction  trx_mode_code  \
# 0                            NaN      0.0                  NaN           19.0
# 1                            NaN      NaN                  NaN            NaN
# 2                            NaN      0.0                  NaN           19.0
# 3  Withdrawal on financial asset      0.0             Decrease            1.0
# 4                            NaN      NaN                  NaN            1.0
#
#      trx_mode_desc  trx_place_incommunity  trx_distance_km trx_outlet  \
# 0  CLOSING BALANCE                    NaN              NaN        NaN
# 1              NaN                    NaN              NaN        NaN
# 2  CLOSING BALANCE                    NaN              NaN        NaN
# 3             Cash                    NaN              NaN        NaN
# 4             Cash                    NaN              NaN        NaN
#
#   trx_direction  trx_value_kes  trx_value_usd  ddd_gift trx_inkind_units  \
# 0           NaN            0.0       0.000000         0              NaN
# 1       Outflow          100.0       1.176471         0              NaN
# 2           NaN            0.0       0.000000         0              NaN
# 3        Inflow          710.0       8.352942         0              NaN
# 4       Outflow          100.0       1.176471         0              NaN
#
#    trx_inkind_value_usd  trx_inkind_value_kes  trx_stdtime_mnths_hh_nr
# 0                   NaN                   NaN                13.586210
# 1                   NaN                   NaN                 7.206897
# 2                   NaN                   NaN                13.000000
# 3                   NaN                   NaN                 4.793103
# 4                   NaN                   NaN                 6.517241

# %%
for index, row in df.iterrows():
    day = int(df.loc[index,"trx_date"][0:2])
    year = int(df.loc[index,"trx_date"][5:9])
    if df.loc[index,"trx_date"][2:5] == "jan":
        month = 1
    elif df.loc[index,"trx_date"][2:5] == "feb":
        month = 2
    elif df.loc[index,"trx_date"][2:5] == "mar":
        month = 3
    elif df.loc[index,"trx_date"][2:5] == "apr":
        month = 4
    elif df.loc[index,"trx_date"][2:5] == "may":
        month = 5
    elif df.loc[index,"trx_date"][2:5] == "jun":
        month = 6
    elif df.loc[index,"trx_date"][2:5] == "jul":
        month = 7
    elif df.loc[index,"trx_date"][2:5] == "aug":
        month = 8
    elif df.loc[index,"trx_date"][2:5] == "sep":
        month = 9
    elif df.loc[index,"trx_date"][2:5] == "oct":
        month = 10
    elif df.loc[index,"trx_date"][2:5] == "nov":
        month = 11
    elif df.loc[index,"trx_date"][2:5] == "dec":
        month = 12
    else:
        print("The date seems to be in an odd format.",dfh.loc[index,"int_date"][0:2],dfh.loc[index,"int_date"][2:5],dfh.loc[index,"int_date"][5:9])
    
    df.at[index,"trx_date2"]=date(year,month,day)

# %%
df.head()
# Out:
#     hh_ids  unique_hhs first_trx_date_hh last_trx_date_hh  tot_hh_daysofobs  \
# 0  KELDL02         NaN         03sep2012        02oct2013               394
# 1  KVIHC16         NaN         24sep2012        19sep2013               360
# 2  KELDK21         NaN         20sep2012        22oct2013               397
# 3  KMOMT22         NaN         21sep2012        01nov2013               406
# 4  KMOMT32         NaN         20sep2012        18oct2013               393
#
#    tot_hh_monthsofobs interview_designation   int_date  int_month  int_year  \
# 0                  13  04=Diaries Interview  02oct2013         10      2013
# 1                  12  04=Diaries Interview  22apr2013          4      2013
# 2                  13  04=Diaries Interview  02oct2013         10      2013
# 3                  14  04=Diaries Interview  21feb2013          2      2013
# 4                  13  04=Diaries Interview  02may2013          5      2013
#
#   int_yr_mo first_int_date        account_ids  unique_accnts  \
# 0   2013_10      08sep2012  58134738501900000            1.0
# 1   2013_04      20aug2012                 HH            NaN
# 2   2013_10      05sep2012  56134804374600000            NaN
# 3   2013_02      07sep2012  61135001772200000            NaN
# 4   2013_05      29aug2012                 HH            NaN
#
#          m_ids_owner  unique_hm_owner account_bsheet_desig  \
# 0  58134383397900000              NaN                Asset
# 1                 HH              NaN                  NaN
# 2  65134441430300000              NaN            Liability
# 3  61134425330400000              NaN                Asset
# 4                 HH              NaN                  NaN
#
#   account_startclose_balance account_formal account_liquid first_trx_date_acc  \
# 0                      Close       Informal    Less liquid          02oct2013
# 1                        NaN            NaN            NaN          16aug2012
# 2                      Close       Informal            NaN          17oct2012
# 3                        NaN       Informal    More liquid          12oct2012
# 4                        NaN            NaN            NaN          16aug2012
#
#   last_trx_date_acc  tot_acc_daysofobs  tot_acc_monthsofobs  \
# 0         02oct2013                  0                    0
# 1         31dec2013                502                   17
# 2         02oct2013                350                   12
# 3         02oct2013                355                   12
# 4         31dec2013                502                   17
#
#                trx_id          m_ids_trx   trx_date   trx_date2  trx_month  \
# 0  108138072959900000  58134383397900000  02oct2013  2013-10-02         10
# 1   59136660314000000  59134423954300000  21apr2013  2013-04-21          4
# 2  105138073330800000  65134441430300000  02oct2013  2013-10-02         10
# 3   61136151231700000  61134425330400000  07feb2013  2013-02-07          2
# 4   61136746749000000  61134468689200000  28mar2013  2013-03-28          3
#
#    trx_year trx_yr_mo  trx_dq_round  trx_stdtime_days_hh  \
# 0      2013   2013_10          18.0                  394
# 1      2013   2013_04          10.0                  209
# 2      2013   2013_10          17.0                  377
# 3      2013   2013_02           6.0                  139
# 4      2013   2013_03           8.0                  189
#
#    trx_stdtime_mnths_hh  trx_stdtime_days_acc  trx_stdtime_mnths_acc  \
# 0                    13                     0                      0
# 1                     7                   248                      8
# 2                    13                   350                     12
# 3                     4                   118                      4
# 4                     6                   224                      7
#
#   trx_class_code                                     trx_class_desc  \
# 0         findev  Borrowing, lending, savings or insurance media...
# 1           cash  Cash (Cash on hand; cash lost, stolen or missing)
# 2         findev  Borrowing, lending, savings or insurance media...
# 3         findev  Borrowing, lending, savings or insurance media...
# 4           opex  Operational (Personal or household) expenditur...
#
#   trx_family_code                       trx_family_desc  trx_type_code  \
# 0          INFP2P                          Informal P2P           2731
# 1            CASH                                  Cash           3499
# 2          INFGRP                        Informal group           3395
# 3       INFSAVHOM  Informal savings: keep money at home           3405
# 4            COMM                        Communications           2787
#
#                             trx_type_desc                     trx_prx_purpose  \
# 0             Friends and Family: Lending  7. Closing Balance--End of last DQ
# 1                        Cash on hand now    Cash on hand now (end of period)
# 2        Borrowing from an informal Group  7. Closing Balance--End of last DQ
# 3            Keeping Money (Cash) at Home                      3. Withdrawals
# 4  Pre-paid phone credit and data bundles                           Purchases
#
#               trx_prx_purpose_fd  trx_fee trx_bsheet_direction  trx_mode_code  \
# 0                            NaN      0.0                  NaN           19.0
# 1                            NaN      NaN                  NaN            NaN
# 2                            NaN      0.0                  NaN           19.0
# 3  Withdrawal on financial asset      0.0             Decrease            1.0
# 4                            NaN      NaN                  NaN            1.0
#
#      trx_mode_desc  trx_place_incommunity  trx_distance_km trx_outlet  \
# 0  CLOSING BALANCE                    NaN              NaN        NaN
# 1              NaN                    NaN              NaN        NaN
# 2  CLOSING BALANCE                    NaN              NaN        NaN
# 3             Cash                    NaN              NaN        NaN
# 4             Cash                    NaN              NaN        NaN
#
#   trx_direction  trx_value_kes  trx_value_usd  ddd_gift trx_inkind_units  \
# 0           NaN            0.0       0.000000         0              NaN
# 1       Outflow          100.0       1.176471         0              NaN
# 2           NaN            0.0       0.000000         0              NaN
# 3        Inflow          710.0       8.352942         0              NaN
# 4       Outflow          100.0       1.176471         0              NaN
#
#    trx_inkind_value_usd  trx_inkind_value_kes  trx_stdtime_mnths_hh_nr
# 0                   NaN                   NaN                13.586210
# 1                   NaN                   NaN                 7.206897
# 2                   NaN                   NaN                13.000000
# 3                   NaN                   NaN                 4.793103
# 4                   NaN                   NaN                 6.517241

# %% [markdown]
# # Let us look at the number of informal loans (INFGRP, INFP2P) vs formal loans (FRMLN)

# %%
df["trx_family_code"].describe()
# Out:
# count     483949
# unique        44
# top         FOOD
# freq      163483
# Name: trx_family_code, dtype: object

# %%
df["trx_family_code"].unique()
# Out:
# array(['INFP2P', 'CASH', 'INFGRP', 'INFSAVHOM', 'COMM', 'MOBMNY', 'SEI',
#        'FOOD', 'SUPPCRD', 'FRMLN', 'ARREARS', 'FRMSAVWA', 'CITMPC', 'REI',
#        'PERS', 'LAYAWAY', 'ENRGY', 'RG', 'FRMSAVRA', 'OTH', 'OTHER',
#        'EDU', 'CLTH', 'RIOI', 'ADVANCE', 'TRNSP', 'EMPLN', 'RR', 'REL',
#        'ENT', 'CLN', 'FRMINS', 'ALC', 'H20', 'AGRI', 'MED', 'PAWN',
#        'PRCH', 'HSNG', 'PSTHR', 'LOSS', 'SALE', 'NEINCG', 'GIFT'],
#       dtype=object)

# %%
df["trx_family_code"].value_counts()
# Out:
# FOOD         163483
# SEI           71156
# ENRGY         25273
# COMM          25011
# TRNSP         23549
# INFGRP        20516
# INFP2P        19828
# MOBMNY        14665
# CITMPC        12193
# RR            10958
# CLN           10589
# H20            8967
# AGRI           8115
# CASH           7599
# INFSAVHOM      7232
# EDU            5438
# FRMSAVWA       5352
# PERS           4522
# RIOI           4334
# REL            4226
# ALC            4144
# SUPPCRD        4050
# RG             3623
# REI            3521
# OTH            2938
# MED            2389
# CLTH           1725
# HSNG           1505
# FRMLN          1429
# ARREARS        1402
# FRMSAVRA       1220
# PRCH            644
# FRMINS          553
# NEINCG          354
# LAYAWAY         287
# ADVANCE         280
# SALE            229
# ENT             183
# PSTHR           163
# OTHER           129
# EMPLN           111
# LOSS             26
# GIFT             22
# PAWN             16
# Name: trx_family_code, dtype: int64

# %% [markdown]
# ### We see that there are way more informal loans than formal loans. Eventhough micorcredit would probably be considered to be formal loans, I feel like we should also take advantage of the informal loans data.

# %% [markdown]
# # Let's only keep the informal loans. Since INFGRP seems to be closer to a formal loan than the other ones, let us first look at those.

# %%
dfi = df[df["trx_family_code"] == "INFGRP"]

# %%
dfi.head()
# Out:
#      hh_ids  unique_hhs first_trx_date_hh last_trx_date_hh  tot_hh_daysofobs  \
# 2   KELDK21         NaN         20sep2012        22oct2013               397
# 13  KMAKE25         NaN         25sep2012        12oct2013               382
# 20  KELDK27         NaN         23sep2012        06oct2013               378
# 26  KMOMM10         NaN         05sep2012        04nov2013               425
# 40  KNBOK05         NaN         01nov2012        02nov2013               366
#
#     tot_hh_monthsofobs interview_designation   int_date  int_month  int_year  \
# 2                   13  04=Diaries Interview  02oct2013         10      2013
# 13                  13  04=Diaries Interview  01oct2013         10      2013
# 20                  13  04=Diaries Interview  06oct2013         10      2013
# 26                  14  04=Diaries Interview  25sep2013          9      2013
# 40                  12  04=Diaries Interview  01nov2013         11      2013
#
#    int_yr_mo first_int_date         account_ids  unique_accnts  \
# 2    2013_10      05sep2012   56134804374600000            NaN
# 13   2013_10      25sep2012   63134736324600000            NaN
# 20   2013_10      26aug2012  105136651810500000            NaN
# 26   2013_09      05sep2012   57136307716900000            NaN
# 40   2013_11      11sep2012   50135816159000000            NaN
#
#            m_ids_owner  unique_hm_owner account_bsheet_desig  \
# 2    65134441430300000              NaN            Liability
# 13   63134458362700000              NaN            Insurance
# 20  105136530871900000              NaN                Asset
# 26   57134320447800000              NaN                Asset
# 40   64134429266300000              NaN                Asset
#
#    account_startclose_balance account_formal account_liquid  \
# 2                       Close       Informal            NaN
# 13                      Close       Informal            NaN
# 20                      Close       Informal    Less liquid
# 26                      Close       Informal    Less liquid
# 40                      Close       Informal    Less liquid
#
#    first_trx_date_acc last_trx_date_acc  tot_acc_daysofobs  \
# 2           17oct2012         02oct2013                350
# 13          29sep2012         01oct2013                367
# 20          13apr2013         06oct2013                176
# 26          05sep2012         04nov2013                425
# 40          15nov2012         01nov2013                351
#
#     tot_acc_monthsofobs              trx_id           m_ids_trx   trx_date  \
# 2                    12  105138073330800000   65134441430300000  02oct2013
# 13                   12   63138301746700000   63134458362700000  01oct2013
# 20                    6  105138119212200000  105136530871900000  06oct2013
# 26                   14   57138010737300000   57134320447800000  25sep2013
# 40                   12   89138362764600000   64134429266300000  01nov2013
#
#      trx_date2  trx_month  trx_year trx_yr_mo  trx_dq_round  \
# 2   2013-10-02         10      2013   2013_10          17.0
# 13  2013-10-01         10      2013   2013_10          19.0
# 20  2013-10-06         10      2013   2013_10          18.0
# 26  2013-09-25          9      2013   2013_09          22.0
# 40  2013-11-01         11      2013   2013_11          22.0
#
#     trx_stdtime_days_hh  trx_stdtime_mnths_hh  trx_stdtime_days_acc  \
# 2                   377                    13                   350
# 13                  371                    12                   367
# 20                  378                    13                   176
# 26                  385                    13                   385
# 40                  365                    12                   351
#
#     trx_stdtime_mnths_acc trx_class_code  \
# 2                      12         findev
# 13                     12         findev
# 20                      6         findev
# 26                     13         findev
# 40                     12         findev
#
#                                        trx_class_desc trx_family_code  \
# 2   Borrowing, lending, savings or insurance media...          INFGRP
# 13  Borrowing, lending, savings or insurance media...          INFGRP
# 20  Borrowing, lending, savings or insurance media...          INFGRP
# 26  Borrowing, lending, savings or insurance media...          INFGRP
# 40  Borrowing, lending, savings or insurance media...          INFGRP
#
#    trx_family_desc  trx_type_code                     trx_type_desc  \
# 2   Informal group           3395  Borrowing from an informal Group
# 13  Informal group           3248                     Welfare Group
# 20  Informal group           3335                 Saving in a ROSCA
# 26  Informal group           3335                 Saving in a ROSCA
# 40  Informal group           3335                 Saving in a ROSCA
#
#                        trx_prx_purpose trx_prx_purpose_fd  trx_fee  \
# 2   7. Closing Balance--End of last DQ                NaN      0.0
# 13  3. Closing Balance--End of last DQ                NaN      0.0
# 20  6. Closing Balance--End of last DQ                NaN      0.0
# 26  6. Closing Balance--End of last DQ                NaN      0.0
# 40  6. Closing Balance--End of last DQ                NaN      0.0
#
#    trx_bsheet_direction  trx_mode_code    trx_mode_desc  \
# 2                   NaN           19.0  CLOSING BALANCE
# 13                  NaN           19.0  CLOSING BALANCE
# 20                  NaN           19.0  CLOSING BALANCE
# 26                  NaN           19.0  CLOSING BALANCE
# 40                  NaN           19.0  CLOSING BALANCE
#
#     trx_place_incommunity  trx_distance_km trx_outlet trx_direction  \
# 2                     NaN              NaN        NaN           NaN
# 13                    NaN              NaN        NaN           NaN
# 20                    NaN              NaN        NaN           NaN
# 26                    NaN              NaN        NaN           NaN
# 40                    NaN              NaN        NaN           NaN
#
#     trx_value_kes  trx_value_usd  ddd_gift trx_inkind_units  \
# 2             0.0       0.000000         0              NaN
# 13            0.0       0.000000         0              NaN
# 20            0.0       0.000000         0              NaN
# 26         8000.0      94.117650         0              NaN
# 40         -450.0      -5.294117         0              NaN
#
#     trx_inkind_value_usd  trx_inkind_value_kes  trx_stdtime_mnths_hh_nr
# 2                    NaN                   NaN                 13.00000
# 13                   NaN                   NaN                 12.79310
# 20                   NaN                   NaN                 13.03448
# 26                   NaN                   NaN                 13.27586
# 40                   NaN                   NaN                 12.58621

# %% [markdown]
# ### In the column "account_bsheet_desig" we have liability, asset and insurance. This seems confusing to me. I thought that transactions with the class code "INFGRP" are supposed to only be loans.

# %% [markdown]
# ### I want to check some other columns to see if these are really all only loans.

# %%
dfi["trx_class_code"].describe()
# Out:
# count      20516
# unique         1
# top       findev
# freq       20516
# Name: trx_class_code, dtype: object

# %% [markdown]
# ### They are all financial devices, which is good.

# %%
dfi["trx_type_desc"].describe()
# Out:
# count                 20516
# unique                    4
# top       Saving in a ROSCA
# freq                  13717
# Name: trx_type_desc, dtype: object

# %%
dfi["trx_type_desc"].unique()
# Out:
# array(['Borrowing from an informal Group', 'Welfare Group',
#        'Saving in a ROSCA', 'Saving in an ASCA'], dtype=object)

# %%
dfi["account_bsheet_desig"].unique()
# Out:
# array(['Liability', 'Insurance', 'Asset'], dtype=object)

# %% [markdown]
# ### I just checked the handbook and it is not the case that all transactions with the code "INFGRP" are loans, there also are other kinds of financial devices with that code. We will need to additionally screen for the trx_type_code 3395.

# %%
dfi = dfi[dfi["trx_type_code"]==3395]

# %%
dfi.shape
# Out:
# (1377, 59)

# %%
df[df["trx_family_code"]=="FRMLN"].shape
# Out:
# (1429, 59)

# %% [markdown]
# ## So there is a similar number of transactions linked to loans from informal groups and formal loans.

# %%
dfi.head()
# Out:
#       hh_ids  unique_hhs first_trx_date_hh last_trx_date_hh  tot_hh_daysofobs  \
# 2    KELDK21         NaN         20sep2012        22oct2013               397
# 96   KNBOK05         NaN         01nov2012        02nov2013               366
# 211  KMAKE34         NaN         14sep2012        10oct2013               391
# 217  KVIHC28         NaN         01oct2012        05oct2013               369
# 287  KMOMB16         NaN         03sep2012        30sep2013               392
#
#      tot_hh_monthsofobs  interview_designation   int_date  int_month  \
# 2                    13   04=Diaries Interview  02oct2013         10
# 96                   12   04=Diaries Interview  15mar2013          3
# 211                  13   04=Diaries Interview  20jun2013          6
# 217                  12  06=Cleaning interview  04oct2013         10
# 287                  13   04=Diaries Interview  30sep2013          9
#
#      int_year int_yr_mo first_int_date        account_ids  unique_accnts  \
# 2        2013   2013_10      05sep2012  56134804374600000            NaN
# 96       2013   2013_03      11sep2012  89136459180500000            NaN
# 211      2013   2013_06      28aug2012  63137182523900000            NaN
# 217      2013   2013_10      28sep2012  59134985308000000            NaN
# 287      2013   2013_09      20aug2012  57134667505500000            NaN
#
#            m_ids_owner  unique_hm_owner account_bsheet_desig  \
# 2    65134441430300000              NaN            Liability
# 96   64134429266300000              NaN            Liability
# 211  63134364423800000              NaN            Liability
# 217  59134388500400000              NaN            Liability
# 287  57134295592300000              NaN            Liability
#
#     account_startclose_balance account_formal account_liquid  \
# 2                        Close       Informal            NaN
# 96                         NaN       Informal            NaN
# 211                        NaN       Informal            NaN
# 217                        NaN       Informal            NaN
# 287                      Close       Informal            NaN
#
#     first_trx_date_acc last_trx_date_acc  tot_acc_daysofobs  \
# 2            17oct2012         02oct2013                350
# 96           12feb2013         01nov2013                262
# 211          10jun2013         01oct2013                113
# 217          22nov2012         03oct2013                315
# 287          03sep2012         30sep2013                392
#
#      tot_acc_monthsofobs              trx_id          m_ids_trx   trx_date  \
# 2                     12  105138073330800000  65134441430300000  02oct2013
# 96                     9   89136682215400000  64134429266300000  14mar2013
# 211                    3   63137182717700000  63134364423800000  10jun2013
# 217                   10   60138643199500000  59134388500400000  30dec2012
# 287                   13   57138052924400000  57134295592300000  30sep2013
#
#       trx_date2  trx_month  trx_year trx_yr_mo  trx_dq_round  \
# 2    2013-10-02         10      2013   2013_10          17.0
# 96   2013-03-14          3      2013   2013_03           7.0
# 211  2013-06-10          6      2013   2013_06          13.0
# 217  2012-12-30         12      2012   2012_12          19.0
# 287  2013-09-30          9      2013   2013_09          22.0
#
#      trx_stdtime_days_hh  trx_stdtime_mnths_hh  trx_stdtime_days_acc  \
# 2                    377                    13                   350
# 96                   133                     4                    30
# 211                  269                     9                     0
# 217                   90                     3                    38
# 287                  392                    13                   392
#
#      trx_stdtime_mnths_acc trx_class_code  \
# 2                       12         findev
# 96                       1         findev
# 211                      0         findev
# 217                      1         findev
# 287                     13         findev
#
#                                         trx_class_desc trx_family_code  \
# 2    Borrowing, lending, savings or insurance media...          INFGRP
# 96   Borrowing, lending, savings or insurance media...          INFGRP
# 211  Borrowing, lending, savings or insurance media...          INFGRP
# 217  Borrowing, lending, savings or insurance media...          INFGRP
# 287  Borrowing, lending, savings or insurance media...          INFGRP
#
#     trx_family_desc  trx_type_code                     trx_type_desc  \
# 2    Informal group           3395  Borrowing from an informal Group
# 96   Informal group           3395  Borrowing from an informal Group
# 211  Informal group           3395  Borrowing from an informal Group
# 217  Informal group           3395  Borrowing from an informal Group
# 287  Informal group           3395  Borrowing from an informal Group
#
#                         trx_prx_purpose trx_prx_purpose_fd  trx_fee  \
# 2    7. Closing Balance--End of last DQ                NaN      0.0
# 96                 5. Interest accruing                NaN      0.0
# 211                5. Interest accruing                NaN      0.0
# 217                5. Interest accruing                NaN      0.0
# 287  7. Closing Balance--End of last DQ                NaN      0.0
#
#     trx_bsheet_direction  trx_mode_code    trx_mode_desc  \
# 2                    NaN           19.0  CLOSING BALANCE
# 96              Increase            1.0             Cash
# 211             Increase            1.0             Cash
# 217             Increase            1.0             Cash
# 287                  NaN           19.0  CLOSING BALANCE
#
#      trx_place_incommunity  trx_distance_km trx_outlet trx_direction  \
# 2                      NaN              NaN        NaN           NaN
# 96                     NaN              NaN        NaN           NaN
# 211                    NaN              NaN        NaN           NaN
# 217                    NaN              NaN        NaN           NaN
# 287                    NaN              NaN        NaN           NaN
#
#      trx_value_kes  trx_value_usd  ddd_gift trx_inkind_units  \
# 2              0.0       0.000000         0              NaN
# 96           600.0       7.058824         0              NaN
# 211          200.0       2.352941         0              NaN
# 217         1000.0      11.764710         0              NaN
# 287          350.0       4.117647         0              NaN
#
#      trx_inkind_value_usd  trx_inkind_value_kes  trx_stdtime_mnths_hh_nr
# 2                     NaN                   NaN                13.000000
# 96                    NaN                   NaN                 4.586207
# 211                   NaN                   NaN                 9.275862
# 217                   NaN                   NaN                 3.103448
# 287                   NaN                   NaN                13.517240

# %%
dfi["account_bsheet_desig"].unique()
# Out:
# array(['Liability'], dtype=object)

# %%
dfi["trx_type_desc"].unique()
# Out:
# array(['Borrowing from an informal Group'], dtype=object)

# %% [markdown]
# ### The last time I checked for the height of the loans using just a histogram for all the values associated to that code. But this does not actually make sense, since we are interested in the amount of the starting balance. Or when they take a new borrowing on an old loan, how much that is. So maybe the best way to get an idea of the distribution of the heights of loans would be to make a histogram of all starting balances and all new borrowing transactions. Let's see where that is recorded.

# %%
dfi["trx_prx_purpose"].unique()
# Out:
# array(['7. Closing Balance--End of last DQ', '5. Interest accruing',
#        'INCREASE--Unexplained balance adjustment',
#        'DECREASE--Unexplained balance adjustment',
#        '1. Starting balance (today)', '3. Payments', '4. Any known fees',
#        '2. New borrowing'], dtype=object)

# %% [markdown]
# ###  We only want to keep the columns "starting balance" or "new borrowing" I believe. But to make sure, let's see how often there is an unexplained balance increase or decrease.

# %%
dfi[(dfi["trx_prx_purpose"]=="INCREASE--Unexplained balance adjustment")|(dfi["trx_prx_purpose"]=="DECREASE--Unexplained balance adjustment")].shape
# Out:
# (21, 59)

# %% [markdown]
# ### Ok not too often. I wonder if these are huge amounts.

# %%
dfi[(dfi["trx_prx_purpose"]=="INCREASE--Unexplained balance adjustment")|(dfi["trx_prx_purpose"]=="DECREASE--Unexplained balance adjustment")]["trx_value_kes"].hist()

# %%
dfi[(dfi["trx_prx_purpose"]=="INCREASE--Unexplained balance adjustment")|(dfi["trx_prx_purpose"]=="DECREASE--Unexplained balance adjustment")]["trx_value_kes"].mean()
# Out:
# 4575.9047619047615

# %% [markdown]
# ### Ok not tiny. I wonder how many unique accounts this concerns.

# %%
dfi[(dfi["trx_prx_purpose"]=="INCREASE--Unexplained balance adjustment")|(dfi["trx_prx_purpose"]=="DECREASE--Unexplained balance adjustment")]["account_ids"].value_counts()
# Out:
# 59134744923800000    1
# 89136147514200000    1
# 59134752803800000    1
# 59134874164800000    1
# 59135453668400000    1
# 63137411946300000    1
# 59134796449500000    1
# 63135365595900000    1
# 58134808684000000    1
# 61134761356700000    1
# 50135720216700000    1
# 59134864183300000    1
# 62134812582900000    1
# 89136197072500000    1
# 59134865147600000    1
# 59135453645700000    1
# 50135823715900000    1
# 59134794957300000    1
# 89136446053700000    1
# 50136213203700000    1
# 89137171306900000    1
# Name: account_ids, dtype: int64

# %%
dfi[(dfi["trx_prx_purpose"]=="INCREASE--Unexplained balance adjustment")|(dfi["trx_prx_purpose"]=="DECREASE--Unexplained balance adjustment")][["trx_bsheet_direction", "trx_direction","trx_value_kes"]]
# Out:
#       trx_bsheet_direction trx_direction  trx_value_kes
# 612               Increase           NaN         2500.0
# 835               Decrease           NaN         1800.0
# 1518              Increase           NaN          500.0
# 3401              Decrease           NaN         6200.0
# 5704              Decrease           NaN         7000.0
# 8661              Increase           NaN         1450.0
# 9602              Increase           NaN        51570.0
# 10732             Decrease           NaN         1600.0
# 10887             Decrease           NaN          260.0
# 11496             Increase           NaN         1500.0
# 1022                    0                     0                     0
# 1415                   46                     1                     0
# 1497                    0                     0                     0
# 1701                   61                     2                    35
# 1996                   22                     0                     0
#
#       trx_stdtime_mnths_acc trx_class_code  \
# 1022                      0         findev
# 1415                      0         findev
# 1497                      0         findev
# 1701                      1         findev
# 1996                      0         findev
#
#                                          trx_class_desc trx_family_code  \
# 1022  Borrowing, lending, savings or insurance media...          INFGRP
# 1415  Borrowing, lending, savings or insurance media...          INFGRP
# 1497  Borrowing, lending, savings or insurance media...          INFGRP
# 1701  Borrowing, lending, savings or insurance media...          INFGRP
# 1996  Borrowing, lending, savings or insurance media...          INFGRP
#
#      trx_family_desc  trx_type_code                     trx_type_desc  \
# 1022  Informal group           3395  Borrowing from an informal Group
# 1415  Informal group           3395  Borrowing from an informal Group
# 1497  Informal group           3395  Borrowing from an informal Group
# 1701  Informal group           3395  Borrowing from an informal Group
# 1996  Informal group           3395  Borrowing from an informal Group
#
#                   trx_prx_purpose trx_prx_purpose_fd  trx_fee  \
# 1022  1. Starting balance (today)                NaN      0.0
# 1415  1. Starting balance (today)                NaN      0.0
# 1497  1. Starting balance (today)                NaN      0.0
# 1701  1. Starting balance (today)                NaN      0.0
# 1996  1. Starting balance (today)                NaN      0.0
#
#      trx_bsheet_direction  trx_mode_code     trx_mode_desc  \
# 1022             Increase           18.0  STARTING BALANCE
# 1415             Increase           18.0  STARTING BALANCE
# 1497             Increase           18.0  STARTING BALANCE
# 1701             Increase           18.0  STARTING BALANCE
# 1996             Increase           18.0  STARTING BALANCE
#
#       trx_place_incommunity  trx_distance_km trx_outlet trx_direction  \
# 1022                    NaN              NaN        NaN           NaN
# 1415                    NaN              NaN        NaN           NaN
# 1497                    NaN              NaN        NaN           NaN
# 1701                    NaN              NaN        NaN           NaN
# 1996                    NaN              NaN        NaN           NaN
#
#       trx_value_kes  trx_value_usd  ddd_gift trx_inkind_units  \
# 1022        10000.0      117.64710         0              NaN
# 1415        17680.0      208.00000         0              NaN
# 1497        15000.0      176.47060         0              NaN
# 1701         2000.0       23.52941         0              NaN
# 1996        20000.0      235.29410         0              NaN
#
#       trx_inkind_value_usd  trx_inkind_value_kes  trx_stdtime_mnths_hh_nr
# 1022                   NaN                   NaN                 0.000000
# 1415                   NaN                   NaN                 1.586207
# 1497                   NaN                   NaN                 0.000000
# 1701                   NaN                   NaN                 2.103448
# 1996                   NaN                   NaN                 0.758621

# %%
dfi[(dfi["trx_prx_purpose"]=="1. Starting balance (today)")|(dfi["trx_prx_purpose"]=="2. New borrowing")]["trx_value_kes"].hist()

# %%
dfi[((dfi["trx_prx_purpose"]=="1. Starting balance (today)")|(dfi["trx_prx_purpose"]=="2. New borrowing"))& (dfi["trx_value_kes"] <= 10000)]["trx_value_kes"].hist()

# %%
dfi[((dfi["trx_prx_purpose"]=="1. Starting balance (today)")|(dfi["trx_prx_purpose"]=="2. New borrowing"))& (dfi["trx_value_kes"] <= 1000)]["trx_value_kes"].hist()

# %% [markdown]
# ### Let us see if we also have negative values, i.e. mistakes here.

# %%
dfi[dfi["trx_value_kes"]<0]
# Out:
# Empty DataFrame
# Columns: [hh_ids, unique_hhs, first_trx_date_hh, last_trx_date_hh, tot_hh_daysofobs, tot_hh_monthsofobs, interview_designation, int_date, int_month, int_year, int_yr_mo, first_int_date, account_ids, unique_accnts, m_ids_owner, unique_hm_owner, account_bsheet_desig, account_startclose_balance, account_formal, account_liquid, first_trx_date_acc, last_trx_date_acc, tot_acc_daysofobs, tot_acc_monthsofobs, trx_id, m_ids_trx, trx_date, trx_date2, trx_month, trx_year, trx_yr_mo, trx_dq_round, trx_stdtime_days_hh, trx_stdtime_mnths_hh, trx_stdtime_days_acc, trx_stdtime_mnths_acc, trx_class_code, trx_class_desc, trx_family_code, trx_family_desc, trx_type_code, trx_type_desc, trx_prx_purpose, trx_prx_purpose_fd, trx_fee, trx_bsheet_direction, trx_mode_code, trx_mode_desc, trx_place_incommunity, trx_distance_km, trx_outlet, trx_direction, trx_value_kes, trx_value_usd, ddd_gift, trx_inkind_units, trx_inkind_value_usd, trx_inkind_value_kes, trx_stdtime_mnths_hh_nr]
# Index: []

# %% [markdown]
# ### Doesn't look like it.

# %% [markdown]
# ## To see how well we can evaluate whether a person paid back their loan or not, we would need to follow the evolution of a single loan. To this goal I want to choose one loan among the above and follow its evolution.

# %%
dfi["account_ids"].count()
# Out:
# 1377

# %%
dfi["account_ids"].describe()
# Out:
# count                  1377
# unique                  159
# top       89135780169200000
# freq                     47
# Name: account_ids, dtype: object

# %%
import random 
acc = random.choice(dfi["account_ids"].unique())

# %%
print(acc)
# Out:
# 89136446053700000

# %% [markdown]
# ### I used a = 89136446053700000.

# %%
lna = dfi[dfi["account_ids"]==acc]

# %%
lna.shape
# Out:
# (27, 59)

# %% [markdown]
# ### Let's look at this one account.

# %%
lna.sort_values("trx_stdtime_days_acc", inplace=True)
lna
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#          hh_ids  unique_hhs first_trx_date_hh last_trx_date_hh  \
# 199468  KNBOK42         NaN         14nov2012        24oct2013
# 412526  KNBOK42         NaN         14nov2012        24oct2013
# 412525  KNBOK42         NaN         14nov2012        24oct2013
# 117531  KNBOK42         NaN         14nov2012        24oct2013
# 209484  KNBOK42         NaN         14nov2012        24oct2013
# 46498   KNBOK42         NaN         14nov2012        24oct2013
# 412520  KNBOK42         NaN         14nov2012        24oct2013
# 326108  KNBOK42         NaN         14nov2012        24oct2013
# 207674  KNBOK42         NaN         14nov2012        24oct2013
# 24509   KNBOK42         NaN         14nov2012        24oct2013
# 71936   KNBOK42         NaN         14nov2012        24oct2013
# 312531  KNBOK42         NaN         14nov2012        24oct2013
# 330030  KNBOK42         NaN         14nov2012        24oct2013
# 394024  KNBOK42         NaN         14nov2012        24oct2013
# 328290  KNBOK42         NaN         14nov2012        24oct2013
# 412510  KNBOK42         NaN         14nov2012        24oct2013
# 344082  KNBOK42         NaN         14nov2012        24oct2013
# 412505  KNBOK42         NaN         14nov2012        24oct2013
# 400004  KNBOK42         NaN         14nov2012        24oct2013
# 412502  KNBOK42         NaN         14nov2012        24oct2013
# 29361   KNBOK42         NaN         14nov2012        24oct2013
# 344082  Borrowing, lending, savings or insurance media...          INFGRP
# 412505  Borrowing, lending, savings or insurance media...          INFGRP
# 400004  Borrowing, lending, savings or insurance media...          INFGRP
# 412502  Borrowing, lending, savings or insurance media...          INFGRP
# 29361   Borrowing, lending, savings or insurance media...          INFGRP
# 147334  Borrowing, lending, savings or insurance media...          INFGRP
# 93219   Borrowing, lending, savings or insurance media...          INFGRP
# 189672  Borrowing, lending, savings or insurance media...          INFGRP
# 122044  Borrowing, lending, savings or insurance media...          INFGRP
# 26757   Borrowing, lending, savings or insurance media...          INFGRP
# 8661    Borrowing, lending, savings or insurance media...          INFGRP
#
#        trx_family_desc  trx_type_code                     trx_type_desc  \
# 199468  Informal group           3395  Borrowing from an informal Group
# 412526  Informal group           3395  Borrowing from an informal Group
# 412525  Informal group           3395  Borrowing from an informal Group
# 117531  Informal group           3395  Borrowing from an informal Group
# 209484  Informal group           3395  Borrowing from an informal Group
# 46498   Informal group           3395  Borrowing from an informal Group
# 412520  Informal group           3395  Borrowing from an informal Group
# 326108  Informal group           3395  Borrowing from an informal Group
# 207674  Informal group           3395  Borrowing from an informal Group
# 24509   Informal group           3395  Borrowing from an informal Group
# 71936   Informal group           3395  Borrowing from an informal Group
# 312531  Informal group           3395  Borrowing from an informal Group
# 330030  Informal group           3395  Borrowing from an informal Group
# 394024  Informal group           3395  Borrowing from an informal Group
# 328290  Informal group           3395  Borrowing from an informal Group
# 412510  Informal group           3395  Borrowing from an informal Group
# 344082  Informal group           3395  Borrowing from an informal Group
# 412505  Informal group           3395  Borrowing from an informal Group
# 400004  Informal group           3395  Borrowing from an informal Group
# 412502  Informal group           3395  Borrowing from an informal Group
# 29361   Informal group           3395  Borrowing from an informal Group
# 147334  Informal group           3395  Borrowing from an informal Group
# 93219   Informal group           3395  Borrowing from an informal Group
# 189672  Informal group           3395  Borrowing from an informal Group
# 122044  Informal group           3395  Borrowing from an informal Group
# 26757   Informal group           3395  Borrowing from an informal Group
# 8661    Informal group           3395  Borrowing from an informal Group
#
#                                  trx_prx_purpose  \
# 199468                          2. New borrowing
# 412526                               3. Payments
# 412525                               3. Payments
# 117531                               3. Payments
# 209484                               3. Payments
# 46498                                3. Payments
# 412520                               3. Payments
# 326108                               3. Payments
# 207674                               3. Payments
# 24509                       5. Interest accruing
# 71936                                3. Payments
# 312531                               3. Payments
# 330030                               3. Payments
# 394024                               3. Payments
# 328290                               3. Payments
# 412510                               3. Payments
# 344082                               3. Payments
# 412505                               3. Payments
# 400004                               3. Payments
# 412502                               3. Payments
# 29361                                3. Payments
# 147334                          2. New borrowing
# 93219                           2. New borrowing
# 189672                               3. Payments
# 122044                               3. Payments
# 26757         7. Closing Balance--End of last DQ
# 8661    INCREASE--Unexplained balance adjustment
#
#                           trx_prx_purpose_fd  trx_fee trx_bsheet_direction  \
# 199468  New borrowing on financial liability      0.0             Increase
# 412526      Repayment on financial liability      0.0             Decrease
# 412525      Repayment on financial liability      0.0             Decrease
# 117531      Repayment on financial liability      0.0             Decrease
# 209484      Repayment on financial liability      0.0             Decrease
# Name: trx_stdtime_days_acc, dtype: int64

# %% [markdown]
# ### The loan was inplace for 235 days.
# ###  There is no starting balance but a closing balance.

# %% [markdown]
# ## Let us again check if outflow and inflow all work out.
# ### Inflow and Outflow refers to the individual's standpoint, so it is an outflow when people pay money into the account. Decrease and Increase are about the balance of the account. If the account is a loan, then decrease means that the loan is being payed back. I feel like for loans, Outflows should mostly correspond to decreases. Let's check that.

# %%
lna[(lna["trx_bsheet_direction"]=="Decrease")&(lna["trx_direction"]=="Inflow") ]
# Out:
# Empty DataFrame
# Columns: [hh_ids, unique_hhs, first_trx_date_hh, last_trx_date_hh, tot_hh_daysofobs, tot_hh_monthsofobs, interview_designation, int_date, int_month, int_year, int_yr_mo, first_int_date, account_ids, unique_accnts, m_ids_owner, unique_hm_owner, account_bsheet_desig, account_startclose_balance, account_formal, account_liquid, first_trx_date_acc, last_trx_date_acc, tot_acc_daysofobs, tot_acc_monthsofobs, trx_id, m_ids_trx, trx_date, trx_date2, trx_month, trx_year, trx_yr_mo, trx_dq_round, trx_stdtime_days_hh, trx_stdtime_mnths_hh, trx_stdtime_days_acc, trx_stdtime_mnths_acc, trx_class_code, trx_class_desc, trx_family_code, trx_family_desc, trx_type_code, trx_type_desc, trx_prx_purpose, trx_prx_purpose_fd, trx_fee, trx_bsheet_direction, trx_mode_code, trx_mode_desc, trx_place_incommunity, trx_distance_km, trx_outlet, trx_direction, trx_value_kes, trx_value_usd, ddd_gift, trx_inkind_units, trx_inkind_value_usd, trx_inkind_value_kes, trx_stdtime_mnths_hh_nr]
# Index: []

# %%
lna[(lna["trx_bsheet_direction"]=="Increase")&(lna["trx_direction"]=="Outflow") ]
# Out:
# Empty DataFrame
# Columns: [hh_ids, unique_hhs, first_trx_date_hh, last_trx_date_hh, tot_hh_daysofobs, tot_hh_monthsofobs, interview_designation, int_date, int_month, int_year, int_yr_mo, first_int_date, account_ids, unique_accnts, m_ids_owner, unique_hm_owner, account_bsheet_desig, account_startclose_balance, account_formal, account_liquid, first_trx_date_acc, last_trx_date_acc, tot_acc_daysofobs, tot_acc_monthsofobs, trx_id, m_ids_trx, trx_date, trx_date2, trx_month, trx_year, trx_yr_mo, trx_dq_round, trx_stdtime_days_hh, trx_stdtime_mnths_hh, trx_stdtime_days_acc, trx_stdtime_mnths_acc, trx_class_code, trx_class_desc, trx_family_code, trx_family_desc, trx_type_code, trx_type_desc, trx_prx_purpose, trx_prx_purpose_fd, trx_fee, trx_bsheet_direction, trx_mode_code, trx_mode_desc, trx_place_incommunity, trx_distance_km, trx_outlet, trx_direction, trx_value_kes, trx_value_usd, ddd_gift, trx_inkind_units, trx_inkind_value_usd, trx_inkind_value_kes, trx_stdtime_mnths_hh_nr]
# Index: []

# %%
lna[(lna["trx_bsheet_direction"]=="Decrease")&(lna["trx_direction"]=="Outflow")].shape
# Out:
# (21, 59)

# %%
lna[(lna["trx_bsheet_direction"]=="Increase")&(lna["trx_direction"]=="Inflow") ].shape
# Out:
# (3, 59)

# %% [markdown]
# ### There seem to be a few entries that do not fall into these categories. Let's look at them.

# %%
lna[~(((lna["trx_bsheet_direction"]=="Increase")&(lna["trx_direction"]=="Inflow")) | ((lna["trx_bsheet_direction"]=="Decrease")&(lna["trx_direction"]=="Outflow")))].shape
# Out:
# (3, 59)

# %%
lna[~(((lna["trx_bsheet_direction"]=="Increase")&(lna["trx_direction"]=="Inflow")) | ((lna["trx_bsheet_direction"]=="Decrease")&(lna["trx_direction"]=="Outflow")))]
# Out:
#         hh_ids  unique_hhs first_trx_date_hh last_trx_date_hh  \
# 24509  KNBOK42         NaN         14nov2012        24oct2013
# 26757  KNBOK42         NaN         14nov2012        24oct2013
# 8661   KNBOK42         NaN         14nov2012        24oct2013
#
#        tot_hh_daysofobs  tot_hh_monthsofobs interview_designation   int_date  \
# 24509               344                  11  04=Diaries Interview  23may2013
# 26757               344                  11  04=Diaries Interview  24oct2013
# 8661                344                  11  04=Diaries Interview  24oct2013
#
#        int_month  int_year int_yr_mo first_int_date        account_ids  \
# 24509          5      2013   2013_05      29nov2012  89136446053700000
# 26757         10      2013   2013_10      29nov2012  89136446053700000
# 8661          10      2013   2013_10      29nov2012  89136446053700000
#
#        unique_accnts        m_ids_owner  unique_hm_owner account_bsheet_desig  \
# 24509            NaN  50135417760600000              NaN            Liability
# 26757            NaN  50135417760600000              NaN            Liability
# 8661             NaN  50135417760600000              NaN            Liability
#
#       account_startclose_balance account_formal account_liquid  \
# 24509                        NaN       Informal            NaN
# 26757                      Close       Informal            NaN
# 8661                         NaN       Informal            NaN
#
#       first_trx_date_acc last_trx_date_acc  tot_acc_daysofobs  \
# 24509          03mar2013         24oct2013                235
# 26757          03mar2013         24oct2013                235
# 8661           03mar2013         24oct2013                235
#
#        tot_acc_monthsofobs             trx_id          m_ids_trx   trx_date  \
# 24509                    8  89136929110100000  50135417760600000  19may2013
# 26757                    8  89138259521800000  50135417760600000  24oct2013
# 8661                     8  51140471171800000  50135417760600000  24oct2013
#
#         trx_date2  trx_month  trx_year trx_yr_mo  trx_dq_round  \
# 24509  2013-05-19          5      2013   2013_05          11.0
# 26757  2013-10-24         10      2013   2013_10          22.0
# 8661   2013-10-24         10      2013   2013_10          22.0
#
#        trx_stdtime_days_hh  trx_stdtime_mnths_hh  trx_stdtime_days_acc  \
# 24509                  186                     6                    77
# 26757                  344                    11                   235
# 8661                   344                    11                   235
#
#        trx_stdtime_mnths_acc trx_class_code  \
# 24509                      2         findev
# 26757                      8         findev
# 8661                       8         findev
#
#                                           trx_class_desc trx_family_code  \
# 24509  Borrowing, lending, savings or insurance media...          INFGRP
# 26757  Borrowing, lending, savings or insurance media...          INFGRP
# 8661   Borrowing, lending, savings or insurance media...          INFGRP
#
#       trx_family_desc  trx_type_code                     trx_type_desc  \
# 24509  Informal group           3395  Borrowing from an informal Group
# 26757  Informal group           3395  Borrowing from an informal Group
# 8661   Informal group           3395  Borrowing from an informal Group
#
#                                 trx_prx_purpose trx_prx_purpose_fd  trx_fee  \
# 24509                      5. Interest accruing                NaN      0.0
# 26757        7. Closing Balance--End of last DQ                NaN      0.0
# 8661   INCREASE--Unexplained balance adjustment                NaN      0.0
#
#       trx_bsheet_direction  trx_mode_code    trx_mode_desc  \
# 24509             Increase            1.0             Cash
# 26757                  NaN           19.0  CLOSING BALANCE
# 8661              Increase           19.0  CLOSING BALANCE
#
#        trx_place_incommunity  trx_distance_km trx_outlet trx_direction  \
# 24509                    NaN              NaN        NaN           NaN
# 26757                    1.0              0.0        NaN           NaN
# 8661                     NaN              NaN        NaN           NaN
#
#        trx_value_kes  trx_value_usd  ddd_gift trx_inkind_units  \
# 24509          200.0       2.352941         0              NaN
# 26757            0.0       0.000000         0              NaN
# 8661          1450.0      17.058820         0              NaN
#
#        trx_inkind_value_usd  trx_inkind_value_kes  trx_stdtime_mnths_hh_nr
# 24509                   NaN                   NaN                 6.413793
# 26757                   NaN                   NaN                11.862070
# 8661                    NaN                   NaN                11.862070

# %% [markdown]
# ### So we have no In or outflow for interest accruing, unexplained increase of balance and the closing balance. This all makes sense.
# ### Also there is no increase or decrease of the account balance when the closing balance is recorded.
# ### But there are two different closing balances, that is clear to me.

# %% [markdown]
# ### Now we want to understand the evolution of the balance of a loan account.

# %%
lna.insert(58, "trx_val_dir",np.zeros(lna.shape[0]))

# %%
lna.head(1)
# Out:
#          hh_ids  unique_hhs first_trx_date_hh last_trx_date_hh  \
# 199468  KNBOK42         NaN         14nov2012        24oct2013
#
#         tot_hh_daysofobs  tot_hh_monthsofobs interview_designation   int_date  \
# 199468               344                  11  04=Diaries Interview  14mar2013
#
#         int_month  int_year int_yr_mo first_int_date        account_ids  \
# 199468          3      2013   2013_03      29nov2012  89136446053700000
#
#         unique_accnts        m_ids_owner  unique_hm_owner  \
# 199468            1.0  50135417760600000              NaN
#
#        account_bsheet_desig account_startclose_balance account_formal  \
# 199468            Liability                        NaN       Informal
#
#        account_liquid first_trx_date_acc last_trx_date_acc  tot_acc_daysofobs  \
# 199468            NaN          03mar2013         24oct2013                235
#
#         tot_acc_monthsofobs             trx_id          m_ids_trx   trx_date  \
# 199468                    8  89136446069000000  50135417760600000  03mar2013
#
#          trx_date2  trx_month  trx_year trx_yr_mo  trx_dq_round  \
# 199468  2013-03-03          3      2013   2013_03           6.0
#
#         trx_stdtime_days_hh  trx_stdtime_mnths_hh  trx_stdtime_days_acc  \
# 199468                  109                     3                     0
#
#         trx_stdtime_mnths_acc trx_class_code  \
# 199468                      0         findev
#
#                                            trx_class_desc trx_family_code  \
# 199468  Borrowing, lending, savings or insurance media...          INFGRP
#
#        trx_family_desc  trx_type_code                     trx_type_desc  \
# 199468  Informal group           3395  Borrowing from an informal Group
#
#          trx_prx_purpose                    trx_prx_purpose_fd  trx_fee  \
# 199468  2. New borrowing  New borrowing on financial liability      0.0
#
#        trx_bsheet_direction  trx_mode_code trx_mode_desc  \
# 199468             Increase            1.0          Cash
#
#         trx_place_incommunity  trx_distance_km        trx_outlet  \
# 199468                    1.0              0.0  07=Group meeting
#
#        trx_direction  trx_value_kes  trx_value_usd  ddd_gift trx_inkind_units  \
# 199468        Inflow         2000.0       23.52941         0              NaN
#
#         trx_inkind_value_usd  trx_inkind_value_kes  trx_val_dir  \
# 199468                   NaN                   NaN          0.0
#
#         trx_stdtime_mnths_hh_nr
# 199468                 3.758621

# %%
for index, row in lna.iterrows():
    if lna.loc[index,"trx_bsheet_direction"]=="Increase":
        lna.at[index,"trx_val_dir"] = lna.loc[index,"trx_value_kes"]
    elif lna.loc[index,"trx_bsheet_direction"]=="Decrease":
        lna.at[index,"trx_val_dir"] = -lna.loc[index,"trx_value_kes"]
    else:
        print("Error neither increase nor decrease at index" + str(index))
# Out:
# Error neither increase nor decrease at index26757

# %%
lna[["trx_stdtime_days_acc","trx_value_kes","trx_prx_purpose","trx_direction","trx_bsheet_direction","trx_val_dir"]]
# Out:
#         trx_stdtime_days_acc  trx_value_kes  \
# 199468                     0         2000.0
# 412526                    14          200.0
# 412525                    21          200.0
# 117531                    28          200.0
# 209484                    35          200.0
# 46498                     42          200.0
# 412520                    49          200.0
# 326108                    62          200.0
# 207674                    70          500.0
# 24509                     77          200.0
# 71936                     77          200.0
# 312531                    84          150.0
# 330030                    91          150.0
# 394024                    91          150.0
# 328290                    98          150.0
# 412510                   112          150.0
# 344082                   119          150.0
# 412505                   126          150.0
# 400004                   133          150.0
# 412502                   140          150.0
# 29361                    147          150.0
# 147334                   154          150.0
# 93219                    161          150.0
# 189672                   175          200.0
# 122044                   182          150.0
# 26757                    235            0.0
# 8661                     235         1450.0
#
#                                  trx_prx_purpose trx_direction  \
# 199468                          2. New borrowing        Inflow
# 412526                               3. Payments       Outflow
# 412525                               3. Payments       Outflow
# 117531                               3. Payments       Outflow
# 209484                               3. Payments       Outflow
# 46498                                3. Payments       Outflow
# 412520                               3. Payments       Outflow
# 326108                               3. Payments       Outflow
# 207674                               3. Payments       Outflow
# 24509                       5. Interest accruing           NaN
# 71936                                3. Payments       Outflow
# 312531                               3. Payments       Outflow
# 330030                               3. Payments       Outflow
# 394024                               3. Payments       Outflow
# 328290                               3. Payments       Outflow
# 412510                               3. Payments       Outflow
# 344082                               3. Payments       Outflow
# 412505                               3. Payments       Outflow
# 400004                               3. Payments       Outflow
# 412502                               3. Payments       Outflow
# 29361                                3. Payments       Outflow
# 147334                          2. New borrowing        Inflow
# 93219                           2. New borrowing        Inflow
# 189672                               3. Payments       Outflow
# 122044                               3. Payments       Outflow
# 26757         7. Closing Balance--End of last DQ           NaN
# 8661    INCREASE--Unexplained balance adjustment           NaN
#
#        trx_bsheet_direction  trx_val_dir
# 199468             Increase       2000.0
# 412526             Decrease       -200.0
# 412525             Decrease       -200.0
# 117531             Decrease       -200.0
# 209484             Decrease       -200.0
# 46498              Decrease       -200.0
# 412520             Decrease       -200.0
# 326108             Decrease       -200.0
# 207674             Decrease       -500.0
# 24509              Increase        200.0
# 71936              Decrease       -200.0
# 312531             Decrease       -150.0
# 330030             Decrease       -150.0
# 394024             Decrease       -150.0
# 328290             Decrease       -150.0
# 412510             Decrease       -150.0
# 344082             Decrease       -150.0
# 412505             Decrease       -150.0
# 400004             Decrease       -150.0
# 412502             Decrease       -150.0
# 29361              Decrease       -150.0
# 147334             Increase        150.0
# 93219              Increase        150.0
# 189672             Decrease       -200.0
# 122044             Decrease       -150.0
# 26757                   NaN          0.0
# 8661               Increase       1450.0

# %%
lna.insert(59,"bal_evol",np.zeros(lna.shape[0]))

# %%
s=0
for index,row in lna.iterrows():
    s+=lna.loc[index,"trx_val_dir"]
    lna.at[index,"bal_evol"]=s

# %%
lna[["trx_stdtime_days_acc","trx_value_kes","trx_prx_purpose","trx_direction","trx_bsheet_direction","trx_val_dir","bal_evol"]]
# Out:
#         trx_stdtime_days_acc  trx_value_kes  \
# 199468                     0         2000.0
# 412526                    14          200.0
# 412525                    21          200.0
# 117531                    28          200.0
# 209484                    35          200.0
# 46498                     42          200.0
# 412520                    49          200.0
# 326108                    62          200.0
# 207674                    70          500.0
# 24509                     77          200.0
# 71936                     77          200.0
# 312531                    84          150.0
# 330030                    91          150.0
# 394024                    91          150.0
# 328290                    98          150.0
# 412510                   112          150.0
# 344082                   119          150.0
# 412505                   126          150.0
# 400004                   133          150.0
# 412502                   140          150.0
# 29361                    147          150.0
# 147334                   154          150.0
# 93219                    161          150.0
# 189672                   175          200.0
# 122044                   182          150.0
# 26757                    235            0.0
# 8661                     235         1450.0
#
#                                  trx_prx_purpose trx_direction  \
# 199468                          2. New borrowing        Inflow
# 412526                               3. Payments       Outflow
# 412525                               3. Payments       Outflow
# 117531                               3. Payments       Outflow
# 209484                               3. Payments       Outflow
# 46498                                3. Payments       Outflow
# 412520                               3. Payments       Outflow
# 326108                               3. Payments       Outflow
# 207674                               3. Payments       Outflow
# 24509                       5. Interest accruing           NaN
# 71936                                3. Payments       Outflow
# 312531                               3. Payments       Outflow
# 330030                               3. Payments       Outflow
# 394024                               3. Payments       Outflow
# 328290                               3. Payments       Outflow
# 412510                               3. Payments       Outflow
# 344082                               3. Payments       Outflow
# 412505                               3. Payments       Outflow
# 400004                               3. Payments       Outflow
# 412502                               3. Payments       Outflow
# 29361                                3. Payments       Outflow
# 147334                          2. New borrowing        Inflow
# 93219                           2. New borrowing        Inflow
# 189672                               3. Payments       Outflow
# 122044                               3. Payments       Outflow
# 26757         7. Closing Balance--End of last DQ           NaN
# 8661    INCREASE--Unexplained balance adjustment           NaN
#
#        trx_bsheet_direction  trx_val_dir  bal_evol
# 199468             Increase       2000.0    2000.0
# 412526             Decrease       -200.0    1800.0
# 412525             Decrease       -200.0    1600.0
# 117531             Decrease       -200.0    1400.0
# 209484             Decrease       -200.0    1200.0
# 46498              Decrease       -200.0    1000.0
# 412520             Decrease       -200.0     800.0
# 326108             Decrease       -200.0     600.0
# 207674             Decrease       -500.0     100.0
# 24509              Increase        200.0     300.0
# 71936              Decrease       -200.0     100.0
# 312531             Decrease       -150.0     -50.0
# 330030             Decrease       -150.0    -200.0
# 394024             Decrease       -150.0    -350.0
# 328290             Decrease       -150.0    -500.0
# 412510             Decrease       -150.0    -650.0
# 344082             Decrease       -150.0    -800.0
# 412505             Decrease       -150.0    -950.0
# 400004             Decrease       -150.0   -1100.0
# 412502             Decrease       -150.0   -1250.0
# 29361              Decrease       -150.0   -1400.0
# 147334             Increase        150.0   -1250.0
# 93219              Increase        150.0   -1100.0
# 189672             Decrease       -200.0   -1300.0
# 122044             Decrease       -150.0   -1450.0
# 26757                   NaN          0.0   -1450.0
# 8661               Increase       1450.0       0.0

# %%
lna.plot(x="trx_stdtime_days_acc",y="bal_evol")

# %% [markdown]
# ## This loan seems to be a bit misterious. First they take a loan, then they continue paying into the loan, eventhough they apparently finished paying it back.

# %% [markdown]
# ## Let's look at the evolution of the balance of a different account.

# %%
a = random.choice(dfi["account_ids"].unique())
print(a)
# Out:
# 89135910908900000

# %% [markdown]
# ### I used a = 89135910908900000.

# %%
lna = dfi[dfi["account_ids"]==a]

# %%
lna.shape
# Out:
# (11, 59)

# %% [markdown]
# ### Let's look at this one account.

# %%
lna.sort_values("trx_stdtime_days_acc", inplace=True)
lna
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#          hh_ids  unique_hhs first_trx_date_hh last_trx_date_hh  \
# 5566    KNBOK03         NaN         01nov2012        22oct2013
# 334199  KNBOK03         NaN         01nov2012        22oct2013
# 179026  KNBOK03         NaN         01nov2012        22oct2013
# 274867  KNBOK03         NaN         01nov2012        22oct2013
# 378952  KNBOK03         NaN         01nov2012        22oct2013
# 280362  KNBOK03         NaN         01nov2012        22oct2013
# 306980  KNBOK03         NaN         01nov2012        22oct2013
# 407639  KNBOK03         NaN         01nov2012        22oct2013
# 149134  KNBOK03         NaN         01nov2012        22oct2013
# 203370  KNBOK03         NaN         01nov2012        22oct2013
# 12887   KNBOK03         NaN         01nov2012        22oct2013
#
#         tot_hh_daysofobs  tot_hh_monthsofobs  interview_designation  \
# 5566                 355                  12   04=Diaries Interview
# 334199               355                  12   04=Diaries Interview
# 179026               355                  12  06=Cleaning interview
# 274867               355                  12  06=Cleaning interview
# 378952               355                  12  06=Cleaning interview
# 280362               355                  12  06=Cleaning interview
# 306980               355                  12  06=Cleaning interview
# 407639               355                  12  06=Cleaning interview
# 149134               355                  12   04=Diaries Interview
# 203370               355                  12   04=Diaries Interview
# 12887                355                  12   04=Diaries Interview
#
#          int_date  int_month  int_year int_yr_mo first_int_date  \
# 5566    27mar2013          3      2013   2013_03      21nov2012
# 334199  27mar2013          3      2013   2013_03      21nov2012
# 179026  23oct2013         10      2013   2013_10      21nov2012
# 274867  23oct2013         10      2013   2013_10      21nov2012
# 378952  23oct2013         10      2013   2013_10      21nov2012
# 280362  23oct2013         10      2013   2013_10      21nov2012
# 306980  23oct2013         10      2013   2013_10      21nov2012
# 407639  23oct2013         10      2013   2013_10      21nov2012
# 149134  08oct2013         10      2013   2013_10      21nov2012
# 203370  22oct2013         10      2013   2013_10      21nov2012
# 12887   22oct2013         10      2013   2013_10      21nov2012
#
#               account_ids  unique_accnts        m_ids_owner  unique_hm_owner  \
# 5566    89135910908900000            1.0  64134408292500000              NaN
# 334199  89135910908900000            NaN  64134408292500000              NaN
# 179026  89135910908900000            NaN  64134408292500000              NaN
# 274867  89135910908900000            NaN  64134408292500000              NaN
# 378952  89135910908900000            NaN  64134408292500000              NaN
# 280362  89135910908900000            NaN  64134408292500000              NaN
# 306980  89135910908900000            NaN  64134408292500000              NaN
# 407639  89135910908900000            NaN  64134408292500000              NaN
# 149134  89135910908900000            NaN  64134408292500000              NaN
# 203370  89135910908900000            NaN  64134408292500000              NaN
# 5566    Borrowing, lending, savings or insurance media...          INFGRP
# 334199  Borrowing, lending, savings or insurance media...          INFGRP
# 179026  Borrowing, lending, savings or insurance media...          INFGRP
# 274867  Borrowing, lending, savings or insurance media...          INFGRP
# 378952  Borrowing, lending, savings or insurance media...          INFGRP
# 280362  Borrowing, lending, savings or insurance media...          INFGRP
# 306980  Borrowing, lending, savings or insurance media...          INFGRP
# 407639  Borrowing, lending, savings or insurance media...          INFGRP
# 149134  Borrowing, lending, savings or insurance media...          INFGRP
# 203370  Borrowing, lending, savings or insurance media...          INFGRP
# 12887   Borrowing, lending, savings or insurance media...          INFGRP
#
#        trx_family_desc  trx_type_code                     trx_type_desc  \
# 5566    Informal group           3395  Borrowing from an informal Group
# 334199  Informal group           3395  Borrowing from an informal Group
# 179026  Informal group           3395  Borrowing from an informal Group
# 274867  Informal group           3395  Borrowing from an informal Group
# 378952  Informal group           3395  Borrowing from an informal Group
# 280362  Informal group           3395  Borrowing from an informal Group
# 306980  Informal group           3395  Borrowing from an informal Group
# 407639  Informal group           3395  Borrowing from an informal Group
# 149134  Informal group           3395  Borrowing from an informal Group
# 203370  Informal group           3395  Borrowing from an informal Group
# 12887   Informal group           3395  Borrowing from an informal Group
#
#                            trx_prx_purpose                trx_prx_purpose_fd  \
# 5566           1. Starting balance (today)                               NaN
# 334199                         3. Payments  Repayment on financial liability
# 179026                         3. Payments  Repayment on financial liability
# 274867                         3. Payments  Repayment on financial liability
# 378952                         3. Payments  Repayment on financial liability
# 280362                         3. Payments  Repayment on financial liability
# 306980                         3. Payments  Repayment on financial liability
# 407639                         3. Payments  Repayment on financial liability
# 149134                         3. Payments  Repayment on financial liability
# 203370                         3. Payments  Repayment on financial liability
# 12887   7. Closing Balance--End of last DQ                               NaN
#
#         trx_fee trx_bsheet_direction  trx_mode_code     trx_mode_desc  \
# 5566        0.0             Increase           18.0  STARTING BALANCE
# 334199      0.0             Decrease            1.0              Cash
# 179026      0.0             Decrease            1.0              Cash
# 274867      0.0             Decrease            1.0              Cash
# 378952      0.0             Decrease            1.0              Cash
# 280362      0.0             Decrease            1.0              Cash
# 306980      0.0             Decrease            1.0              Cash
# 407639      0.0             Decrease            1.0              Cash
# 149134      0.0             Decrease            1.0              Cash
# 203370      0.0             Decrease            1.0              Cash
# 12887       0.0                  NaN           19.0   CLOSING BALANCE
#
#         trx_place_incommunity  trx_distance_km  \
# 5566                      NaN              NaN
# 334199                    1.0              0.0
# 179026                    1.0              0.0
# 274867                    1.0              0.0
# 378952                    1.0              0.0
# 280362                    1.0              0.0
# 306980                    1.0              0.0
# 407639                    1.0              0.0
# 149134                    1.0              0.0
# 203370                    1.0              0.0
# 12887                     NaN              NaN
#
#                                 trx_outlet trx_direction  trx_value_kes  \
# 5566                                   NaN           NaN        30000.0
# 334199                    07=Group meeting       Outflow         3000.0
# 179026                    07=Group meeting       Outflow         2000.0
# 274867                    07=Group meeting       Outflow         2000.0
# 378952                    07=Group meeting       Outflow         2000.0
# 280362                    07=Group meeting       Outflow         2000.0
# 306980                    07=Group meeting       Outflow         2000.0
# 407639                    07=Group meeting       Outflow         2000.0
# 149134                    07=Group meeting       Outflow         2000.0
# 203370  13=Private individual or household       Outflow         3000.0
# 12887                                  NaN           NaN        10000.0
#
#         trx_value_usd  ddd_gift trx_inkind_units  trx_inkind_value_usd  \
# 5566        352.94120         0              NaN                   NaN
# 334199       35.29412         0              NaN                   NaN
# 179026       23.52941         0              NaN                   NaN
# 274867       23.52941         0              NaN                   NaN
# 378952       23.52941         0              NaN                   NaN
# 280362       23.52941         0              NaN                   NaN
# 306980       23.52941         0              NaN                   NaN
# 407639       23.52941         0              NaN                   NaN
# 149134       23.52941         0              NaN                   NaN
# 203370       35.29412         0              NaN                   NaN
# 12887       117.64710         0              NaN                   NaN
#
#         trx_inkind_value_kes  trx_stdtime_mnths_hh_nr
# 5566                     NaN                 4.517241
# 334199                   NaN                 4.586207
# 179026                   NaN                 5.551724
# 274867                   NaN                 6.517241
# 378952                   NaN                 7.724138
# 280362                   NaN                 8.689655
# 306980                   NaN                 9.655172
# 407639                   NaN                10.862070
# 149134                   NaN                11.586210
# 203370                   NaN                11.862070
# 12887                    NaN                12.241380

# %%
lna.insert(58, "trx_val_dir",np.zeros(lna.shape[0]))

# %%
for index, row in lna.iterrows():
    if lna.loc[index,"trx_bsheet_direction"]=="Increase":
        lna.at[index,"trx_val_dir"] = lna.loc[index,"trx_value_kes"]
    elif lna.loc[index,"trx_bsheet_direction"]=="Decrease":
        lna.at[index,"trx_val_dir"] = -lna.loc[index,"trx_value_kes"]
    else:
        print("Error neither increase nor decrease at index" + str(index))
# Out:
# Error neither increase nor decrease at index12887

# %%
lna[["trx_stdtime_days_acc","trx_value_kes","trx_prx_purpose","trx_direction","trx_bsheet_direction","trx_val_dir"]]
# Out:
#         trx_stdtime_days_acc  trx_value_kes  \
# 5566                       0        30000.0
# 334199                     2         3000.0
# 179026                    30         2000.0
# 274867                    58         2000.0
# 378952                    93         2000.0
# 280362                   121         2000.0
# 306980                   149         2000.0
# 407639                   184         2000.0
# 149134                   205         2000.0
# 203370                   213         3000.0
# 12887                    224        10000.0
#
#                            trx_prx_purpose trx_direction trx_bsheet_direction  \
# 5566           1. Starting balance (today)           NaN             Increase
# 334199                         3. Payments       Outflow             Decrease
# 179026                         3. Payments       Outflow             Decrease
# 274867                         3. Payments       Outflow             Decrease
# 378952                         3. Payments       Outflow             Decrease
# 280362                         3. Payments       Outflow             Decrease
# 306980                         3. Payments       Outflow             Decrease
# 407639                         3. Payments       Outflow             Decrease
# 149134                         3. Payments       Outflow             Decrease
# 203370                         3. Payments       Outflow             Decrease
# 12887   7. Closing Balance--End of last DQ           NaN                  NaN
#
#         trx_val_dir
# 5566        30000.0
# 334199      -3000.0
# 179026      -2000.0
# 274867      -2000.0
# 378952      -2000.0
# 280362      -2000.0
# 306980      -2000.0
# 407639      -2000.0
# 149134      -2000.0
# 203370      -3000.0
# 12887           0.0

# %%
lna.insert(59,"bal_evol",np.zeros(lna.shape[0]))

# %%
s=0
for index,row in lna.iterrows():
    s+=lna.loc[index,"trx_val_dir"]
    lna.at[index,"bal_evol"]=s

# %%
lna[["trx_stdtime_days_acc","trx_value_kes","trx_prx_purpose","trx_direction","trx_bsheet_direction","trx_val_dir","bal_evol"]]
# Out:
#         trx_stdtime_days_acc  trx_value_kes  \
# 5566                       0        30000.0
# 334199                     2         3000.0
# 179026                    30         2000.0
# 274867                    58         2000.0
# 378952                    93         2000.0
# 280362                   121         2000.0
# 306980                   149         2000.0
# 407639                   184         2000.0
# 149134                   205         2000.0
# 203370                   213         3000.0
# 12887                    224        10000.0
#
#                            trx_prx_purpose trx_direction trx_bsheet_direction  \
# 5566           1. Starting balance (today)           NaN             Increase
# 334199                         3. Payments       Outflow             Decrease
# 179026                         3. Payments       Outflow             Decrease
# 274867                         3. Payments       Outflow             Decrease
# 378952                         3. Payments       Outflow             Decrease
# 280362                         3. Payments       Outflow             Decrease
# 306980                         3. Payments       Outflow             Decrease
# 407639                         3. Payments       Outflow             Decrease
# 149134                         3. Payments       Outflow             Decrease
# 203370                         3. Payments       Outflow             Decrease
# 12887   7. Closing Balance--End of last DQ           NaN                  NaN
#
#         trx_val_dir  bal_evol
# 5566        30000.0   30000.0
# 334199      -3000.0   27000.0
# 179026      -2000.0   25000.0
# 274867      -2000.0   23000.0
# 378952      -2000.0   21000.0
# 280362      -2000.0   19000.0
# 306980      -2000.0   17000.0
# 407639      -2000.0   15000.0
# 149134      -2000.0   13000.0
# 203370      -3000.0   10000.0
# 12887           0.0   10000.0

# %%
lna.plot(x="trx_stdtime_days_acc",y="bal_evol")

# %% [markdown]
# ## Let's look at the evolution of the balance of a different account.

# %%
a = random.choice(dfi["account_ids"].unique())
print(a)
# Out:
# 59134856295000000

# %% [markdown]
# ### I used a = 59134856295000000.

# %%
lna = dfi[dfi["account_ids"]==a]

# %%
lna.shape
# Out:
# (8, 59)

# %% [markdown]
# ### Let's look at this one account.

# %%
lna.sort_values("trx_stdtime_days_acc", inplace=True)
lna
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#          hh_ids  unique_hhs first_trx_date_hh last_trx_date_hh  \
# 15160   KVIHC36         NaN         08sep2012        30sep2013
# 12029   KVIHC36         NaN         08sep2012        30sep2013
# 140303  KVIHC36         NaN         08sep2012        30sep2013
# 136647  KVIHC36         NaN         08sep2012        30sep2013
# 406920  KVIHC36         NaN         08sep2012        30sep2013
# 249721  KVIHC36         NaN         08sep2012        30sep2013
# 70038   KVIHC36         NaN         08sep2012        30sep2013
# 10511   KVIHC36         NaN         08sep2012        30sep2013
#
#         tot_hh_daysofobs  tot_hh_monthsofobs  interview_designation  \
# 15160                387                  13   04=Diaries Interview
# 12029                387                  13  06=Cleaning interview
# 140303               387                  13   04=Diaries Interview
# 136647               387                  13   04=Diaries Interview
# 406920               387                  13   04=Diaries Interview
# 249721               387                  13  06=Cleaning interview
# 70038                387                  13  06=Cleaning interview
# 10511                387                  13   04=Diaries Interview
#
#          int_date  int_month  int_year int_yr_mo first_int_date  \
# 15160   02nov2012         11      2012   2012_11      27aug2012
# 12029   26sep2013          9      2013   2013_09      27aug2012
# 140303  15jan2013          1      2013   2013_01      27aug2012
# 15160   Borrowing, lending, savings or insurance media...          INFGRP
# 12029   Borrowing, lending, savings or insurance media...          INFGRP
# 140303  Borrowing, lending, savings or insurance media...          INFGRP
# 136647  Borrowing, lending, savings or insurance media...          INFGRP
# 406920  Borrowing, lending, savings or insurance media...          INFGRP
# 249721  Borrowing, lending, savings or insurance media...          INFGRP
# 70038   Borrowing, lending, savings or insurance media...          INFGRP
# 10511   Borrowing, lending, savings or insurance media...          INFGRP
#
#        trx_family_desc  trx_type_code                     trx_type_desc  \
# 15160   Informal group           3395  Borrowing from an informal Group
# 12029   Informal group           3395  Borrowing from an informal Group
# 140303  Informal group           3395  Borrowing from an informal Group
# 136647  Informal group           3395  Borrowing from an informal Group
# 406920  Informal group           3395  Borrowing from an informal Group
# 249721  Informal group           3395  Borrowing from an informal Group
# 70038   Informal group           3395  Borrowing from an informal Group
# 10511   Informal group           3395  Borrowing from an informal Group
#
#                            trx_prx_purpose  \
# 15160          1. Starting balance (today)
# 12029                 5. Interest accruing
# 140303                         3. Payments
# 136647                    2. New borrowing
# 406920                         3. Payments
# 249721                         3. Payments
# 70038                          3. Payments
# 10511   7. Closing Balance--End of last DQ
#
#                           trx_prx_purpose_fd  trx_fee trx_bsheet_direction  \
# 15160                                    NaN      0.0             Increase
# 12029                                    NaN      0.0             Increase
# 140303      Repayment on financial liability      0.0             Decrease
# 136647  New borrowing on financial liability      0.0             Increase
# 406920      Repayment on financial liability      0.0             Decrease
# 249721      Repayment on financial liability      0.0             Decrease
# 70038       Repayment on financial liability      0.0             Decrease
# 10511                                    NaN      0.0                  NaN
#
#         trx_mode_code     trx_mode_desc  trx_place_incommunity  \
# 15160            18.0  STARTING BALANCE                    NaN
# 12029             1.0              Cash                    NaN
# 140303            1.0              Cash                    1.0
# 136647            1.0              Cash                    1.0
# 406920            1.0              Cash                    1.0
# 249721            1.0              Cash                    1.0
# 70038             1.0              Cash                    1.0
# 10511            19.0   CLOSING BALANCE                    NaN
#
#         trx_distance_km        trx_outlet trx_direction  trx_value_kes  \
# 15160               NaN               NaN           NaN         3000.0
# 12029               NaN               NaN           NaN         5200.0
# 140303              0.0  07=Group meeting       Outflow         3200.0
# 136647              0.0  07=Group meeting        Inflow         3000.0
# 406920              0.0  07=Group meeting       Outflow          600.0
# 249721              0.0  07=Group meeting       Outflow         1000.0
# 70038               0.0  07=Group meeting       Outflow         1000.0
# 10511               NaN               NaN           NaN         5200.0
#
#         trx_value_usd  ddd_gift trx_inkind_units  trx_inkind_value_usd  \
# 15160       35.294120         0              NaN                   NaN
# 12029       61.176470         0              NaN                   NaN
# 140303      37.647060         0              NaN                   NaN
# 136647      35.294120         0              NaN                   NaN
# 406920       7.058824         0              NaN                   NaN
# 249721      11.764710         0              NaN                   NaN
# 70038       11.764710         0              NaN                   NaN
# 10511       61.176470         0              NaN                   NaN
#
#         trx_inkind_value_kes  trx_stdtime_mnths_hh_nr
# 15160                    NaN                 1.896552
# 12029                    NaN                 1.965517
# 140303                   NaN                 3.241379
# 136647                   NaN                 6.344828
# 406920                   NaN                 6.344828
# 249721                   NaN                 9.413794
# 70038                    NaN                12.586210
# 10511                    NaN                13.172410

# %%
lna.insert(58, "trx_val_dir",np.zeros(lna.shape[0]))

# %%
for index, row in lna.iterrows():
    if lna.loc[index,"trx_bsheet_direction"]=="Increase":
        lna.at[index,"trx_val_dir"] = lna.loc[index,"trx_value_kes"]
    elif lna.loc[index,"trx_bsheet_direction"]=="Decrease":
        lna.at[index,"trx_val_dir"] = -lna.loc[index,"trx_value_kes"]
    else:
        print("Error neither increase nor decrease at index " + str(index)+".")
# Out:
# Error neither increase nor decrease at index 10511.

# %%
lna[["trx_stdtime_days_acc","trx_value_kes","trx_prx_purpose","trx_direction","trx_bsheet_direction","trx_val_dir","trx_date2"]]
# Out:
#         trx_stdtime_days_acc  trx_value_kes  \
# 15160                      0         3000.0
# 12029                      2         5200.0
# 140303                    39         3200.0
# 136647                   129         3000.0
# 406920                   129          600.0
# 249721                   218         1000.0
# 70038                    310         1000.0
# 10511                    327         5200.0
#
#                            trx_prx_purpose trx_direction trx_bsheet_direction  \
# 15160          1. Starting balance (today)           NaN             Increase
# 12029                 5. Interest accruing           NaN             Increase
# 140303                         3. Payments       Outflow             Decrease
# 136647                    2. New borrowing        Inflow             Increase
# 406920                         3. Payments       Outflow             Decrease
# 249721                         3. Payments       Outflow             Decrease
# 70038                          3. Payments       Outflow             Decrease
# 10511   7. Closing Balance--End of last DQ           NaN                  NaN
#
#         trx_val_dir   trx_date2
# 15160        3000.0  2012-11-02
# 12029        5200.0  2012-11-04
# 140303      -3200.0  2012-12-11
# 136647       3000.0  2013-03-11
# 406920       -600.0  2013-03-11
# 249721      -1000.0  2013-06-08
# 70038       -1000.0  2013-09-08
# 10511           0.0  2013-09-25

# %%
lna.insert(59,"bal_evol",np.zeros(lna.shape[0]))

# %%
s=0
for index,row in lna.iterrows():
    s+=lna.loc[index,"trx_val_dir"]
    lna.at[index,"bal_evol"]=s

# %%
lna[["trx_stdtime_days_acc","trx_value_kes","trx_prx_purpose","trx_direction","trx_bsheet_direction","trx_val_dir","bal_evol"]]
# Out:
#         trx_stdtime_days_acc  trx_value_kes  \
# 15160                      0         3000.0
# 12029                      2         5200.0
# 140303                    39         3200.0
# 136647                   129         3000.0
# 406920                   129          600.0
# 249721                   218         1000.0
# 70038                    310         1000.0
# 10511                    327         5200.0
#
#                            trx_prx_purpose trx_direction trx_bsheet_direction  \
# 15160          1. Starting balance (today)           NaN             Increase
# 12029                 5. Interest accruing           NaN             Increase
# 140303                         3. Payments       Outflow             Decrease
# 136647                    2. New borrowing        Inflow             Increase
# 406920                         3. Payments       Outflow             Decrease
# 249721                         3. Payments       Outflow             Decrease
# 70038                          3. Payments       Outflow             Decrease
# 10511   7. Closing Balance--End of last DQ           NaN                  NaN
#
#         trx_val_dir  bal_evol
# 15160        3000.0    3000.0
# 12029        5200.0    8200.0
# 140303      -3200.0    5000.0
# 136647       3000.0    8000.0
# 406920       -600.0    7400.0
# 249721      -1000.0    6400.0
# 70038       -1000.0    5400.0
# 10511           0.0    5400.0

# %%
lna.plot(x="trx_stdtime_days_acc",y="bal_evol")

# %% [markdown]
# ## Let's look at the evolution of the balance of a different account.

# %%
a = random.choice(dfi["account_ids"].unique())
print(a)
# Out:
# 105137101304000000

# %% [markdown]
# ### I used a = 105137101304000000.

# %%
lna = dfi[dfi["account_ids"]==a]

# %%
lna.shape
# Out:
# (7, 59)

# %% [markdown]
# ### Let's look at this one account.

# %%
lna.sort_values("trx_stdtime_days_acc", inplace=True)
lna
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#          hh_ids  unique_hhs first_trx_date_hh last_trx_date_hh  \
# 201726  KELDK09         NaN         07sep2012        02oct2013
# 203404  KELDK09         NaN         07sep2012        02oct2013
# 322738  KELDK09         NaN         07sep2012        02oct2013
# 384189  KELDK09         NaN         07sep2012        02oct2013
# 311367  KELDK09         NaN         07sep2012        02oct2013
# 386346  KELDK09         NaN         07sep2012        02oct2013
# 1780    KELDK09         NaN         07sep2012        02oct2013
#
#         tot_hh_daysofobs  tot_hh_monthsofobs interview_designation   int_date  \
# 201726               390                  13  04=Diaries Interview  12jun2013
# 203404               390                  13  04=Diaries Interview  26jun2013
# 322738               390                  13  04=Diaries Interview  24jul2013
# 384189               390                  13  04=Diaries Interview  07aug2013
# 311367               390                  13  04=Diaries Interview  21aug2013
# 386346               390                  13  04=Diaries Interview  04sep2013
# 1780                 390                  13  04=Diaries Interview  02oct2013
#
#         int_month  int_year int_yr_mo first_int_date         account_ids  \
# 201726          6      2013   2013_06      26jul2012  105137101304000000
# 203404          6      2013   2013_06      26jul2012  105137101304000000
# 322738          7      2013   2013_07      26jul2012  105137101304000000
# 384189          8      2013   2013_08      26jul2012  105137101304000000
# 311367          8      2013   2013_08      26jul2012  105137101304000000
# 386346          9      2013   2013_09      26jul2012  105137101304000000
# 1780           10      2013   2013_10      26jul2012  105137101304000000
#
#         unique_accnts        m_ids_owner  unique_hm_owner  \
# 201726            1.0  56134329944600000              NaN
# 203404            NaN  56134329944600000              NaN
# 322738            NaN  56134329944600000              NaN
# 384189            NaN  56134329944600000              NaN
# 311367            NaN  56134329944600000              NaN
# 386346            NaN  56134329944600000              NaN
# 1780              NaN  56134329944600000              NaN
#
#        account_bsheet_desig account_startclose_balance account_formal  \
# 201726            Liability                        NaN       Informal
# 203404            Liability                        NaN       Informal
# 322738            Liability                        NaN       Informal
# 384189            Liability                        NaN       Informal
# 311367            Liability                        NaN       Informal
# 386346            Liability                        NaN       Informal
# 1780              Liability                      Close       Informal
#
#        account_liquid first_trx_date_acc last_trx_date_acc  tot_acc_daysofobs  \
# 201726            NaN          31may2013         02oct2013                124
# 203404            NaN          31may2013         02oct2013                124
# 322738            NaN          31may2013         02oct2013                124
# 384189            NaN          31may2013         02oct2013                124
# 311367            NaN          31may2013         02oct2013                124
# 386346            NaN          31may2013         02oct2013                124
# 1780              NaN          31may2013         02oct2013                124
#
#         tot_acc_monthsofobs              trx_id          m_ids_trx   trx_date  \
# 201726                    4  105137101323300000  56134329944600000  31may2013
# 203404                    4  105137222070000000  56134329944600000  21jun2013
# 322738                    4  105137463896500000  56134329944600000  19jul2013
# 384189                    4  105137585066400000  56134329944600000  02aug2013
# 311367                    4  105137705877500000  56134329944600000  09aug2013
# 386346                    4  105137827244100000  56134329944600000  23aug2013
# 1780                      4  105138068673000000  56134329944600000  02oct2013
#
#          trx_date2  trx_month  trx_year trx_yr_mo  trx_dq_round  \
# 201726  2013-05-31          5      2013   2013_05          11.0
# 203404  2013-06-21          6      2013   2013_06          12.0
# 322738  2013-07-19          7      2013   2013_07          14.0
# 384189  2013-08-02          8      2013   2013_08          15.0
# 311367  2013-08-09          8      2013   2013_08          16.0
# 386346  2013-08-23          8      2013   2013_08          17.0
# 1780    2013-10-02         10      2013   2013_10          19.0
#
#         trx_stdtime_days_hh  trx_stdtime_mnths_hh  trx_stdtime_days_acc  \
# 201726                  266                     9                     0
# 203404                  287                     9                    21
# 322738                  315                    10                    49
# 384189                  329                    11                    63
# 311367                  336                    11                    70
# 386346                  350                    12                    84
# 1780                    390                    13                   124
#
#         trx_stdtime_mnths_acc trx_class_code  \
# 201726                      0         findev
# 203404                      0         findev
# 322738                      1         findev
# 384189                      2         findev
# 311367                      2         findev
# 386346                      2         findev
# 1780                        4         findev
#
#                                            trx_class_desc trx_family_code  \
# 201726  Borrowing, lending, savings or insurance media...          INFGRP
# 203404  Borrowing, lending, savings or insurance media...          INFGRP
# 322738  Borrowing, lending, savings or insurance media...          INFGRP
# 384189  Borrowing, lending, savings or insurance media...          INFGRP
# 311367  Borrowing, lending, savings or insurance media...          INFGRP
# 386346  Borrowing, lending, savings or insurance media...          INFGRP
# 1780    Borrowing, lending, savings or insurance media...          INFGRP
#
#        trx_family_desc  trx_type_code                     trx_type_desc  \
# 201726  Informal group           3395  Borrowing from an informal Group
# 203404  Informal group           3395  Borrowing from an informal Group
# 322738  Informal group           3395  Borrowing from an informal Group
# 384189  Informal group           3395  Borrowing from an informal Group
# 311367  Informal group           3395  Borrowing from an informal Group
# 386346  Informal group           3395  Borrowing from an informal Group
# 1780    Informal group           3395  Borrowing from an informal Group
#
#                            trx_prx_purpose  \
# 201726                    2. New borrowing
# 203404                         3. Payments
# 322738                    2. New borrowing
# 384189                         3. Payments
# 311367                    2. New borrowing
# 386346                         3. Payments
# 1780    7. Closing Balance--End of last DQ
#
#                           trx_prx_purpose_fd  trx_fee trx_bsheet_direction  \
# 201726  New borrowing on financial liability      0.0             Increase
# 203404      Repayment on financial liability      0.0             Decrease
# 322738  New borrowing on financial liability      0.0             Increase
# 384189      Repayment on financial liability      0.0             Decrease
# 311367  New borrowing on financial liability      0.0             Increase
# 386346      Repayment on financial liability      0.0             Decrease
# 1780                                     NaN      0.0                  NaN
#
#         trx_mode_code    trx_mode_desc  trx_place_incommunity  \
# 201726            1.0             Cash                    1.0
# 203404            1.0             Cash                    1.0
# 322738            1.0             Cash                    1.0
# 384189            1.0             Cash                    1.0
# 311367            1.0             Cash                    1.0
# 386346            1.0             Cash                    1.0
# 1780             19.0  CLOSING BALANCE                    NaN
#
#         trx_distance_km        trx_outlet trx_direction  trx_value_kes  \
# 201726              0.0  07=Group meeting        Inflow         1500.0
# 203404              0.0  07=Group meeting       Outflow         1500.0
# 322738              0.0  07=Group meeting        Inflow         1500.0
# 384189              0.0  07=Group meeting       Outflow         1500.0
# 311367              0.0  07=Group meeting        Inflow          500.0
# 386346              0.0  07=Group meeting       Outflow          500.0
# 1780                NaN               NaN           NaN            0.0
#
#         trx_value_usd  ddd_gift trx_inkind_units  trx_inkind_value_usd  \
# 201726      17.647060         0              NaN                   NaN
# 203404      17.647060         0              NaN                   NaN
# 322738      17.647060         0              NaN                   NaN
# 384189      17.647060         0              NaN                   NaN
# 311367       5.882353         0              NaN                   NaN
# 386346       5.882353         0              NaN                   NaN
# 1780         0.000000         0              NaN                   NaN
#
#         trx_inkind_value_kes  trx_stdtime_mnths_hh_nr
# 201726                   NaN                 9.172414
# 203404                   NaN                 9.896552
# 322738                   NaN                10.862070
# 384189                   NaN                11.344830
# 311367                   NaN                11.586210
# 386346                   NaN                12.068970
# 1780                     NaN                13.448280

# %%
lna.insert(58, "trx_val_dir",np.zeros(lna.shape[0]))

# %%
for index, row in lna.iterrows():
    if lna.loc[index,"trx_bsheet_direction"]=="Increase":
        lna.at[index,"trx_val_dir"] = lna.loc[index,"trx_value_kes"]
    elif lna.loc[index,"trx_bsheet_direction"]=="Decrease":
        lna.at[index,"trx_val_dir"] = -lna.loc[index,"trx_value_kes"]
    else:
        print("Error neither increase nor decrease at index " + str(index)+".")
# Out:
# Error neither increase nor decrease at index 1780.

# %%
lna[["trx_stdtime_days_acc","trx_value_kes","trx_prx_purpose","trx_direction","trx_bsheet_direction","trx_val_dir","trx_date2"]]
# Out:
#         trx_stdtime_days_acc  trx_value_kes  \
# 201726                     0         1500.0
# 203404                    21         1500.0
# 322738                    49         1500.0
# 384189                    63         1500.0
# 311367                    70          500.0
# 386346                    84          500.0
# 1780                     124            0.0
#
#                            trx_prx_purpose trx_direction trx_bsheet_direction  \
# 201726                    2. New borrowing        Inflow             Increase
# 203404                         3. Payments       Outflow             Decrease
# 322738                    2. New borrowing        Inflow             Increase
# 384189                         3. Payments       Outflow             Decrease
# 311367                    2. New borrowing        Inflow             Increase
# 386346                         3. Payments       Outflow             Decrease
# 1780    7. Closing Balance--End of last DQ           NaN                  NaN
#
#         trx_val_dir   trx_date2
# 201726       1500.0  2013-05-31
# 203404      -1500.0  2013-06-21
# 322738       1500.0  2013-07-19
# 384189      -1500.0  2013-08-02
# 311367        500.0  2013-08-09
# 386346       -500.0  2013-08-23
# 1780            0.0  2013-10-02

# %%
lna.insert(59,"bal_evol",np.zeros(lna.shape[0]))

# %%
s=0
for index,row in lna.iterrows():
    s+=lna.loc[index,"trx_val_dir"]
    lna.at[index,"bal_evol"]=s

# %%
lna[["trx_stdtime_days_acc","trx_value_kes","trx_prx_purpose","trx_direction","trx_bsheet_direction","trx_val_dir","bal_evol"]]
# Out:
#         trx_stdtime_days_acc  trx_value_kes  \
# 201726                     0         1500.0
# 203404                    21         1500.0
# 322738                    49         1500.0
# 384189                    63         1500.0
# 311367                    70          500.0
# 386346                    84          500.0
# 1780                     124            0.0
#
#                            trx_prx_purpose trx_direction trx_bsheet_direction  \
# 201726                    2. New borrowing        Inflow             Increase
# 203404                         3. Payments       Outflow             Decrease
# 322738                    2. New borrowing        Inflow             Increase
# 384189                         3. Payments       Outflow             Decrease
# 311367                    2. New borrowing        Inflow             Increase
# 386346                         3. Payments       Outflow             Decrease
# 1780    7. Closing Balance--End of last DQ           NaN                  NaN
#
#         trx_val_dir  bal_evol
# 201726       1500.0    1500.0
# 203404      -1500.0       0.0
# 322738       1500.0    1500.0
# 384189      -1500.0       0.0
# 311367        500.0     500.0
# 386346       -500.0       0.0
# 1780            0.0       0.0

# %%
lna.plot(x="trx_stdtime_days_acc",y="bal_evol")

# %% [markdown]
# ## Let's look at the evolution of the balance of a different account.

# %%
a = random.choice(dfi["account_ids"].unique())
print(a)
# Out:
# 59135825372200000

# %% [markdown]
# ### I used a = 59135825372200000.

# %%
lna = dfi[dfi["account_ids"]==a]

# %%
lna.shape
# Out:
# (21, 59)

# %% [markdown]
# ### Let's look at this one account.

# %%
lna.sort_values("trx_stdtime_days_acc", inplace=True)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
lna.insert(58, "trx_val_dir",np.zeros(lna.shape[0]))

# %%
for index, row in lna.iterrows():
    if lna.loc[index,"trx_bsheet_direction"]=="Increase":
        lna.at[index,"trx_val_dir"] = lna.loc[index,"trx_value_kes"]
    elif lna.loc[index,"trx_bsheet_direction"]=="Decrease":
        lna.at[index,"trx_val_dir"] = -lna.loc[index,"trx_value_kes"]
    else:
        print("Error neither increase nor decrease at index " + str(index)+".")
# Out:
# Error neither increase nor decrease at index 20990.

# %%
lna[["trx_stdtime_days_acc","trx_value_kes","trx_prx_purpose","trx_direction","trx_bsheet_direction","trx_val_dir","trx_date2"]]
# Out:
#         trx_stdtime_days_acc  trx_value_kes  \
# 285092                     0         1000.0
# 19868                      0          200.0
# 3935                       9          200.0
# 455577                     9         1000.0
# 455585                     9          200.0
# 18616                      9          200.0
# 3936                      32          200.0
# 443210                    32         1000.0
# 265640                    60         1000.0
# 3937                      60          200.0
# 84161                     60          200.0
# 93310                     60         1000.0
# 298527                   120          400.0
# 387713                   120         2000.0
# 256091                   151         1200.0
# 18964                    151          200.0
# 253758                   151         1000.0
# 290738                   158         2600.0
# 35384                    181         1000.0
# 443062                   213         2200.0
# 20990                    261            0.0
#
#                            trx_prx_purpose trx_direction trx_bsheet_direction  \
# 285092                    2. New borrowing        Inflow             Increase
# 19868                 5. Interest accruing           NaN             Increase
# 3935                  5. Interest accruing           NaN             Increase
# 455577                    2. New borrowing        Inflow             Increase
# 455585                         3. Payments       Outflow             Decrease
# 18616                 5. Interest accruing           NaN             Increase
# 3936                  5. Interest accruing           NaN             Increase
# 443210                    2. New borrowing        Inflow             Increase
# 265640                    2. New borrowing        Inflow             Increase
# 3937                  5. Interest accruing           NaN             Increase
# 84161                          3. Payments       Outflow             Decrease
# 93310                          3. Payments       Outflow             Decrease
# 298527                5. Interest accruing           NaN             Increase
# 387713                    2. New borrowing        Inflow             Increase
# 256091                         3. Payments       Outflow             Decrease
# 18964                 5. Interest accruing           NaN             Increase
# 253758                    2. New borrowing        Inflow             Increase
# 290738                         3. Payments       Outflow             Decrease
# 35384                          3. Payments       Outflow             Decrease
# 443062                         3. Payments       Outflow             Decrease
# 20990   7. Closing Balance--End of last DQ           NaN                  NaN
#
#         trx_val_dir   trx_date2
# 285092       1000.0  2013-01-10
# 19868         200.0  2013-01-10
# 3935          200.0  2013-01-19
# 455577       1000.0  2013-01-19
# 455585       -200.0  2013-01-19
# 18616         200.0  2013-01-19
# 3936          200.0  2013-02-11
# 443210       1000.0  2013-02-11
# 265640       1000.0  2013-03-11
# 3937          200.0  2013-03-11
# 84161        -200.0  2013-03-11
# 93310       -1000.0  2013-03-11
# 298527        400.0  2013-05-10
# 387713       2000.0  2013-05-10
# 256091      -1200.0  2013-06-10
# 18964         200.0  2013-06-10
# 253758       1000.0  2013-06-10
# 290738      -2600.0  2013-06-17
# 35384       -1000.0  2013-07-10
# 443062      -2200.0  2013-08-11
# 20990           0.0  2013-09-28

# %%
lna.insert(59,"bal_evol",np.zeros(lna.shape[0]))

# %%
s=0
for index,row in lna.iterrows():
    s+=lna.loc[index,"trx_val_dir"]
    lna.at[index,"bal_evol"]=s

# %%
lna[["trx_stdtime_days_acc","trx_value_kes","trx_prx_purpose","trx_direction","trx_bsheet_direction","trx_val_dir","bal_evol"]]
# Out:
#         trx_stdtime_days_acc  trx_value_kes  \
# 285092                     0         1000.0
# 19868                      0          200.0
# 3935                       9          200.0
# 455577                     9         1000.0
# 455585                     9          200.0
# 18616                      9          200.0
# 3936                      32          200.0
# 443210                    32         1000.0
# 265640                    60         1000.0
# 3937                      60          200.0
# 84161                     60          200.0
# 93310                     60         1000.0
# 298527                   120          400.0
# 387713                   120         2000.0
# 256091                   151         1200.0
# 18964                    151          200.0
# 253758                   151         1000.0
# 290738                   158         2600.0
# 35384                    181         1000.0
# 443062                   213         2200.0
# 20990                    261            0.0
#
#                            trx_prx_purpose trx_direction trx_bsheet_direction  \
# 285092                    2. New borrowing        Inflow             Increase
# 19868                 5. Interest accruing           NaN             Increase
# 3935                  5. Interest accruing           NaN             Increase
# 455577                    2. New borrowing        Inflow             Increase
# 455585                         3. Payments       Outflow             Decrease
# 18616                 5. Interest accruing           NaN             Increase
# 3936                  5. Interest accruing           NaN             Increase
# 443210                    2. New borrowing        Inflow             Increase
# 265640                    2. New borrowing        Inflow             Increase
# 3937                  5. Interest accruing           NaN             Increase
# 84161                          3. Payments       Outflow             Decrease
# 93310                          3. Payments       Outflow             Decrease
# 298527                5. Interest accruing           NaN             Increase
# 387713                    2. New borrowing        Inflow             Increase
# 256091                         3. Payments       Outflow             Decrease
# 18964                 5. Interest accruing           NaN             Increase
# 253758                    2. New borrowing        Inflow             Increase
# 290738                         3. Payments       Outflow             Decrease
# 35384                          3. Payments       Outflow             Decrease
# 443062                         3. Payments       Outflow             Decrease
# 20990   7. Closing Balance--End of last DQ           NaN                  NaN
#
#         trx_val_dir  bal_evol
# 285092       1000.0    1000.0
# 19868         200.0    1200.0
# 3935          200.0    1400.0
# 455577       1000.0    2400.0
# 455585       -200.0    2200.0
# 18616         200.0    2400.0
# 3936          200.0    2600.0
# 443210       1000.0    3600.0
# 265640       1000.0    4600.0
# 3937          200.0    4800.0
# 84161        -200.0    4600.0
# 93310       -1000.0    3600.0
# 298527        400.0    4000.0
# 387713       2000.0    6000.0
# 256091      -1200.0    4800.0
# 18964         200.0    5000.0
# 253758       1000.0    6000.0
# 290738      -2600.0    3400.0
# 35384       -1000.0    2400.0
# 443062      -2200.0     200.0
# 20990           0.0     200.0

# %%
lna.plot(x="trx_stdtime_days_acc",y="bal_evol")

# %% [markdown]
# ## Let's look at the evolution of the balance of a different account.

# %%
a = random.choice(dfi["account_ids"].unique())
print(a)
# Out:
# 63135365595900000

# %% [markdown]
# ### I used a = 63135365595900000.

# %%
lna = dfi[dfi["account_ids"]==a]

# %%
lna.shape
# Out:
# (5, 59)

# %% [markdown]
# ### Let's look at this one account.

# %%
lna.sort_values("trx_stdtime_days_acc", inplace=True)
lna
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#          hh_ids  unique_hhs first_trx_date_hh last_trx_date_hh  \
# 333279  KMAKE21         NaN         01oct2012        04oct2013
# 418471  KMAKE21         NaN         01oct2012        04oct2013
# 356631  KMAKE21         NaN         01oct2012        04oct2013
# 7958    KMAKE21         NaN         01oct2012        04oct2013
# 25192   KMAKE21         NaN         01oct2012        04oct2013
#
#         tot_hh_daysofobs  tot_hh_monthsofobs  interview_designation  \
# 333279               368                  12   04=Diaries Interview
# 418471               368                  12   04=Diaries Interview
# 356631               368                  12   04=Diaries Interview
# 7958                 368                  12  06=Cleaning interview
# 25192                368                  12  06=Cleaning interview
#
#          int_date  int_month  int_year int_yr_mo first_int_date  \
# 333279  22nov2012         11      2012   2012_11      04oct2012
# 418471  22nov2012         11      2012   2012_11      04oct2012
# 356631  22nov2012         11      2012   2012_11      04oct2012
# 7958    04oct2013         10      2013   2013_10      04oct2012
# 25192   04oct2013         10      2013   2013_10      04oct2012
#
#               account_ids  unique_accnts        m_ids_owner  unique_hm_owner  \
# 333279  63135365595900000            NaN  63134382825300000              NaN
# 418471  63135365595900000            1.0  63134382825300000              NaN
# 356631  63135365595900000            NaN  63134382825300000              NaN
# 7958    63135365595900000            NaN  63134382825300000              NaN
# 25192   63135365595900000            NaN  63134382825300000              NaN
#
#        account_bsheet_desig account_startclose_balance account_formal  \
# 333279            Liability                        NaN       Informal
# 418471            Liability                        NaN       Informal
# 356631            Liability                        NaN       Informal
# 7958              Liability                      Close       Informal
# 25192             Liability                        NaN       Informal
#
#        account_liquid first_trx_date_acc last_trx_date_acc  tot_acc_daysofobs  \
# 333279            NaN          05nov2012         04oct2013                333
# 418471            NaN          05nov2012         04oct2013                333
# 356631            NaN          05nov2012         04oct2013                333
# 7958              NaN          05nov2012         04oct2013                333
# 25192             NaN          05nov2012         04oct2013                333
#
#         tot_acc_monthsofobs              trx_id          m_ids_trx   trx_date  \
# 333279                   11   63135365610000000  63134382825300000  05nov2012
# 418471                   11   63135365621600000  63134382825300000  05nov2012
# 356631                   11   63135365614000000  63134382825300000  19nov2012
# 7958                     11  105140418553900000  63134382825300000  04oct2013
# 25192                    11  105140418549100000  63134382825300000  04oct2013
#
#          trx_date2  trx_month  trx_year trx_yr_mo  trx_dq_round  \
# 333279  2012-11-05         11      2012   2012_11           4.0
# 418471  2012-11-05         11      2012   2012_11           4.0
# 356631  2012-11-19         11      2012   2012_11           4.0
# 7958    2013-10-04         10      2013   2013_10          21.0
# 25192   2013-10-04         10      2013   2013_10          21.0
#
#         trx_stdtime_days_hh  trx_stdtime_mnths_hh  trx_stdtime_days_acc  \
# 333279                   35                     1                     0
# 418471                   35                     1                     0
# 356631                   49                     1                    14
# 7958                    368                    12                   333
# 25192                   368                    12                   333
#
#         trx_stdtime_mnths_acc trx_class_code  \
# 333279                      0         findev
# 418471                      0         findev
# 356631                      0         findev
# 7958                       11         findev
# 25192                      11         findev
#
#                                            trx_class_desc trx_family_code  \
# 333279  Borrowing, lending, savings or insurance media...          INFGRP
# 418471  Borrowing, lending, savings or insurance media...          INFGRP
# 356631  Borrowing, lending, savings or insurance media...          INFGRP
# 7958    Borrowing, lending, savings or insurance media...          INFGRP
# 25192   Borrowing, lending, savings or insurance media...          INFGRP
#
#        trx_family_desc  trx_type_code                     trx_type_desc  \
# 333279  Informal group           3395  Borrowing from an informal Group
# 418471  Informal group           3395  Borrowing from an informal Group
# 356631  Informal group           3395  Borrowing from an informal Group
# 7958    Informal group           3395  Borrowing from an informal Group
# 25192   Informal group           3395  Borrowing from an informal Group
#
#                                  trx_prx_purpose  \
# 333279                          2. New borrowing
# 418471                               3. Payments
# 356631                               3. Payments
# 7958          7. Closing Balance--End of last DQ
# 25192   INCREASE--Unexplained balance adjustment
#
#                           trx_prx_purpose_fd  trx_fee trx_bsheet_direction  \
# 333279  New borrowing on financial liability      0.0             Increase
# 418471      Repayment on financial liability      0.0             Decrease
# 356631      Repayment on financial liability      0.0             Decrease
# 7958                                     NaN      0.0                  NaN
# 25192                                    NaN      0.0             Increase
#
#         trx_mode_code    trx_mode_desc  trx_place_incommunity  \
# 333279            1.0             Cash                    1.0
# 418471            1.0             Cash                    1.0
# 356631            1.0             Cash                    1.0
# 7958             19.0  CLOSING BALANCE                    NaN
# 25192            19.0  CLOSING BALANCE                    NaN
#
#         trx_distance_km        trx_outlet trx_direction  trx_value_kes  \
# 333279              0.0  07=Group meeting        Inflow          500.0
# 418471              0.0  07=Group meeting       Outflow           50.0
# 356631              0.0  07=Group meeting       Outflow          500.0
# 7958                NaN               NaN           NaN            0.0
# 25192               NaN               NaN           NaN           50.0
#
#         trx_value_usd  ddd_gift trx_inkind_units  trx_inkind_value_usd  \
# 333279       5.882353         0              NaN                   NaN
# 418471       0.588235         0              NaN                   NaN
# 356631       5.882353         0              NaN                   NaN
# 7958         0.000000         0              NaN                   NaN
# 25192        0.588235         0              NaN                   NaN
#
#         trx_inkind_value_kes  trx_stdtime_mnths_hh_nr
# 333279                   NaN                 1.206897
# 418471                   NaN                 1.206897
# 356631                   NaN                 1.689655
# 7958                     NaN                12.689660
# 25192                    NaN                12.689660

# %%
lna.insert(58, "trx_val_dir",np.zeros(lna.shape[0]))

# %%
for index, row in lna.iterrows():
    if lna.loc[index,"trx_bsheet_direction"]=="Increase":
        lna.at[index,"trx_val_dir"] = lna.loc[index,"trx_value_kes"]
    elif lna.loc[index,"trx_bsheet_direction"]=="Decrease":
        lna.at[index,"trx_val_dir"] = -lna.loc[index,"trx_value_kes"]
    else:
        print("Error neither increase nor decrease at index " + str(index)+".")
# Out:
# Error neither increase nor decrease at index 7958.

# %%
lna[["trx_stdtime_days_acc","trx_value_kes","trx_prx_purpose","trx_direction","trx_bsheet_direction","trx_val_dir","trx_date2"]]
# Out:
#         trx_stdtime_days_acc  trx_value_kes  \
# 333279                     0          500.0
# 418471                     0           50.0
# 356631                    14          500.0
# 7958                     333            0.0
# 25192                    333           50.0
#
#                                  trx_prx_purpose trx_direction  \
# 333279                          2. New borrowing        Inflow
# 418471                               3. Payments       Outflow
# 356631                               3. Payments       Outflow
# 7958          7. Closing Balance--End of last DQ           NaN
# 25192   INCREASE--Unexplained balance adjustment           NaN
#
#        trx_bsheet_direction  trx_val_dir   trx_date2
# 333279             Increase        500.0  2012-11-05
# 418471             Decrease        -50.0  2012-11-05
# 356631             Decrease       -500.0  2012-11-19
# 7958                    NaN          0.0  2013-10-04
# 25192              Increase         50.0  2013-10-04

# %%
lna.insert(59,"bal_evol",np.zeros(lna.shape[0]))

# %%
s=0
for index,row in lna.iterrows():
    s+=lna.loc[index,"trx_val_dir"]
    lna.at[index,"bal_evol"]=s

# %%
lna[["trx_stdtime_days_acc","trx_value_kes","trx_prx_purpose","trx_direction","trx_bsheet_direction","trx_val_dir","bal_evol"]]
# Out:
#         trx_stdtime_days_acc  trx_value_kes  \
# 333279                     0          500.0
# 418471                     0           50.0
# 356631                    14          500.0
# 7958                     333            0.0
# 25192                    333           50.0
#
#                                  trx_prx_purpose trx_direction  \
# 333279                          2. New borrowing        Inflow
# 418471                               3. Payments       Outflow
# 356631                               3. Payments       Outflow
# 7958          7. Closing Balance--End of last DQ           NaN
# 25192   INCREASE--Unexplained balance adjustment           NaN
#
#        trx_bsheet_direction  trx_val_dir  bal_evol
# 333279             Increase        500.0     500.0
# 418471             Decrease        -50.0     450.0
# 356631             Decrease       -500.0     -50.0
# 7958                    NaN          0.0     -50.0
# 25192              Increase         50.0       0.0

# %%
lna.plot(x="trx_stdtime_days_acc",y="bal_evol")

# %% [markdown]
# ## Let's look at the evolution of the balance of a different account.

# %%
a = random.choice(dfi["account_ids"].unique())
print(a)
# Out:
# 59135520912300000

# %% [markdown]
# ### I used a = 59135520912300000.

# %%
lna = dfi[dfi["account_ids"]==a]

# %%
lna.shape
# Out:
# (10, 59)

# %% [markdown]
# ### Let's look at this one account.

# %%
lna.sort_values("trx_stdtime_days_acc", inplace=True)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
lna.insert(58, "trx_val_dir",np.zeros(lna.shape[0]))

# %%
for index, row in lna.iterrows():
    if lna.loc[index,"trx_bsheet_direction"]=="Increase":
        lna.at[index,"trx_val_dir"] = lna.loc[index,"trx_value_kes"]
    elif lna.loc[index,"trx_bsheet_direction"]=="Decrease":
        lna.at[index,"trx_val_dir"] = -lna.loc[index,"trx_value_kes"]
    else:
        print("Error neither increase nor decrease at index " + str(index)+".")
# Out:
# Error neither increase nor decrease at index 2931.

# %%
lna[["trx_stdtime_days_acc","trx_value_kes","trx_prx_purpose","trx_direction","trx_bsheet_direction","trx_val_dir","trx_date2"]]
# Out:
#         trx_stdtime_days_acc  trx_value_kes  \
# 15694                      0         3000.0
# 296957                    67         2000.0
# 426832                   130          400.0
# 455607                   165          400.0
# 111664                   193          400.0
# 432386                   193          400.0
# 3131                     221         1000.0
# 187942                   256          680.0
# 455604                   283          520.0
# 2931                     327            0.0
#
#                            trx_prx_purpose trx_direction trx_bsheet_direction  \
# 15694          1. Starting balance (today)           NaN             Increase
# 296957                         3. Payments       Outflow             Decrease
# 426832                         3. Payments       Outflow             Decrease
# 455607                         3. Payments       Outflow             Decrease
# 111664                5. Interest accruing           NaN             Increase
# 432386                         3. Payments       Outflow             Decrease
# 3131                  5. Interest accruing           NaN             Increase
# 187942                         3. Payments       Outflow             Decrease
# 455604                         3. Payments       Outflow             Decrease
# 2931    7. Closing Balance--End of last DQ           NaN                  NaN
#
#         trx_val_dir   trx_date2
# 15694        3000.0  2012-11-02
# 296957      -2000.0  2013-01-08
# 426832       -400.0  2013-03-12
# 455607       -400.0  2013-04-16
# 111664        400.0  2013-05-14
# 432386       -400.0  2013-05-14
# 3131         1000.0  2013-06-11
# 187942       -680.0  2013-07-16
# 455604       -520.0  2013-08-12
# 2931            0.0  2013-09-25

# %%
lna.insert(59,"bal_evol",np.zeros(lna.shape[0]))

# %%
s=0
for index,row in lna.iterrows():
    s+=lna.loc[index,"trx_val_dir"]
    lna.at[index,"bal_evol"]=s

# %%
lna[["trx_stdtime_days_acc","trx_value_kes","trx_prx_purpose","trx_direction","trx_bsheet_direction","trx_val_dir","bal_evol"]]
# Out:
#         trx_stdtime_days_acc  trx_value_kes  \
# 15694                      0         3000.0
# 296957                    67         2000.0
# 426832                   130          400.0
# 455607                   165          400.0
# 111664                   193          400.0
# 432386                   193          400.0
# 3131                     221         1000.0
# 187942                   256          680.0
# 455604                   283          520.0
# 2931                     327            0.0
#
#                            trx_prx_purpose trx_direction trx_bsheet_direction  \
# 15694          1. Starting balance (today)           NaN             Increase
# 296957                         3. Payments       Outflow             Decrease
# 426832                         3. Payments       Outflow             Decrease
# 455607                         3. Payments       Outflow             Decrease
# 111664                5. Interest accruing           NaN             Increase
# 432386                         3. Payments       Outflow             Decrease
# 3131                  5. Interest accruing           NaN             Increase
# 187942                         3. Payments       Outflow             Decrease
# 455604                         3. Payments       Outflow             Decrease
# 2931    7. Closing Balance--End of last DQ           NaN                  NaN
#
#         trx_val_dir  bal_evol
# 15694        3000.0    3000.0
# 296957      -2000.0    1000.0
# 426832       -400.0     600.0
# 455607       -400.0     200.0
# 111664        400.0     600.0
# 432386       -400.0     200.0
# 3131         1000.0    1200.0
# 187942       -680.0     520.0
# 455604       -520.0       0.0
# 2931            0.0       0.0

# %%
lna.plot(x="trx_stdtime_days_acc",y="bal_evol")

# %% [markdown]
# ## Further steps:
# ## 1. Check how often an "unexplained balance adjustment" occured.
# ## 2. Check how often the balance of the loan got negative.
