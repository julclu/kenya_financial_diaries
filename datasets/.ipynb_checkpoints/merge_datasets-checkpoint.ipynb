# %%
import os
import pandas as pd 
import glob

# %%
glob.glob('*.csv')
# Out:
# ['edu_hh_ind_merge.csv',
#  'wellbeing_goingson.csv',
#  'goingson.csv',
#  'wellbeing.csv',
#  'combination_wellbeing_goingson_cons_outcome.csv',
#  'consumption_mapped_to_m_ids.csv']

# %%
cons = pd.read_csv('consumption_mapped_to_m_ids.csv')
wb_go = pd.read_csv('wellbeing_goingson.csv')
edu = pd.read_csv('edu_hh_ind_merge.csv', index_col = 0)

# %%
cons.head()
# Out:
#          m_ids_owner   hh_ids  con_pur_hh_meanptrx  con_pur_hh_sdptrx  \
# 0  58134383397900000  KELDL02             107.9147           286.7984
# 1  58134383535800000  KELDL02             107.9147           286.7984
# 2                 HH  KVIHC16             115.6588           345.8901
# 3  59134423954300000  KVIHC16             115.6588           345.8901
# 4  65134441430300000  KELDK21            1061.1900          4257.9390
#
#    con_pur_hh_minpti  con_pur_hh_meanpti  con_pur_hh_medpti  \
# 0               3293            14372.27            15640.0
# 1               3293            14372.27            15640.0
# 2               1070             5825.00             5470.0
# 3               1070             5825.00             5470.0
# 4               1150            26529.75            17300.0
#
#    con_pur_hh_maxpti  con_pur_hh_meanpti_ALC  con_pur_hh_medpti_ALC  \
# 0              23670                204.5455                    0.0
# ...

# %%
cons.shape
# Out:
# (670, 38)

# %%
wb_go.head()
# Out:
#     hh_ids  happiness  economically  relationships  confidence  police  \
# 0  KELDK01   4.045455      3.863636       4.863636    4.681818     0.0
# 1  KELDK02   4.105263      3.947368       4.842105    4.736842     0.0
# 2  KELDK08   4.038462      3.653846       4.730769    4.884615     0.0
# 3  KELDK09   4.052632      3.947368       4.947368    4.894737     0.0
# 4  KELDK10   4.111111      4.000000       4.777778    4.944444     0.0
#
#    doctor    unsafe  utilities  asset_taken  miss_app  miss_inc  romantic  \
# 0     0.0  0.000000        0.0          0.0       0.0  0.000000  0.000000
# 1     0.0  0.076923        0.0          0.0       0.0  0.153846  0.000000
# 2     0.0  0.000000        0.0          0.0       0.0  0.000000  0.000000
# 3     0.0  0.000000        0.0          0.0       0.0  0.000000  0.000000
# 4     0.0  0.000000        0.0          0.0       0.0  0.000000  0.058824
#
#      hungry  school_sent
# 0  0.000000     0.071429
# 1  0.000000     0.111111
# ...

# %%
wb_go.shape
# Out:
# (298, 15)

# %%
edu.head()
# Out:
#                m_ids   hh_ids  edu_i_enrolled                  edu_i_attain  \
# 0  56134390476100000  KELDK01             0.0    Primary (some or complete)
# 1  56134390654900000  KELDK01             0.0  Secondary (some or complete)
# 2  56134392820800000  KELDK01             1.0    Primary (some or complete)
# 3  56134392826900000  KELDK01             0.0                  No education
# 4  56134389503000000  KELDK02             0.0    Primary (some or complete)
#
#    edu_i_attain_yrs  edu_hh_child613inschool  edu_hh_child1417inschool  \
# 0               8.0                      1.0                       NaN
# 1              10.0                      1.0                       NaN
# 2               3.0                      1.0                       NaN
# 3               0.0                      1.0                       NaN
# 4               8.0                      NaN                       1.0
#
#    edu_hh_girls613inschool  edu_hh_girls1417inschool  edu_hh_boys613inschool  \
# ...

# %%
edu.shape
# Out:
# (1565, 12)

# %%
cons_wb_go = cons.merge(wb_go, on = 'hh_ids', how = 'left')

# %%
cons_wb_go.head()
# Out:
#          m_ids_owner   hh_ids  con_pur_hh_meanptrx  con_pur_hh_sdptrx  \
# 0  58134383397900000  KELDL02             107.9147           286.7984
# 1  58134383535800000  KELDL02             107.9147           286.7984
# 2                 HH  KVIHC16             115.6588           345.8901
# 3  59134423954300000  KVIHC16             115.6588           345.8901
# 4  65134441430300000  KELDK21            1061.1900          4257.9390
#
#    con_pur_hh_minpti  con_pur_hh_meanpti  con_pur_hh_medpti  \
# 0               3293            14372.27            15640.0
# 1               3293            14372.27            15640.0
# 2               1070             5825.00             5470.0
# 3               1070             5825.00             5470.0
# 4               1150            26529.75            17300.0
#
#    con_pur_hh_maxpti  con_pur_hh_meanpti_ALC  con_pur_hh_medpti_ALC  \
# 0              23670                204.5455                    0.0
# ...

# %%
cons_wb_go.shape
# Out:
# (670, 52)

# %%
cons_wb_go_edu = cons_wb_go.merge(edu, left_on  = 'm_ids_owner', right_on='m_ids', how = 'outer')

# %%
cons_wb_go_edu.shape
# Out:
# (2235, 64)

# %%
df_full.head()
# Out:
#                                                loans        m_ids_owner  \
# 0  ['56134804374600000.3', '56134804374600000.1',...  65134441430300000
# 1     ['60137430710900000.1', '60134978362300000.1']  60134547419200000
# 2  ['63136740549700000.1', '63136740416600000.2',...  63134425702500000
# 3     ['89136459180500000.2', '89136459180500000.1']  64134429266300000
# 4   ['105136540140100000.1', '105136540140100000.2']  65134432186900000
#
#    owner_score  owner_score_binarize   hh_ids  con_pur_hh_meanptrx  \
# 0         0.75                     0  KELDK21            1061.1900
# 1         0.50                     0  KVIHK40             213.3567
# 2         1.00                     0  KMAKE06             153.4010
# 3         1.00                     0  KNBOK05             273.7134
# 4         1.00                     0  KELDK37             217.1206
#
#    con_pur_hh_sdptrx  con_pur_hh_minpti  con_pur_hh_meanpti  \
# 0          4257.9390               1150           26529.750
# ...

# %%
df_full.to_csv('combination_wellbeing_goingson_cons_outcome.csv', index = False)
