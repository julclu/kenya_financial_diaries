# %%
import pandas as pd
import os
import glob

# %%
x = pd.read_csv('dummy_hou.csv', index_col = 0)

# %%
x.head()
# Out:
#     hh_ids  hh_inf_rooms_habitable  hh_inf_rooms_other  hh_otherprop_N  \
# 0  KNBOK31                     NaN                 NaN             NaN
# 1  KNBOK01                     3.0                 3.0             NaN
# 2  KNBOK02                     1.0                 1.0             NaN
# 3  KNBOK04                     2.0                 1.0             1.0
# 4  KNBOK05                     5.0                 3.0             NaN
#
#    hh_othershamba_N  add_prop_value  hh_inf_wall_material_2  \
# 0               NaN             NaN                       0
# 1               NaN             NaN                       0
# 2               NaN             NaN                       0
# 3               NaN             NaN                       0
# 4               NaN             NaN                       0
#
#    hh_inf_wall_material_3  hh_inf_wall_material_4  hh_inf_wall_material_5  \
# 0                       0                       0                       0
# ...

# %%
x.describe()
# Out:
#        hh_inf_rooms_habitable  hh_inf_rooms_other  hh_otherprop_N  \
# count              296.000000          296.000000       82.000000
# mean                 2.486486            1.425676        1.085366
# std                  1.345357            1.491632        0.612649
# min                  1.000000            0.000000        0.000000
# 25%                  1.000000            1.000000        1.000000
# 50%                  2.000000            1.000000        1.000000
# 75%                  3.000000            2.000000        1.000000
# max                  8.000000           21.000000        5.000000
#
#        hh_othershamba_N  add_prop_value  hh_inf_wall_material_2  \
# count         45.000000    2.000000e+00              301.000000
# mean           0.888889    1.635250e+06                0.345515
# std            0.745356    2.283601e+06                0.476328
# min            0.000000    2.050000e+04                0.000000
# ...
