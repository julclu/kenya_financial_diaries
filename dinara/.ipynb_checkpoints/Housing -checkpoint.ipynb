# %%
import pandas as pd
import numpy as np
import math as math
import matplotlib.pyplot as plt
import seaborn as sns
import random
# %matplotlib inline

# %%
df = pd.read_csv("../../diaries_transactions_all.csv", dtype={'account_startclose_balance': str})

# %%
dfb = df[(df["trx_family_code"]=="FRMLN")&((df["trx_type_code"]==2760)|(df["trx_type_code"]==3247))]

# %%
dfb["trx_prx_purpose"].unique()
# Out:
# array(['6. Closing Balance--End of last DQ',
#        '1. Starting balance (today)', '5. Interest accruing',
#        '3. Payments', 'INCREASE--Unexplained balance adjustment',
#        '2. New borrowinng (individual portion)', '4. Any known fees',
#        'DECREASE--Unexplained balance adjustment',
#        '7. Refund from lender', '2. New borrowing'], dtype=object)

# %%
for acc in dfb["account_ids"].unique():
    u = 0
    for index,row in dfb[dfb["account_ids"]==acc].iterrows():
        if row["trx_prx_purpose"]=="DECREASE--Unexplained balance adjustment" or row["trx_prx_purpose"]=="INCREASE--Unexplained balance adjustment":
            u = 1
    for index,row in dfb[dfb["account_ids"]==acc].iterrows():
        dfb.at[index,"acc_unexplained_trx"] = u

# %%
s = set()
for acc in dfb[dfb["acc_unexplained_trx"]==0]["account_ids"].unique():
     for i in dfb[dfb["account_ids"]==acc]["trx_prx_purpose"].unique():
            s.add(i)
print(s)
# Out:
# {'4. Any known fees', '2. New borrowinng (individual portion)', '7. Refund from lender', '2. New borrowing', '1. Starting balance (today)', '6. Closing Balance--End of last DQ', '5. Interest accruing', '3. Payments'}

# %%
dfb = dfb[dfb["acc_unexplained_trx"]==0]

# %%
del dfb["new_account_ids"]
dfb.insert(df.columns.get_loc("account_ids")+1,"new_account_ids", ["-"]*(dfb.shape[0]))
dfb.sample(1)
# Out:
#          hh_ids  unique_hhs first_trx_date_hh last_trx_date_hh  \
# 288513  KVIHC35         NaN         05aug2012        22sep2013
#
#         tot_hh_daysofobs  tot_hh_monthsofobs interview_designation   int_date  \
# 288513               413                  14  04=Diaries Interview  25jan2013
#
#         int_month  int_year  ...        trx_outlet trx_direction  \
# 288513          1      2013  ...  07=Group meeting       Outflow
#
#        trx_value_kes trx_value_usd  ddd_gift trx_inkind_units  \
# 288513       12350.0      145.2941         0              NaN
#
#         trx_inkind_value_usd trx_inkind_value_kes trx_stdtime_mnths_hh_nr  \
# 288513                   NaN                  NaN                5.689655
#
#        acc_unexplained_trx
# 288513                 0.0
#
# [1 rows x 60 columns]

# %% [markdown]
# ### Here I "cleaned" data for housing in excel. What can be extracted: if owned, number and value of additional property

# %%
df1 = pd.read_csv('../housing_conditions_ownership.csv')
dfh=df1[['hh_ids','owned','N', 'other_prop_or_shamba_value' ]]
dfh.head()
# Out:
#     hh_ids owned    N  other_prop_or_shamba_value
# 0  KNBOK31    no  NaN                         NaN
# 1  KNBOK01   yes  NaN                         NaN
# 2  KNBOK02   yes  NaN                         NaN
# 3  KNBOK04   yes  1.0                   1500000.0
# 4  KNBOK05   yes  NaN                         NaN

# %%
pd.merge(dfb, dfh, on = 'hh_ids', how='outer')
# Out:
#       hh_ids  unique_hhs first_trx_date_hh last_trx_date_hh  tot_hh_daysofobs  \
# 0    KVIHK40         NaN         10sep2012        03oct2013             388.0
# 1    KVIHK40         NaN         10sep2012        03oct2013             388.0
# 2    KVIHK40         NaN         10sep2012        03oct2013             388.0
# 3    KVIHK40         NaN         10sep2012        03oct2013             388.0
# 4    KVIHK40         NaN         10sep2012        03oct2013             388.0
# 5    KVIHK40         NaN         10sep2012        03oct2013             388.0
# 6    KVIHK40         NaN         10sep2012        03oct2013             388.0
# 7    KVIHK40         NaN         10sep2012        03oct2013             388.0
# 8    KVIHK40         NaN         10sep2012        03oct2013             388.0
# 9    KVIHK40         NaN         10sep2012        03oct2013             388.0
# 10   KVIHK40         NaN         10sep2012        03oct2013             388.0
# 11   KVIHK40         NaN         10sep2012        03oct2013             388.0
# 12   KVIHK40         NaN         10sep2012        03oct2013             388.0
# 13   KVIHK40         NaN         10sep2012        03oct2013             388.0
# 14   KVIHK40         NaN         10sep2012        03oct2013             388.0
# 15   KVIHK40         NaN         10sep2012        03oct2013             388.0
# 16   KVIHK40         NaN         10sep2012        03oct2013             388.0
# 17   KVIHK40         NaN         10sep2012        03oct2013             388.0
# 18   KVIHK40         NaN         10sep2012        03oct2013             388.0
# 19   KVIHK40         NaN         10sep2012        03oct2013             388.0
# 20   KVIHK40         NaN         10sep2012        03oct2013             388.0
# 21   KVIHK40         NaN         10sep2012        03oct2013             388.0
# 22   KVIHK40         NaN         10sep2012        03oct2013             388.0
# 23   KVIHK40         NaN         10sep2012        03oct2013             388.0
# 24   KVIHK40         NaN         10sep2012        03oct2013             388.0
# 25   KVIHK40         NaN         10sep2012        03oct2013             388.0
# 26   KVIHK40         NaN         10sep2012        03oct2013             388.0
# 27   KVIHK40         NaN         10sep2012        03oct2013             388.0
# 28   KVIHK40         NaN         10sep2012        03oct2013             388.0
# 29   KVIHK40         NaN         10sep2012        03oct2013             388.0
# ..       ...         ...               ...              ...               ...
# 700  KVIHC25         NaN               NaN              NaN               NaN
# 701  KVIHC26         NaN               NaN              NaN               NaN
# 702  KVIHC34         NaN               NaN              NaN               NaN
# 703  KVIHK01         NaN               NaN              NaN               NaN
# 704  KVIHK02         NaN               NaN              NaN               NaN
# 705  KVIHK05         NaN               NaN              NaN               NaN
# 706  KVIHK06         NaN               NaN              NaN               NaN
# 707  KVIHK07         NaN               NaN              NaN               NaN
# 708  KVIHK10         NaN               NaN              NaN               NaN
# 709  KVIHK11         NaN               NaN              NaN               NaN
# 710  KVIHK13         NaN               NaN              NaN               NaN
# 711  KVIHK15         NaN               NaN              NaN               NaN
# 712  KVIHK16         NaN               NaN              NaN               NaN
# 713  KVIHK17         NaN               NaN              NaN               NaN
# 714  KVIHK18         NaN               NaN              NaN               NaN
# 715  KVIHK19         NaN               NaN              NaN               NaN
# 716  KVIHK21         NaN               NaN              NaN               NaN
# 717  KVIHK22         NaN               NaN              NaN               NaN
# 718  KVIHK23         NaN               NaN              NaN               NaN
# 719  KVIHK24         NaN               NaN              NaN               NaN
# 720  KVIHK26         NaN               NaN              NaN               NaN
# 721  KVIHK29         NaN               NaN              NaN               NaN
# 722  KVIHK31         NaN               NaN              NaN               NaN
# 723  KVIHK32         NaN               NaN              NaN               NaN
# 724  KNBOK36         NaN               NaN              NaN               NaN
# 725  KNBOK38         NaN               NaN              NaN               NaN
# 726  KNBOK39         NaN               NaN              NaN               NaN
# 727  KNBOK40         NaN               NaN              NaN               NaN
# 728  KNBOK41         NaN               NaN              NaN               NaN
# 729  KNBOK42         NaN               NaN              NaN               NaN
#
#      tot_hh_monthsofobs  interview_designation   int_date  int_month  \
# 0                  13.0  06=Cleaning interview  04oct2013       10.0
# 1                  13.0   04=Diaries Interview  04jun2013        6.0
# 2                  13.0  06=Cleaning interview  04oct2013       10.0
# 3                  13.0                  03=Q3  02oct2012       10.0
# 4                  13.0   04=Diaries Interview  14nov2012       11.0
# 5                  13.0   04=Diaries Interview  29jan2013        1.0
# 6                  13.0   04=Diaries Interview  04jul2013        7.0
# 7                  13.0   04=Diaries Interview  09apr2013        4.0
# 8                  13.0   04=Diaries Interview  15jan2013        1.0
# 9                  13.0   04=Diaries Interview  23jul2013        7.0
# 10                 13.0   04=Diaries Interview  14nov2012       11.0
# 11                 13.0   04=Diaries Interview  15jan2013        1.0
# 12                 13.0   04=Diaries Interview  20aug2013        8.0
# 13                 13.0   04=Diaries Interview  29jan2013        1.0
# 14                 13.0   04=Diaries Interview  21may2013        5.0
# 15                 13.0   04=Diaries Interview  23oct2012       10.0
# 16                 13.0   04=Diaries Interview  14nov2012       11.0
# 17                 13.0   04=Diaries Interview  27nov2012       11.0
# 18                 13.0   04=Diaries Interview  09apr2013        4.0
# 19                 13.0   04=Diaries Interview  18jun2013        6.0
# 20                 13.0   04=Diaries Interview  19mar2013        3.0
# 21                 13.0   04=Diaries Interview  18sep2013        9.0
# 22                 13.0   04=Diaries Interview  27nov2012       11.0
# 23                 13.0   04=Diaries Interview  07may2013        5.0
# 24                 13.0   04=Diaries Interview  18dec2012       12.0
# 25                 13.0   04=Diaries Interview  21may2013        5.0
# 26                 13.0   04=Diaries Interview  18dec2012       12.0
# 27                 13.0   04=Diaries Interview  14nov2012       11.0
# 28                 13.0   04=Diaries Interview  19feb2013        2.0
# 29                 13.0   04=Diaries Interview  21may2013        5.0
# ..                  ...                    ...        ...        ...
# 700                 NaN                    NaN        NaN        NaN
# 701                 NaN                    NaN        NaN        NaN
# 702                 NaN                    NaN        NaN        NaN
# 703                 NaN                    NaN        NaN        NaN
# 704                 NaN                    NaN        NaN        NaN
# 705                 NaN                    NaN        NaN        NaN
# 706                 NaN                    NaN        NaN        NaN
# 707                 NaN                    NaN        NaN        NaN
# 708                 NaN                    NaN        NaN        NaN
# 709                 NaN                    NaN        NaN        NaN
# 710                 NaN                    NaN        NaN        NaN
# 711                 NaN                    NaN        NaN        NaN
# 712                 NaN                    NaN        NaN        NaN
# 713                 NaN                    NaN        NaN        NaN
# 714                 NaN                    NaN        NaN        NaN
# 715                 NaN                    NaN        NaN        NaN
# 716                 NaN                    NaN        NaN        NaN
# 717                 NaN                    NaN        NaN        NaN
# 718                 NaN                    NaN        NaN        NaN
# 719                 NaN                    NaN        NaN        NaN
# 720                 NaN                    NaN        NaN        NaN
# 721                 NaN                    NaN        NaN        NaN
# 722                 NaN                    NaN        NaN        NaN
# 723                 NaN                    NaN        NaN        NaN
# 724                 NaN                    NaN        NaN        NaN
# 725                 NaN                    NaN        NaN        NaN
# 726                 NaN                    NaN        NaN        NaN
# 727                 NaN                    NaN        NaN        NaN
# 728                 NaN                    NaN        NaN        NaN
# 729                 NaN                    NaN        NaN        NaN
#
#      int_year  ... trx_value_usd ddd_gift trx_inkind_units  \
# 0      2013.0  ...    1191.76500      0.0              NaN
# 1      2013.0  ...     411.76470      0.0              NaN
# 2      2013.0  ...     210.58820      0.0              NaN
# 3      2012.0  ...    1035.29400      0.0              NaN
# 4      2012.0  ...      31.76471      0.0              NaN
# 5      2013.0  ...      23.52941      0.0              NaN
# 6      2013.0  ...      47.05882      0.0              NaN
# 7      2013.0  ...      20.58824      0.0              NaN
# 8      2013.0  ...      25.88235      0.0              NaN
# 9      2013.0  ...     132.35290      0.0              NaN
# 10     2012.0  ...      31.76471      0.0              NaN
# 11     2013.0  ...      47.05882      0.0              NaN
# 12     2013.0  ...     132.35290      0.0              NaN
# 13     2013.0  ...      23.52941      0.0              NaN
# 14     2013.0  ...      47.05882      0.0              NaN
# 15     2012.0  ...      29.41176      0.0              NaN
# 16     2012.0  ...      31.76471      0.0              NaN
# 17     2012.0  ...      30.58824      0.0              NaN
# 18     2013.0  ...      24.70588      0.0              NaN
# 19     2013.0  ...      47.05882      0.0              NaN
# 20     2013.0  ...      26.47059      0.0              NaN
# 21     2013.0  ...     131.76470      0.0              NaN
# 22     2012.0  ...      11.76471      0.0              NaN
# 23     2013.0  ...      71.76471      0.0              NaN
# 24     2012.0  ...      25.88235      0.0              NaN
# 25     2013.0  ...      17.64706      0.0              NaN
# 26     2012.0  ...      25.88235      0.0              NaN
# 27     2012.0  ...      31.76471      0.0              NaN
# 28     2013.0  ...      49.41177      0.0              NaN
# 29     2013.0  ...      11.76471      0.0              NaN
# ..        ...  ...           ...      ...              ...
# 700       NaN  ...           NaN      NaN              NaN
# 701       NaN  ...           NaN      NaN              NaN
# 702       NaN  ...           NaN      NaN              NaN
# 703       NaN  ...           NaN      NaN              NaN
# 704       NaN  ...           NaN      NaN              NaN
# 705       NaN  ...           NaN      NaN              NaN
# 706       NaN  ...           NaN      NaN              NaN
# 707       NaN  ...           NaN      NaN              NaN
# 708       NaN  ...           NaN      NaN              NaN
# 709       NaN  ...           NaN      NaN              NaN
# 710       NaN  ...           NaN      NaN              NaN
# 711       NaN  ...           NaN      NaN              NaN
# 712       NaN  ...           NaN      NaN              NaN
# 713       NaN  ...           NaN      NaN              NaN
# 714       NaN  ...           NaN      NaN              NaN
# 715       NaN  ...           NaN      NaN              NaN
# 716       NaN  ...           NaN      NaN              NaN
# 717       NaN  ...           NaN      NaN              NaN
# 718       NaN  ...           NaN      NaN              NaN
# 719       NaN  ...           NaN      NaN              NaN
# 720       NaN  ...           NaN      NaN              NaN
# 721       NaN  ...           NaN      NaN              NaN
# 722       NaN  ...           NaN      NaN              NaN
# 723       NaN  ...           NaN      NaN              NaN
# 724       NaN  ...           NaN      NaN              NaN
# 725       NaN  ...           NaN      NaN              NaN
# 726       NaN  ...           NaN      NaN              NaN
# 727       NaN  ...           NaN      NaN              NaN
# 728       NaN  ...           NaN      NaN              NaN
# 729       NaN  ...           NaN      NaN              NaN
#
#     trx_inkind_value_usd  trx_inkind_value_kes trx_stdtime_mnths_hh_nr  \
# 0                    NaN                   NaN               13.379310
# 1                    NaN                   NaN                8.931034
# 2                    NaN                   NaN               13.379310
# 3                    NaN                   NaN                0.758621
# 4                    NaN                   NaN                1.482759
# 5                    NaN                   NaN                4.620690
# 6                    NaN                   NaN               10.000000
# 7                    NaN                   NaN                6.896552
# 8                    NaN                   NaN                3.413793
# 9                    NaN                   NaN               10.310340
# 10                   NaN                   NaN                2.206897
# 11                   NaN                   NaN                4.137931
# 12                   NaN                   NaN               11.379310
# 13                   NaN                   NaN                4.379310
# 14                   NaN                   NaN                8.310345
# 15                   NaN                   NaN                1.241379
# 16                   NaN                   NaN                1.724138
# 17                   NaN                   NaN                2.448276
# 18                   NaN                   NaN                6.655172
# 19                   NaN                   NaN                9.482759
# 20                   NaN                   NaN                6.413793
# 21                   NaN                   NaN               12.551720
# 22                   NaN                   NaN                2.620690
# 23                   NaN                   NaN                7.827586
# 24                   NaN                   NaN                2.689655
# 25                   NaN                   NaN                8.310345
# 26                   NaN                   NaN                3.172414
# 27                   NaN                   NaN                1.965517
# 28                   NaN                   NaN                5.344828
# 29                   NaN                   NaN                8.344828
# ..                   ...                   ...                     ...
# 700                  NaN                   NaN                     NaN
# 701                  NaN                   NaN                     NaN
# 702                  NaN                   NaN                     NaN
# 703                  NaN                   NaN                     NaN
# 704                  NaN                   NaN                     NaN
# 705                  NaN                   NaN                     NaN
# 706                  NaN                   NaN                     NaN
# 707                  NaN                   NaN                     NaN
# 708                  NaN                   NaN                     NaN
# 709                  NaN                   NaN                     NaN
# 710                  NaN                   NaN                     NaN
# 711                  NaN                   NaN                     NaN
# 712                  NaN                   NaN                     NaN
# 713                  NaN                   NaN                     NaN
# 714                  NaN                   NaN                     NaN
# 715                  NaN                   NaN                     NaN
# 716                  NaN                   NaN                     NaN
# 717                  NaN                   NaN                     NaN
# 718                  NaN                   NaN                     NaN
# 719                  NaN                   NaN                     NaN
# 720                  NaN                   NaN                     NaN
# 721                  NaN                   NaN                     NaN
# 722                  NaN                   NaN                     NaN
# 723                  NaN                   NaN                     NaN
# 724                  NaN                   NaN                     NaN
# 725                  NaN                   NaN                     NaN
# 726                  NaN                   NaN                     NaN
# 727                  NaN                   NaN                     NaN
# 728                  NaN                   NaN                     NaN
# 729                  NaN                   NaN                     NaN
#
#      acc_unexplained_trx owned    N other_prop_or_shamba_value
# 0                    0.0   yes  NaN                        NaN
# 1                    0.0   yes  NaN                        NaN
# 2                    0.0   yes  NaN                        NaN
# 3                    0.0   yes  NaN                        NaN
# 4                    0.0   yes  NaN                        NaN
# 5                    0.0   yes  NaN                        NaN
# 6                    0.0   yes  NaN                        NaN
# 7                    0.0   yes  NaN                        NaN
# 8                    0.0   yes  NaN                        NaN
# 9                    0.0   yes  NaN                        NaN
# 10                   0.0   yes  NaN                        NaN
# 11                   0.0   yes  NaN                        NaN
# 12                   0.0   yes  NaN                        NaN
# 13                   0.0   yes  NaN                        NaN
# 14                   0.0   yes  NaN                        NaN
# 15                   0.0   yes  NaN                        NaN
# 16                   0.0   yes  NaN                        NaN
# 17                   0.0   yes  NaN                        NaN
# 18                   0.0   yes  NaN                        NaN
# 19                   0.0   yes  NaN                        NaN
# 20                   0.0   yes  NaN                        NaN
# 21                   0.0   yes  NaN                        NaN
# 22                   0.0   yes  NaN                        NaN
# 23                   0.0   yes  NaN                        NaN
# 24                   0.0   yes  NaN                        NaN
# 25                   0.0   yes  NaN                        NaN
# 26                   0.0   yes  NaN                        NaN
# 27                   0.0   yes  NaN                        NaN
# 28                   0.0   yes  NaN                        NaN
# 29                   0.0   yes  NaN                        NaN
# ..                   ...   ...  ...                        ...
# 700                  NaN   yes  NaN                        NaN
# 701                  NaN   yes  1.0                       99.0
# 702                  NaN   yes  NaN                        NaN
# 703                  NaN   yes  NaN                        NaN
# 704                  NaN   yes  NaN                        NaN
# 705                  NaN   yes  NaN                        NaN
# 706                  NaN   yes  2.0                   400000.0
# 707                  NaN   yes  NaN                        NaN
# 708                  NaN   yes  NaN                        NaN
# 709                  NaN   yes  2.0                   900000.0
# 710                  NaN   yes  NaN                        NaN
# 711                  NaN   yes  NaN                        NaN
# 712                  NaN   yes  NaN                        NaN
# 713                  NaN   yes  1.0                   500000.0
# 714                  NaN   yes  NaN                        NaN
# 715                  NaN   yes  2.0                   400000.0
# 716                  NaN   yes  NaN                        NaN
# 717                  NaN   yes  NaN                        NaN
# 718                  NaN   yes  1.0                   400000.0
# 719                  NaN   yes  NaN                        NaN
# 720                  NaN   yes  NaN                        NaN
# 721                  NaN   yes  2.0                  1750000.0
# 722                  NaN   yes  NaN                        NaN
# 723                  NaN   yes  NaN                        NaN
# 724                  NaN   yes  NaN                        NaN
# 725                  NaN   yes  NaN                        NaN
# 726                  NaN   yes  1.0                   150000.0
# 727                  NaN   yes  1.0                   300000.0
# 728                  NaN   yes  2.0                   250000.0
# 729                  NaN   yes  NaN                        NaN
#
# [730 rows x 63 columns]
