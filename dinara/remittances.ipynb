# %%
import pandas as pd
import numpy as np
import math as math
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
def conv(val):
    if val == np.nan:
        return 0
    return val

# %%
df = pd.read_csv("../../rem_ind_over_trx_yr_mo_kes.csv")

# %%
df.head()
# Out:
#     hh_ids        m_ids_owner  rem_i_unique_sources  rem_i_meanptrx  \
# 0  KELDK02  56134389503000000                     1       4606.4210
# 1  KELDK08  56134410709700000                     2        428.5000
# 2  KELDK09  56134329944600000                     5        656.1765
# 3  KELDK10  56134337157200000                     6        166.8349
# 4  KELDK12  65134436228800000                     1       2000.0000
#
#    rem_i_sdptrx  rem_i_meanptrx_RG  rem_i_sdptrx_RG  rem_i_meanptrx_RR  \
# 0     2317.3330           4606.421         2317.333                NaN
# 1      139.3000                NaN              NaN           330.0000
# 2     1560.7240           5000.000         1732.051                NaN
# 3      618.0686                NaN              NaN           114.8535
# 4           NaN           2000.000              NaN                NaN
#
#    rem_i_sdptrx_RR  rem_i_count_medianpti  ...  rem_i_net_medianpti_cash  \
# ...
