# %%
import os
import pandas as pd 
import glob
import random 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pd.set_option('display.max_columns',200)
pd.set_option('display.max_rows',680)

# %% [markdown]
# ## Determine how quickly someone pays back their one time loans, separated into their respective categories:

# %%
trx = pd.read_csv('../diaries_transactions_all.csv', low_memory = False)

# %%
liability_trx = trx.loc[trx['account_bsheet_desig'] == "Liability"]
liability_trx.shape
# Out:
# (23078, 58)

# %%
liability_trx.trx_family_code.value_counts()
# Out:
# INFP2P     14755
# SUPPCRD     4050
# FRMLN       1429
# INFGRP      1377
# ARREARS     1058
# ADVANCE      280
# EMPLN        111
# PAWN          16
# OTHER          2
# Name: trx_family_code, dtype: int64

# %%
liability_trx.trx_family_desc.value_counts()
# Out:
# Informal P2P                              14755
# Supplier credit                            4050
# Formal loan                                1429
# Informal group                             1377
# Arrears owed to or owed by respondents     1058
# Advance                                     280
# Loan from employer                          111
# Pawning assets                               16
# Other                                         2
# Name: trx_family_desc, dtype: int64

# %%
liability_trx.trx_type_desc.value_counts()
# Out:
# Informal credit at a store                   12022
# Okoa Jahazi                                   2973
# Friends and family: Borrowing                 2073
# Borrowing from an informal Group              1377
# Supplier credit                               1077
# Arrears owed by respondents                   1058
# Act as money guard                             449
# Individual Business or Agriculture Loan        442
# Consumer/ personal loan (not payday loan)      324
# Wage advance                                   280
# Joint liability loan                           265
# Moneylender or Shylock Borrowing               211
# Hire Purchase                                  148
# Loan from employer                             111
# School Fees Loan                               107
# M-SHWARI Loan                                  105
# Group Enterprise Loan                           28
# Pawning assets                                  16
# ...

# %%
friends_family_borrowing_df = liability_trx.loc[liability_trx['trx_type_desc']=="Friends and family: Borrowing"]

# %%
len(friends_family_borrowing.account_ids.unique())
# Out:
# 605

# %%
friends_family_borrowing.shape
# Out:
# (2073, 58)

# %%
friends_family_borrowing.account_ids.value_counts()
# Out:
# 57137225366300000     28
# 57136574022700000     19
# 60136177195600000     18
# 61135780595200000     15
# 60135918356600000     15
# 89136060846900000     14
# 63135935605300000     11
# 58134709702500000     10
# 89137593971300000     10
# 61135305343000000      9
# 62136429071700000      9
# 65134701388900000      9
# 60135196617100000      9
# 65137213659900000      9
# 57136390521500000      9
# 61136004358800000      9
# 62137275757000000      8
# 56135281752300000      8
# 60134848077100000      8
# 79134925908800000      8
# 57135784508700000      7
# 84136869241900000      7
# 57137223327200000      7
# 63135513232500000      7
# 57134822995600000      7
# 62134702499000000      7
# 111137122807100000     7
# 57136505913700000      7
# 105136686050400000     7
# 89136747391600000      7
# 57136607675600000      7
# 57136138765200000      7
# 61135901711600000      6
# 61135029606000000      6
# 57135376160800000      6
# 89136747336400000      6
# 89136404360000000      6
# ...

# %% [markdown]
# ### FF borrowing ranges from 1 - 28 transactions

# %%
### what one of them looks like that has 1 transaction:

# %%
friends_family_borrowing.loc[friends_family_borrowing['account_ids']=='61134770551400000']
# Out:
#         hh_ids  unique_hhs first_trx_date_hh last_trx_date_hh  \
# 11736  KMOMK03         NaN         07sep2012        25oct2013
#
#        tot_hh_daysofobs  tot_hh_monthsofobs interview_designation   int_date  \
# 11736               413                  14                 03=Q3  29sep2012
#
#        int_month  int_year int_yr_mo first_int_date        account_ids  \
# 11736          9      2012   2012_09      01sep2012  61134770551400000
#
#        unique_accnts        m_ids_owner  unique_hm_owner account_bsheet_desig  \
# 11736            1.0  61134406243400000              NaN            Liability
#
#       account_startclose_balance account_formal account_liquid  \
# 11736                      Start       Informal            NaN
#
#       first_trx_date_acc last_trx_date_acc  tot_acc_daysofobs  \
# 11736          29sep2012         29sep2012                  0
#
#        tot_acc_monthsofobs             trx_id          m_ids_trx   trx_date  \
# ...

# %%
friends_family_borrowing.loc[friends_family_borrowing['account_ids']=='57136574022700000']
# Out:
#          hh_ids  unique_hhs first_trx_date_hh last_trx_date_hh  \
# 1777    KMOMM18         NaN         04sep2012        28sep2013
# 12097   KMOMM18         NaN         04sep2012        28sep2013
# 16611   KMOMM18         NaN         04sep2012        28sep2013
# 473350  KMOMM18         NaN         04sep2012        28sep2013
# 473354  KMOMM18         NaN         04sep2012        28sep2013
# 473553  KMOMM18         NaN         04sep2012        28sep2013
# 473724  KMOMM18         NaN         04sep2012        28sep2013
# 474120  KMOMM18         NaN         04sep2012        28sep2013
# 474136  KMOMM18         NaN         04sep2012        28sep2013
# 474908  KMOMM18         NaN         04sep2012        28sep2013
# 474910  KMOMM18         NaN         04sep2012        28sep2013
# 475029  KMOMM18         NaN         04sep2012        28sep2013
# 475575  KMOMM18         NaN         04sep2012        28sep2013
# 475990  KMOMM18         NaN         04sep2012        28sep2013
# ...

# %%
x = friends_family_borrowing.loc[friends_family_borrowing['account_ids']=='63134735712400000'].copy()

# %%
x.sort_values("trx_stdtime_days_acc", inplace=True)

# %%
x
# Out:
#          hh_ids  unique_hhs first_trx_date_hh last_trx_date_hh  \
# 6361    KMAKE29         NaN         14sep2012        02oct2013
# 414307  KMAKE29         NaN         14sep2012        02oct2013
# 41597   KMAKE29         NaN         14sep2012        02oct2013
# 4382    KMAKE29         NaN         14sep2012        02oct2013
#
#         tot_hh_daysofobs  tot_hh_monthsofobs  interview_designation  \
# 6361                 383                  13                  03=Q3
# 414307               383                  13   04=Diaries Interview
# 41597                383                  13   04=Diaries Interview
# 4382                 383                  13  06=Cleaning interview
#
#          int_date  int_month  int_year int_yr_mo first_int_date  \
# 6361    25sep2012          9      2012   2012_09      28aug2012
# 414307  20nov2012         11      2012   2012_11      28aug2012
# 41597   07jan2013          1      2013   2013_01      28aug2012
# ...
