# %%
import os
import pandas as pd 
import glob
import random 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Goal: Truncate loans at appropriate places; perhaps using new borrowing as a place to start?

# %%
trx = pd.read_csv('../diaries_transactions_all.csv', low_memory=False)

# %%
trx.columns
# Out:
# Index(['hh_ids', 'unique_hhs', 'first_trx_date_hh', 'last_trx_date_hh',
#        'tot_hh_daysofobs', 'tot_hh_monthsofobs', 'interview_designation',
#        'int_date', 'int_month', 'int_year', 'int_yr_mo', 'first_int_date',
#        'account_ids', 'unique_accnts', 'm_ids_owner', 'unique_hm_owner',
#        'account_bsheet_desig', 'account_startclose_balance', 'account_formal',
#        'account_liquid', 'first_trx_date_acc', 'last_trx_date_acc',
#        'tot_acc_daysofobs', 'tot_acc_monthsofobs', 'trx_id', 'm_ids_trx',
#        'trx_date', 'trx_month', 'trx_year', 'trx_yr_mo', 'trx_dq_round',
#        'trx_stdtime_days_hh', 'trx_stdtime_mnths_hh', 'trx_stdtime_days_acc',
#        'trx_stdtime_mnths_acc', 'trx_class_code', 'trx_class_desc',
#        'trx_family_code', 'trx_family_desc', 'trx_type_code', 'trx_type_desc',
#        'trx_prx_purpose', 'trx_prx_purpose_fd', 'trx_fee',
#        'trx_bsheet_direction', 'trx_mode_code', 'trx_mode_desc',
#        'trx_place_incommunity', 'trx_distance_km', 'trx_outlet',
#        'trx_direction', 'trx_value_kes', 'trx_value_usd', 'ddd_gift',
#        'trx_inkind_units', 'trx_inkind_value_usd', 'trx_inkind_value_kes',
#        'trx_stdtime_mnths_hh_nr'],
#       dtype='object')

# %%
pd.set_option('display.max_columns',200)

# %% [markdown]
# ### Subset to Formal Loans:

# %%
frmln_trx = trx.loc[trx['trx_family_code']=='FRMLN']
frmln_trx.shape
# Out:
# (1429, 58)

# %% [markdown]
# #### How many individual business or agriculture loans are there?

# %%
frmln_trx.loc[frmln_trx['unique_accnts']==1].trx_type_desc.value_counts()
# Out:
# Individual Business or Agriculture Loan      48
# Consumer/ personal loan (not payday loan)    33
# Hire Purchase                                24
# Joint liability loan                         21
# M-SHWARI Loan                                14
# School Fees Loan                             12
# Payday loan                                   2
# Credit card (including store card)            2
# Group Enterprise Loan                         2
# Student loan                                  1
# Name: trx_type_desc, dtype: int64

# %%
frmln_trx.loc[frmln_trx['unique_accnts']==1].trx_type_code.value_counts()
# Out:
# 2760    48
# 2762    33
# 3398    24
# 3247    21
# 4219    14
# 3397    12
# 2761     2
# 2746     2
# 3502     2
# 2759     1
# Name: trx_type_code, dtype: int64

# %% [markdown]
# #### Subset to only those formal loans of business or agriculture:

# %%
bus_ag_trx = frmln_trx.loc[frmln_trx['trx_type_code']==2760]

# %%
bus_ag_trx.shape
# Out:
# (442, 58)

# %%
bus_ag_trx.loc[bus_ag_trx['unique_accnts']==1].shape
# Out:
# (48, 58)

# %%
unique_accnt_ids = bus_ag_trx.loc[bus_ag_trx['unique_accnts']==1].account_ids

# %%
len(unique_accnt_ids)
# Out:
# 48

# %% [markdown]
# ## Cycle through loans, calculating the evolution of balance:

# %%
bus_ag_trx.shape
# Out:
# (442, 58)

# %%
bal_evol_df = pd.DataFrame()

# %%
for idx, acct_id in enumerate(list(unique_accnt_ids)):
    print(idx, acct_id)
    loan_df = bus_ag_trx.loc[bus_ag_trx['account_ids']==acct_id]    
    loan_df = loan_df.copy()
    loan_df.sort_values("trx_stdtime_days_acc", inplace=True)
    for index, row in loan_df.iterrows():
        if loan_df.loc[index,"trx_bsheet_direction"]=="Increase":
            loan_df.at[index,"trx_val_dir"] = loan_df.loc[index,"trx_value_kes"]
        elif loan_df.loc[index,"trx_bsheet_direction"]=="Decrease":
            loan_df.at[index,"trx_val_dir"] = -loan_df.loc[index,"trx_value_kes"]
        else:
            print("Error neither increase nor decrease at index" + str(index))
    print(loan_df.shape) 
    if loan_df.shape[0] > 1: 
        loan_df.insert(loan_df.shape[1],"bal_evol",np.zeros(loan_df.shape[0]))
        s=0
        for index,row in loan_df.iterrows():
            s+=loan_df.loc[index,"trx_val_dir"]
            loan_df.at[index,"bal_evol"]=s
    else: 
        print('Loan has only 1 entry for %s' %acct_id)
    
    bal_evol_df = bal_evol_df.append(loan_df, ignore_index = True)
# Out:
# 0 105136540140100000
# Error neither increase nor decrease at index19299
# (9, 59)
# 1 105137049319900000
# Error neither increase nor decrease at index3193
# (6, 59)
# 2 56134798164800000
# Error neither increase nor decrease at index1078
# (9, 59)
# 3 59134666467600000
# Error neither increase nor decrease at index19693
# (22, 59)
# 4 60136436488300000
# Error neither increase nor decrease at index17802
# (9, 59)
# 5 60134752045800000
# Error neither increase nor decrease at index20002
# (8, 59)
# 6 60134787021500000
# Error neither increase nor decrease at index15364
# (2, 59)
# 7 84136514083500000
# Error neither increase nor decrease at index5632
# (1, 58)
# Loan has only 1 entry for 84136514083500000
# 8 59134752569200000
# Error neither increase nor decrease at index19873
# Error neither increase nor decrease at index24068
# (14, 59)
# 9 60137430710900000
# Error neither increase nor decrease at index27
# (6, 59)
# 10 84136879000800000
# Error neither increase nor decrease at index9403
# (9, 59)
# 11 60138558075900000
# Error neither increase nor decrease at index6257
# (2, 59)
# 12 59134942516400000
# Error neither increase nor decrease at index6641
# (8, 59)
# 13 61134770676600000
# Error neither increase nor decrease at index5453
# (18, 59)
# 14 59135021173400000
# Error neither increase nor decrease at index3716
# (4, 59)
# 15 59134727113000000
# Error neither increase nor decrease at index3378
# (2, 59)
# 16 105137629836900000
# Error neither increase nor decrease at index17639
# (4, 59)
# 17 105137636847800000
# Error neither increase nor decrease at index21998
# (5, 59)
# 18 59134691680100000
# (12, 59)
# 19 59134726342000000
# Error neither increase nor decrease at index1956
# (15, 59)
# 20 59134942469700000
# Error neither increase nor decrease at index21202
# (16, 59)
# 21 56134761927800000
# Error neither increase nor decrease at index1340
# (9, 59)
# 22 105136910664600000
# Error neither increase nor decrease at index24917
# (5, 59)
# 23 60134978362300000
# Error neither increase nor decrease at index14332
# (27, 59)
# 24 58134763288300000
# Error neither increase nor decrease at index5203
# (10, 59)
# 25 59136376033300000
# Error neither increase nor decrease at index38535
# Error neither increase nor decrease at index4027
# (13, 59)
# 26 59135332895300000
# Error neither increase nor decrease at index15424
# (13, 59)
# 27 105137395238900000
# Error neither increase nor decrease at index23238
# (15, 59)
# 28 60136500338400000
# (2, 59)
# 29 59135288408400000
# Error neither increase nor decrease at index177005
# Error neither increase nor decrease at index5984
# (4, 59)
# 30 60136531885600000
# Error neither increase nor decrease at index4005
# (5, 59)
# 31 59135900709000000
# Error neither increase nor decrease at index6802
# (6, 59)
# 32 59136386375100000
# Error neither increase nor decrease at index12641
# (11, 59)
# 33 59136685821800000
# Error neither increase nor decrease at index5750
# (23, 59)
# 34 60135893778700000
# Error neither increase nor decrease at index15825
# (6, 59)
# 35 111137291327800000
# Error neither increase nor decrease at index12980
# (7, 59)
# 36 59136861465600000
# Error neither increase nor decrease at index20951
# (8, 59)
# 37 56134752442400000
# Error neither increase nor decrease at index23986
# (16, 59)
# 38 62134821651800000
# Error neither increase nor decrease at index9179
# (17, 59)
# 39 56135201879700000
# Error neither increase nor decrease at index17446
# (4, 59)
# 40 59134753176900000
# (7, 59)
# 41 58134814374400000
# Error neither increase nor decrease at index22920
# (13, 59)
# 42 105137899512900000
# Error neither increase nor decrease at index20047
# (3, 59)
# 43 56135290200100000
# Error neither increase nor decrease at index11397
# (12, 59)
# 44 105137414874400000
# Error neither increase nor decrease at index5194
# (3, 59)
# 45 59134865220800000
# Error neither increase nor decrease at index24633
# Error neither increase nor decrease at index14442
# (14, 59)
# 46 59137629648900000
# Error neither increase nor decrease at index15503
# (6, 59)
# 47 105137769890900000
# Error neither increase nor decrease at index3304
# (2, 59)

# %%
bal_evol_df.head()
# Out:
#   account_bsheet_desig account_formal         account_ids account_liquid  \
# 0            Liability         Formal  105136540140100000            NaN
# 1            Liability         Formal  105136540140100000            NaN
# 2            Liability         Formal  105136540140100000            NaN
# 3            Liability         Formal  105136540140100000            NaN
# 4            Liability         Formal  105136540140100000            NaN
#
#   account_startclose_balance  bal_evol  ddd_gift first_int_date  \
# 0                      Start   18000.0         0      04sep2012
# 1                        NaN       0.0         0      04sep2012
# 2                        NaN   60000.0         0      04sep2012
# 3                        NaN   55000.0         0      04sep2012
# 4                        NaN   50000.0         0      04sep2012
#
#   first_trx_date_acc first_trx_date_hh   hh_ids   int_date  int_month  \
# 0          18mar2013         24sep2012  KELDK37  08apr2013          4
# 1          18mar2013         24sep2012  KELDK37  08apr2013          4
# 2          18mar2013         24sep2012  KELDK37  08apr2013          4
# 3          18mar2013         24sep2012  KELDK37  26sep2013          9
# 4          18mar2013         24sep2012  KELDK37  26sep2013          9
#
#    int_year int_yr_mo interview_designation last_trx_date_acc  \
# 0      2013   2013_04  04=Diaries Interview         04oct2013
# 1      2013   2013_04  04=Diaries Interview         04oct2013
# 2      2013   2013_04  04=Diaries Interview         04oct2013
# 3      2013   2013_09  04=Diaries Interview         04oct2013
# 4      2013   2013_09  04=Diaries Interview         04oct2013
#
#   last_trx_date_hh        m_ids_owner          m_ids_trx  tot_acc_daysofobs  \
# 0        30nov2013  65134432186900000  65134432186900000                200
# 1        30nov2013  65134432186900000  65134432186900000                200
# 2        30nov2013  65134432186900000  65134432186900000                200
# 3        30nov2013  65134432186900000  65134432186900000                200
# 4        30nov2013  65134432186900000  65134432186900000                200
#
#    tot_acc_monthsofobs  tot_hh_daysofobs  tot_hh_monthsofobs  \
# 0                    6               432                  14
# 1                    6               432                  14
# 2                    6               432                  14
# 3                    6               432                  14
# 4                    6               432                  14
#
#   trx_bsheet_direction trx_class_code  \
# 0             Increase         findev
# 1             Decrease         findev
# 2             Increase         findev
# 3             Decrease         findev
# 4             Decrease         findev
#
#                                       trx_class_desc   trx_date trx_direction  \
# 0  Borrowing, lending, savings or insurance media...  18mar2013           NaN
# 1  Borrowing, lending, savings or insurance media...  22mar2013       Outflow
# 2  Borrowing, lending, savings or insurance media...  05apr2013        Inflow
# 3  Borrowing, lending, savings or insurance media...  04jun2013       Outflow
# 4  Borrowing, lending, savings or insurance media...  04jul2013       Outflow
#
#    trx_distance_km  trx_dq_round trx_family_code trx_family_desc  trx_fee  \
# 0              NaN           6.0           FRMLN     Formal loan      0.0
# 1              NaN           6.0           FRMLN     Formal loan      0.0
# 2         8.651168           6.0           FRMLN     Formal loan      0.0
# 3         8.651168          17.0           FRMLN     Formal loan      0.0
# 4         8.651168          17.0           FRMLN     Formal loan      0.0
#
#                trx_id trx_inkind_units  trx_inkind_value_kes  \
# 0  105136540174100000              NaN                   NaN
# 1  105136540182500000              NaN                   NaN
# 2  105136540188600000              NaN                   NaN
# 3  105138433250900000              NaN                   NaN
# 4  105138433256800000              NaN                   NaN
#
#    trx_inkind_value_usd  trx_mode_code  \
# 0                   NaN           18.0
# 1                   NaN            3.0
# 2                   NaN            3.0
# 3                   NaN           13.0
# 4                   NaN           13.0
#
#                                trx_mode_desc  trx_month  \
# 0                           STARTING BALANCE          3
# 1  Transfer into bank, SACCO, or MFI account          3
# 2  Transfer into bank, SACCO, or MFI account          4
# 3                             Standing order          6
# 4                             Standing order          7
#
#                               trx_outlet  trx_place_incommunity  \
# 0                                    NaN                    NaN
# 1  01=Bank, MFI, SACCO, insurance branch                    NaN
# 2  01=Bank, MFI, SACCO, insurance branch                    0.0
# 3  01=Bank, MFI, SACCO, insurance branch                    0.0
# 4  01=Bank, MFI, SACCO, insurance branch                    0.0
#
#                trx_prx_purpose                    trx_prx_purpose_fd  \
# 0  1. Starting balance (today)                                   NaN
# 1                  3. Payments      Repayment on financial liability
# 2             2. New borrowing  New borrowing on financial liability
# 3                  3. Payments      Repayment on financial liability
# 4                  3. Payments      Repayment on financial liability
#
#    trx_stdtime_days_acc  trx_stdtime_days_hh  trx_stdtime_mnths_acc  \
# 0                     0                  175                      0
# 1                     4                  179                      0
# 2                    18                  193                      0
# 3                    78                  253                      2
# 4                   108                  283                      3
#
#    trx_stdtime_mnths_hh  trx_stdtime_mnths_hh_nr  trx_type_code  \
# 0                     6                 6.034483           2760
# 1                     6                 6.172414           2760
# 2                     6                 6.655172           2760
# 3                     8                 8.724138           2760
# 4                     9                 9.758620           2760
#
#                              trx_type_desc  trx_val_dir  trx_value_kes  \
# 0  Individual Business or Agriculture Loan      18000.0        18000.0
# 1  Individual Business or Agriculture Loan     -18000.0        18000.0
# 2  Individual Business or Agriculture Loan      60000.0        60000.0
# 3  Individual Business or Agriculture Loan      -5000.0         5000.0
# 4  Individual Business or Agriculture Loan      -5000.0         5000.0
#
#    trx_value_usd  trx_year trx_yr_mo  unique_accnts  unique_hhs  \
# 0      211.76470      2013   2013_03            1.0         NaN
# 1      211.76470      2013   2013_03            NaN         NaN
# 2      705.88230      2013   2013_04            NaN         NaN
# 3       58.82353      2013   2013_06            NaN         NaN
# 4       58.82353      2013   2013_07            NaN         NaN
#
#    unique_hm_owner
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %%
bal_evol_df.shape
# Out:
# (442, 60)

# %%
bal_evol_df.trx_prx_purpose.value_counts()
# Out:
# 3. Payments                                 301
# 6. Closing Balance--End of last DQ           47
# 2. New borrowing                             34
# 1. Starting balance (today)                  30
# 5. Interest accruing                         11
# DECREASE--Unexplained balance adjustment      7
# 4. Any known fees                             5
# INCREASE--Unexplained balance adjustment      5
# 7. Refund from lender                         2
# Name: trx_prx_purpose, dtype: int64

# %% [markdown]
# ## How many starting balances are zero?

# %%
bal_evol_df.loc[bal_evol_df['trx_prx_purpose']=="1. Starting balance (today)"].trx_val_dir.value_counts()
# Out:
# 0.0         6
# 338847.0    1
# 88000.0     1
# 3500.0      1
# 12000.0     1
# 16000.0     1
# 298000.0    1
# 148609.0    1
# 23000.0     1
# 20000.0     1
# 40340.0     1
# 108000.0    1
# 9500.0      1
# 18870.0     1
# 4300.0      1
# 1700.0      1
# 116000.0    1
# 5450.0      1
# 41000.0     1
# 100000.0    1
# 45000.0     1
# 341850.0    1
# 16400.0     1
# 126450.0    1
# 18000.0     1
# Name: trx_val_dir, dtype: int64

# %% [markdown]
# ## So, we can safely start with the "starting balance" for all but 6 loans.

# %% [markdown]
# ## For each loan with a starting balance of zero, we want to use the first "new borrowing" as the starting point and discard the rest:

# %%
for idx, acct_id in enumerate(list(unique_accnt_ids)):
    print(idx, acct_id)
    loan_df = bal_evol_df.loc[bal_evol_df['account_ids']==acct_id]    
    loan_df = loan_df.copy()
    loan_df.sort_values("trx_stdtime_days_acc", inplace=True)
    for index, row in loan_df.iterrows():
        if loan_df.loc[index,""]=="Increase":
            loan_df.at[index,"trx_val_dir"] = loan_df.loc[index,"trx_value_kes"]
        elif loan_df.loc[index,"trx_bsheet_direction"]=="Decrease":
            loan_df.at[index,"trx_val_dir"] = -loan_df.loc[index,"trx_value_kes"]
        else:
            print("Error neither increase nor decrease at index" + str(index))
    print(loan_df.shape) 
    if loan_df.shape[0] > 1: 
        loan_df.insert(loan_df.shape[1],"bal_evol",np.zeros(loan_df.shape[0]))
        s=0
        for index,row in loan_df.iterrows():
            s+=loan_df.loc[index,"trx_val_dir"]
            loan_df.at[index,"bal_evol"]=s
    else: 
        print('Loan has only 1 entry for %s' %acct_id)
    
    bal_evol_df = bal_evol_df.append(loan_df, ignore_index = True)
