# %%
import pandas as pd
import numpy as np
import math as math
import matplotlib.pyplot as plt
import seaborn as sns
import random
from scipy import stats
# %matplotlib inline

# %%
# to see all the columns when using head() or describe()
pd.set_option('display.max_columns',60)

# %%
df = pd.read_csv("diaries_trx_trunc_loans.csv", dtype={'account_startclose_balance': str,"account_ids":str, "new_account_ids":str})

# %% [markdown]
# ### Let's add a column to df that contains the information about the balance evolution. We just reuse the previous algorithm for this.

# %%
#add balance evolution to original dataset
df.insert(df.shape[1],"bal_evol",np.zeros(df.shape[0]))

# %%
#add column for starting balance 
df.insert(df.shape[1],"start_bal",np.zeros(df.shape[0]))

# %%
#see the purposes for which there is no increase or decrease
exc = set()
for acc in df["new_account_ids"].unique():
    lna = df[df["new_account_ids"]==acc]
    #we want the lna dataset with the new borrowing the first entry of the first day
    #we reuse the algorithm from the truncation program.
    # sort the dataset according to time
    i=0
    # we will use "indices" to save the reordered indices of the dataset for each unique loan
    indices = []
    # we will use "index_bor" to save the index of the new borrowing that happens on a given day,
    #whenever there were also other transactions (since we need that index to be first)
    index_bor = 0
    # sort the dataset according to time
    lna = lna.sort_values("trx_stdtime_days_acc")
    # for each day in the dataset of the account, we check whether there was 
    # a new borrowing or starting balance and if yes reorder
    for d in lna["trx_stdtime_days_acc"].unique():
        # if only one entry that day we just add the index to indices
        if lna[lna["trx_stdtime_days_acc"]==d].shape[0]==1:
            indices.append(lna[lna["trx_stdtime_days_acc"]==d].index[0])
        # if there are more than 1 entry that day
        elif lna[lna["trx_stdtime_days_acc"]==d].shape[0]>1:
            # if there are more than one new borrowings or starting balances, we need to check manually
            if lna[(lna["trx_stdtime_days_acc"]==d)&((lna["trx_prx_purpose"]=="2. New borrowing")|(lna["trx_prx_purpose"]=="2. New borrowinng (individual portion)")|(lna["trx_prx_purpose"]=="1. Starting balance (today)"))].shape[0]>1:
                print("Several new borrowings on day " + str(d) +", check manually account " + acc + " in category "+ str(lna["trx_type_code"].unique()))
            #if there is exactly one new borrowing or starting balance that day (here we will need to check for each loan type what they exactly call new borrowings)
            elif lna[(lna["trx_stdtime_days_acc"]==d)&((lna["trx_prx_purpose"]=="2. New borrowing")|(lna["trx_prx_purpose"]=="2. New borrowinng (individual portion)")|(lna["trx_prx_purpose"]=="1. Starting balance (today)"))].shape[0]==1:
                #for each type of new borrowing if there is one that day, put that index first into indices
                for kind in ["2. New borrowing","2. New borrowinng (individual portion)","1. Starting balance (today)"]:
                    if kind in lna[lna["trx_stdtime_days_acc"]==d]["trx_prx_purpose"].unique():
                        index_bor = lna[(lna["trx_stdtime_days_acc"]==d) & (lna["trx_prx_purpose"]==kind)].index[0]
                        indices.append(index_bor)
                        #then add all other indices of that day
                        for i in lna[lna["trx_stdtime_days_acc"]==d].index.drop(index_bor):
                            indices.append(i)
            # if there are several entries for that day but none of them new borrowings just add all indices of that day            
            else:
                for i in lna[lna["trx_stdtime_days_acc"]==d].index:
                    indices.append(i)
    # here we reindex the lna dataset
    lna = lna.loc[indices,]
    
    #add transaction with direction for account
    lna.insert(58, "trx_val_dir",np.zeros(lna.shape[0]))
    for index, row in lna.iterrows():
        if lna.loc[index,"trx_bsheet_direction"]=="Increase":
            lna.at[index,"trx_val_dir"] = lna.loc[index,"trx_value_kes"]
        elif lna.loc[index,"trx_bsheet_direction"]=="Decrease":
            lna.at[index,"trx_val_dir"] = -lna.loc[index,"trx_value_kes"]
        else:
            #save where there is neither increase nor decrease
            exc.add(row["trx_prx_purpose"])
    
    #add the balance evolution entries to df 
    s=0
    start_bal = lna.iloc[0,df.columns.get_loc("trx_value_kes")]
    for index,row in lna.iterrows():
        s+=lna.loc[index,"trx_val_dir"]
        df.at[index,"bal_evol"]=s
        df.at[index,"start_bal"]=start_bal
    #add the starting balance to df

# %%
exc
# Out:
# {'6. Closing Balance--End of last DQ',
#  '7. Closing Balance--End of last DQ',
#  '7. Refund from lender'}

# %% [markdown]
# ### The refund from lender seems to be a bit misterious, maybe we should also exclude that.

# %%
df["trx_prx_purpose"].value_counts()
# Out:
# 3. Payments                               1651
# 2. New borrowing                           787
# 7. Closing Balance--End of last DQ         697
# 1. Starting balance (today)                306
# 5. Interest accruing                       256
# 6. Closing Balance--End of last DQ          69
# 4. Any known fees                           32
# 6. Loan written off                         19
# 2. New borrowinng (individual portion)       4
# 6. Debt written off                          1
# 7. Refund from lender                        1
# Name: trx_prx_purpose, dtype: int64

# %%
df[df["trx_prx_purpose"]=="7. Refund from lender"]
# Out:
#       Unnamed: 0   hh_ids  unique_hhs first_trx_date_hh last_trx_date_hh  \
# 1426       38535  KVIHC30         NaN         14aug2012        25sep2013
#
#       tot_hh_daysofobs  tot_hh_monthsofobs  interview_designation   int_date  \
# 1426               407                  14  06=Cleaning interview  24sep2013
#
#       int_month  int_year int_yr_mo first_int_date        account_ids  \
# 1426          9      2013   2013_09      12sep2012  59136376033300000
#
#           new_account_ids  unique_accnts        m_ids_owner  unique_hm_owner  \
# 1426  59136376033300000.1            NaN  59134381215900000              NaN
#
#      account_bsheet_desig account_startclose_balance account_formal  \
# 1426            Liability                        NaN         Formal
#
#       account_liquid first_trx_date_acc last_trx_date_acc  tot_acc_daysofobs  \
# 1426             NaN          15jan2013         23sep2013                251
#
#       tot_acc_monthsofobs             trx_id          m_ids_trx   trx_date  \
# 1426                    8  34138708620100000  59134381215900000  01aug2013
#
#       trx_month    ...      trx_stdtime_days_hh trx_stdtime_mnths_hh  \
# 1426          8    ...                      352                   12
#
#       trx_stdtime_days_acc  trx_stdtime_mnths_acc  trx_class_code  \
# 1426                   198                      6          findev
#
#                                          trx_class_desc  trx_family_code  \
# 1426  Borrowing, lending, savings or insurance media...            FRMLN
#
#      trx_family_desc trx_type_code                            trx_type_desc  \
# 1426     Formal loan          2760  Individual Business or Agriculture Loan
#
#             trx_prx_purpose  trx_prx_purpose_fd trx_fee trx_bsheet_direction  \
# 1426  7. Refund from lender                 NaN     0.0                  NaN
#
#      trx_mode_code                              trx_mode_desc  \
# 1426          10.0  In-kind (trade, good, service--NOT MONEY)
#
#      trx_place_incommunity  trx_distance_km        trx_outlet  trx_direction  \
# 1426                   1.0              0.0  07=Group meeting         Inflow
#
#       trx_value_kes trx_value_usd ddd_gift  trx_inkind_units  \
# 1426          300.0      3.529412        0             panga
#
#       trx_inkind_value_usd  trx_inkind_value_kes trx_stdtime_mnths_hh_nr  \
# 1426              3.529412                 300.0                12.13793
#
#       acc_unexplained_trx  bal_evol  start_bal
# 1426                  0.0    2500.0     9500.0
#
# [1 rows x 63 columns]

# %%
df[df["account_ids"]=="59136376033300000"].sort_values("trx_stdtime_days_acc")
# Out:
#       Unnamed: 0   hh_ids  unique_hhs first_trx_date_hh last_trx_date_hh  \
# 2018      177769  KVIHC30         NaN         14aug2012        25sep2013
# 2159      212912  KVIHC30         NaN         14aug2012        25sep2013
# 2888      342023  KVIHC30         NaN         14aug2012        25sep2013
# 2408      257713  KVIHC30         NaN         14aug2012        25sep2013
# 2529      281215  KVIHC30         NaN         14aug2012        25sep2013
# 2409      257715  KVIHC30         NaN         14aug2012        25sep2013
# 1803      128169  KVIHC30         NaN         14aug2012        25sep2013
# 1942      160764  KVIHC30         NaN         14aug2012        25sep2013
# 2446      266625  KVIHC30         NaN         14aug2012        25sep2013
# 1954      163679  KVIHC30         NaN         14aug2012        25sep2013
# 1426       38535  KVIHC30         NaN         14aug2012        25sep2013
# 1566       67021  KVIHC30         NaN         14aug2012        25sep2013
# 264         4027  KVIHC30         NaN         14aug2012        25sep2013
#
#       tot_hh_daysofobs  tot_hh_monthsofobs  interview_designation   int_date  \
# 2018               407                  14  06=Cleaning interview  24sep2013
# 2159               407                  14  06=Cleaning interview  24sep2013
# 2888               407                  14  06=Cleaning interview  24sep2013
# 2408               407                  14  06=Cleaning interview  24sep2013
# 2529               407                  14  06=Cleaning interview  24sep2013
# 2409               407                  14  06=Cleaning interview  24sep2013
# 1803               407                  14  06=Cleaning interview  24sep2013
# 1942               407                  14   04=Diaries Interview  15jun2013
# 2446               407                  14   04=Diaries Interview  29jun2013
# 1954               407                  14   04=Diaries Interview  25jul2013
# 1426               407                  14  06=Cleaning interview  24sep2013
# 1566               407                  14  06=Cleaning interview  24sep2013
# 264                407                  14   04=Diaries Interview  23sep2013
#
#       int_month  int_year int_yr_mo first_int_date        account_ids  \
# 2018          9      2013   2013_09      12sep2012  59136376033300000
# 2159          9      2013   2013_09      12sep2012  59136376033300000
# 2888          9      2013   2013_09      12sep2012  59136376033300000
# 2408          9      2013   2013_09      12sep2012  59136376033300000
# 2529          9      2013   2013_09      12sep2012  59136376033300000
# 2409          9      2013   2013_09      12sep2012  59136376033300000
# 1803          9      2013   2013_09      12sep2012  59136376033300000
# 1942          6      2013   2013_06      12sep2012  59136376033300000
# 2446          6      2013   2013_06      12sep2012  59136376033300000
# 1954          7      2013   2013_07      12sep2012  59136376033300000
# 1426          9      2013   2013_09      12sep2012  59136376033300000
# 1566          9      2013   2013_09      12sep2012  59136376033300000
# 264           9      2013   2013_09      12sep2012  59136376033300000
#
#           new_account_ids  unique_accnts        m_ids_owner  unique_hm_owner  \
# 2018  59136376033300000.1            NaN  59134381215900000              NaN
# 2159  59136376033300000.1            NaN  59134381215900000              NaN
# 2888  59136376033300000.1            NaN  59134381215900000              NaN
# 2408  59136376033300000.1            NaN  59134381215900000              NaN
# 2529  59136376033300000.1            NaN  59134381215900000              NaN
# 2409  59136376033300000.1            NaN  59134381215900000              NaN
# 1803  59136376033300000.1            NaN  59134381215900000              NaN
# 1942  59136376033300000.1            1.0  59134381215900000              NaN
# 2446  59136376033300000.1            NaN  59134381215900000              NaN
# 1954  59136376033300000.1            NaN  59134381215900000              NaN
# 1426  59136376033300000.1            NaN  59134381215900000              NaN
# 1566  59136376033300000.1            NaN  59134381215900000              NaN
# 264   59136376033300000.1            NaN  59134381215900000              NaN
#
#      account_bsheet_desig account_startclose_balance account_formal  \
# 2018            Liability                        NaN         Formal
# 2159            Liability                        NaN         Formal
# 2888            Liability                        NaN         Formal
# 2408            Liability                        NaN         Formal
# 2529            Liability                        NaN         Formal
# 2409            Liability                        NaN         Formal
# 1803            Liability                        NaN         Formal
# 1942            Liability                        NaN         Formal
# 2446            Liability                        NaN         Formal
# 1954            Liability                        NaN         Formal
# 1426            Liability                        NaN         Formal
# 1566            Liability                        NaN         Formal
# 264             Liability                      Close         Formal
#
#       account_liquid first_trx_date_acc last_trx_date_acc  tot_acc_daysofobs  \
# 2018             NaN          15jan2013         23sep2013                251
# 2159             NaN          15jan2013         23sep2013                251
# 2888             NaN          15jan2013         23sep2013                251
# 2408             NaN          15jan2013         23sep2013                251
# 2529             NaN          15jan2013         23sep2013                251
# 2409             NaN          15jan2013         23sep2013                251
# 1803             NaN          15jan2013         23sep2013                251
# 1942             NaN          15jan2013         23sep2013                251
# 2446             NaN          15jan2013         23sep2013                251
# 1954             NaN          15jan2013         23sep2013                251
# 1426             NaN          15jan2013         23sep2013                251
# 1566             NaN          15jan2013         23sep2013                251
# 264              NaN          15jan2013         23sep2013                251
#
#       tot_acc_monthsofobs              trx_id          m_ids_trx   trx_date  \
# 2018                    8   34138708585300000  59134381215900000  15jan2013
# 2159                    8   34138708599100000  59134381215900000  18jan2013
# 2888                    8   34138708599100000  59134381215900000  25jan2013
# 2408                    8   34138708594100000  59134381215900000  01feb2013
# 2529                    8   34138708599100000  59134381215900000  15mar2013
# 2409                    8   34138708599100000  59134381215900000  15apr2013
# 1803                    8   34138708599100000  59134381215900000  10may2013
# 1942                    8  111137126424100000  59134381215900000  01jun2013
# 2446                    8  111137247923300000  59134381215900000  20jun2013
# 1954                    8   59137472381600000  59134381215900000  16jul2013
# 1426                    8   34138708620100000  59134381215900000  01aug2013
# 1566                    8   34138708589900000  59134381215900000  01aug2013
# 264                     8   59138168520600000  59134381215900000  23sep2013
#
#       trx_month    ...      trx_stdtime_days_hh trx_stdtime_mnths_hh  \
# 2018          1    ...                      154                    5
# 2159          1    ...                      157                    5
# 2888          1    ...                      164                    5
# 2408          2    ...                      171                    5
# 2529          3    ...                      213                    7
# 2409          4    ...                      244                    8
# 1803          5    ...                      269                    9
# 1942          6    ...                      291                   10
# 2446          6    ...                      310                   10
# 1954          7    ...                      336                   11
# 1426          8    ...                      352                   12
# 1566          8    ...                      352                   12
# 264           9    ...                      405                   13
#
#       trx_stdtime_days_acc  trx_stdtime_mnths_acc  trx_class_code  \
# 2018                     0                      0          findev
# 2159                     3                      0          findev
# 2888                    10                      0          findev
# 2408                    17                      0          findev
# 2529                    59                      2          findev
# 2409                    90                      3          findev
# 1803                   115                      3          findev
# 1942                   137                      4          findev
# 2446                   156                      5          findev
# 1954                   182                      6          findev
# 1426                   198                      6          findev
# 1566                   198                      6          findev
# 264                    251                      8          findev
#
#                                          trx_class_desc  trx_family_code  \
# 2018  Borrowing, lending, savings or insurance media...            FRMLN
# 2159  Borrowing, lending, savings or insurance media...            FRMLN
# 2888  Borrowing, lending, savings or insurance media...            FRMLN
# 2408  Borrowing, lending, savings or insurance media...            FRMLN
# 2529  Borrowing, lending, savings or insurance media...            FRMLN
# 2409  Borrowing, lending, savings or insurance media...            FRMLN
# 1803  Borrowing, lending, savings or insurance media...            FRMLN
# 1942  Borrowing, lending, savings or insurance media...            FRMLN
# 2446  Borrowing, lending, savings or insurance media...            FRMLN
# 1954  Borrowing, lending, savings or insurance media...            FRMLN
# 1426  Borrowing, lending, savings or insurance media...            FRMLN
# 1566  Borrowing, lending, savings or insurance media...            FRMLN
# 264   Borrowing, lending, savings or insurance media...            FRMLN
#
#      trx_family_desc trx_type_code                            trx_type_desc  \
# 2018     Formal loan          2760  Individual Business or Agriculture Loan
# 2159     Formal loan          2760  Individual Business or Agriculture Loan
# 2888     Formal loan          2760  Individual Business or Agriculture Loan
# 2408     Formal loan          2760  Individual Business or Agriculture Loan
# 2529     Formal loan          2760  Individual Business or Agriculture Loan
# 2409     Formal loan          2760  Individual Business or Agriculture Loan
# 1803     Formal loan          2760  Individual Business or Agriculture Loan
# 1942     Formal loan          2760  Individual Business or Agriculture Loan
# 2446     Formal loan          2760  Individual Business or Agriculture Loan
# 1954     Formal loan          2760  Individual Business or Agriculture Loan
# 1426     Formal loan          2760  Individual Business or Agriculture Loan
# 1566     Formal loan          2760  Individual Business or Agriculture Loan
# 264      Formal loan          2760  Individual Business or Agriculture Loan
#
#                          trx_prx_purpose  \
# 2018                    2. New borrowing
# 2159                         3. Payments
# 2888                         3. Payments
# 2408                         3. Payments
# 2529                         3. Payments
# 2409                         3. Payments
# 1803                         3. Payments
# 1942                         3. Payments
# 2446                         3. Payments
# 1954                         3. Payments
# 1426               7. Refund from lender
# 1566                         3. Payments
# 264   6. Closing Balance--End of last DQ
#
#                         trx_prx_purpose_fd trx_fee trx_bsheet_direction  \
# 2018  New borrowing on financial liability     0.0             Increase
# 2159      Repayment on financial liability     0.0             Decrease
# 2888      Repayment on financial liability     0.0             Decrease
# 2408      Repayment on financial liability     0.0             Decrease
# 2529      Repayment on financial liability     0.0             Decrease
# 2409      Repayment on financial liability     0.0             Decrease
# 1803      Repayment on financial liability     0.0             Decrease
# 1942      Repayment on financial liability     0.0             Decrease
# 2446      Repayment on financial liability     0.0             Decrease
# 1954      Repayment on financial liability     0.0             Decrease
# 1426                                   NaN     0.0                  NaN
# 1566      Repayment on financial liability     0.0             Decrease
# 264                                    NaN     0.0                  NaN
#
#      trx_mode_code                              trx_mode_desc  \
# 2018          10.0  In-kind (trade, good, service--NOT MONEY)
# 2159           1.0                                       Cash
# 2888           1.0                                       Cash
# 2408           1.0                                       Cash
# 2529           1.0                                       Cash
# 2409           1.0                                       Cash
# 1803           1.0                                       Cash
# 1942           1.0                                       Cash
# 2446           1.0                                       Cash
# 1954           1.0                                       Cash
# 1426          10.0  In-kind (trade, good, service--NOT MONEY)
# 1566           1.0                                       Cash
# 264           19.0                            CLOSING BALANCE
#
#      trx_place_incommunity  trx_distance_km  \
# 2018                   1.0              0.0
# 2159                   1.0              0.0
# 2888                   1.0              0.0
# 2408                   1.0              0.0
# 2529                   1.0              0.0
# 2409                   1.0              0.0
# 1803                   1.0              0.0
# 1942                   1.0              0.0
# 2446                   1.0              0.0
# 1954                   1.0              0.0
# 1426                   1.0              0.0
# 1566                   1.0              0.0
# 264                    NaN              NaN
#
#                                  trx_outlet  trx_direction  trx_value_kes  \
# 2018  01=Bank, MFI, SACCO, insurance branch         Inflow         9500.0
# 2159                       07=Group meeting        Outflow          200.0
# 2888                       07=Group meeting        Outflow          200.0
# 2408                       07=Group meeting        Outflow          500.0
# 2529                       07=Group meeting        Outflow          210.0
# 2409                       07=Group meeting        Outflow          500.0
# 1803                       07=Group meeting        Outflow          200.0
# 1942                       07=Group meeting        Outflow          200.0
# 2446                       07=Group meeting        Outflow         1500.0
# 1954                       07=Group meeting        Outflow         3490.0
# 1426                       07=Group meeting         Inflow          300.0
# 1566                       07=Group meeting        Outflow         2500.0
# 264                                     NaN            NaN            0.0
#
#      trx_value_usd ddd_gift         trx_inkind_units  trx_inkind_value_usd  \
# 2018    111.764700        0  Farm inputs, solar lamp            111.764700
# 2159      2.352941        0                      NaN                   NaN
# 2888      2.352941        0                      NaN                   NaN
# 2408      5.882353        0                      NaN                   NaN
# 2529      2.470588        0                      NaN                   NaN
# 2409      5.882353        0                      NaN                   NaN
# 1803      2.352941        0                      NaN                   NaN
# 1942      2.352941        0                      NaN                   NaN
# 2446     17.647060        0                      NaN                   NaN
# 1954     41.058820        0                      NaN                   NaN
# 1426      3.529412        0                    panga              3.529412
# 1566     29.411760        0                      NaN                   NaN
# 264       0.000000        0                      NaN                   NaN
#
#       trx_inkind_value_kes trx_stdtime_mnths_hh_nr  acc_unexplained_trx  \
# 2018                9500.0                5.310345                  0.0
# 2159                   NaN                5.413793                  0.0
# 2888                   NaN                5.655172                  0.0
# 2408                   NaN                5.896552                  0.0
# 2529                   NaN                7.344828                  0.0
# 2409                   NaN                8.413794                  0.0
# 1803                   NaN                9.275862                  0.0
# 1942                   NaN               10.034480                  0.0
# 2446                   NaN               10.689660                  0.0
# 1954                   NaN               11.586210                  0.0
# 1426                 300.0               12.137930                  0.0
# 1566                   NaN               12.137930                  0.0
# 264                    NaN               13.965520                  0.0
#
#       bal_evol  start_bal
# 2018    9500.0     9500.0
# 2159    9300.0     9500.0
# 2888    9100.0     9500.0
# 2408    8600.0     9500.0
# 2529    8390.0     9500.0
# 2409    7890.0     9500.0
# 1803    7690.0     9500.0
# 1942    7490.0     9500.0
# 2446    5990.0     9500.0
# 1954    2500.0     9500.0
# 1426    2500.0     9500.0
# 1566       0.0     9500.0
# 264        0.0     9500.0
#
# [13 rows x 63 columns]

# %% [markdown]
# ### I think that we can keep this loan as is, by just ignoring the "refund from lender" transaction.

# %% [markdown]
# # Checking if it worked properly.

# %%
for i in range(0,10):
    acc=random.choice(df["new_account_ids"].unique())
    df[df["new_account_ids"]==acc].sort_values("trx_stdtime_days_acc").plot(x="trx_stdtime_days_acc",y="bal_evol", title = acc,marker="o")
    plt.show()
    print(acc)
    display(df[df["new_account_ids"]==acc].sort_values("trx_stdtime_days_acc")[["trx_family_code","trx_type_desc","trx_stdtime_days_acc","trx_prx_purpose","trx_value_kes","bal_evol","start_bal"]])
    display(df[df["account_ids"]==acc[:-2]].sort_values("trx_stdtime_days_acc")[["trx_family_code","trx_type_desc","trx_stdtime_days_acc","trx_prx_purpose","trx_value_kes","bal_evol","start_bal"]])
# Out:
# 112137266202700000.1
#      trx_family_code                  trx_type_desc  trx_stdtime_days_acc  \
# 1555          INFP2P  Friends and family: Borrowing                     0
#
#        trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 1555  2. New borrowing          500.0     500.0      500.0
#      trx_family_code                  trx_type_desc  trx_stdtime_days_acc  \
# 1555          INFP2P  Friends and family: Borrowing                     0
#
#        trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 1555  2. New borrowing          500.0     500.0      500.0
# 59134804797500000.1
#      trx_family_code                     trx_type_desc  trx_stdtime_days_acc  \
# 232           INFP2P  Moneylender or Shylock Borrowing                     0
# 1670          INFP2P  Moneylender or Shylock Borrowing                    26
# 2271          INFP2P  Moneylender or Shylock Borrowing                    43
# 771           INFP2P  Moneylender or Shylock Borrowing                   346
#
#                          trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 232          1. Starting balance (today)          220.0     220.0      220.0
# 1670                         3. Payments          200.0      20.0      220.0
# 2271                         3. Payments           20.0       0.0      220.0
# 771   7. Closing Balance--End of last DQ            0.0       0.0      220.0
#      trx_family_code                     trx_type_desc  trx_stdtime_days_acc  \
# 232           INFP2P  Moneylender or Shylock Borrowing                     0
# 1670          INFP2P  Moneylender or Shylock Borrowing                    26
# 2271          INFP2P  Moneylender or Shylock Borrowing                    43
# 771           INFP2P  Moneylender or Shylock Borrowing                   346
#
#                          trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 232          1. Starting balance (today)          220.0     220.0      220.0
# 1670                         3. Payments          200.0      20.0      220.0
# 2271                         3. Payments           20.0       0.0      220.0
# 771   7. Closing Balance--End of last DQ            0.0       0.0      220.0
# 63137005793200000.1
#      trx_family_code                  trx_type_desc  trx_stdtime_days_acc  \
# 1660          INFP2P  Friends and family: Borrowing                     0
# 2966          INFP2P  Friends and family: Borrowing                     2
# 514           INFP2P  Friends and family: Borrowing                   124
#
#                          trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 1660                    2. New borrowing           40.0      40.0       40.0
# 2966                         3. Payments           40.0       0.0       40.0
# 514   7. Closing Balance--End of last DQ            0.0       0.0       40.0
#      trx_family_code                  trx_type_desc  trx_stdtime_days_acc  \
# 1660          INFP2P  Friends and family: Borrowing                     0
# 2966          INFP2P  Friends and family: Borrowing                     2
# 514           INFP2P  Friends and family: Borrowing                   124
#
#                          trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 1660                    2. New borrowing           40.0      40.0       40.0
# 2966                         3. Payments           40.0       0.0       40.0
# 514   7. Closing Balance--End of last DQ            0.0       0.0       40.0
# 57135784508700000.2
#      trx_family_code                  trx_type_desc  trx_stdtime_days_acc  \
# 3692          INFP2P  Friends and family: Borrowing                   106
# 3708          INFP2P  Friends and family: Borrowing                   130
#
#        trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 3692  2. New borrowing          500.0     500.0      500.0
# 3708       3. Payments          900.0    -400.0      500.0
#      trx_family_code                  trx_type_desc  trx_stdtime_days_acc  \
# 3720          INFP2P  Friends and family: Borrowing                     0
# 3692          INFP2P  Friends and family: Borrowing                   106
# 3708          INFP2P  Friends and family: Borrowing                   130
# 2846          INFP2P  Friends and family: Borrowing                   270
# 2845          INFP2P  Friends and family: Borrowing                   271
# 2895          INFP2P  Friends and family: Borrowing                   284
# 612           INFP2P  Friends and family: Borrowing                   285
#
#                          trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 3720                    2. New borrowing          400.0     400.0      400.0
# 3692                    2. New borrowing          500.0     500.0      500.0
# 3708                         3. Payments          900.0    -400.0      500.0
# 2846                    2. New borrowing          100.0     100.0      100.0
# 2845                    2. New borrowing          200.0     200.0      200.0
# 2895                         3. Payments          200.0       0.0      200.0
# 612   7. Closing Balance--End of last DQ          100.0       0.0      200.0
# 89137593971300000.1
#      trx_family_code                  trx_type_desc  trx_stdtime_days_acc  \
# 3254          INFP2P  Friends and family: Borrowing                     0
# 1576          INFP2P  Friends and family: Borrowing                    41
#
#        trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 3254  2. New borrowing        15000.0   15000.0    15000.0
# 1576       3. Payments        10000.0    5000.0    15000.0
#      trx_family_code                  trx_type_desc  trx_stdtime_days_acc  \
# 3254          INFP2P  Friends and family: Borrowing                     0
# 1576          INFP2P  Friends and family: Borrowing                    41
# 2094          INFP2P  Friends and family: Borrowing                    45
# 1735          INFP2P  Friends and family: Borrowing                    48
# 1589          INFP2P  Friends and family: Borrowing                    52
# 2973          INFP2P  Friends and family: Borrowing                    76
# 3253          INFP2P  Friends and family: Borrowing                    80
# 2693          INFP2P  Friends and family: Borrowing                    83
# 823           INFP2P  Friends and family: Borrowing                    87
# 3184          INFP2P  Friends and family: Borrowing                    87
#
#                          trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 3254                    2. New borrowing        15000.0   15000.0    15000.0
# 1576                         3. Payments        10000.0    5000.0    15000.0
# 2094                    2. New borrowing        10000.0   10000.0    10000.0
# 1735                         3. Payments        10000.0       0.0    10000.0
# 1589                    2. New borrowing        10000.0   10000.0    10000.0
# 2973                         3. Payments        15000.0   -5000.0    10000.0
# 3253                    2. New borrowing        15000.0   15000.0    15000.0
# 2693                         3. Payments        15000.0       0.0    15000.0
# 823   7. Closing Balance--End of last DQ        10000.0   10000.0    10000.0
# 3184                    2. New borrowing        10000.0   10000.0    10000.0
# 59136125228600000.2
#      trx_family_code                     trx_type_desc  trx_stdtime_days_acc  \
# 1000          INFGRP  Borrowing from an informal Group                   119
# 2687          INFGRP  Borrowing from an informal Group                   119
# 2706          INFGRP  Borrowing from an informal Group                   151
# 861           INFGRP  Borrowing from an informal Group                   235
# 969           INFGRP  Borrowing from an informal Group                   238
#
#                          trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 1000                5. Interest accruing         1680.0    2680.0     1000.0
# 2687                    2. New borrowing         1000.0    1000.0     1000.0
# 2706                         3. Payments         3000.0    -320.0     1000.0
# 861                 5. Interest accruing         1420.0    1100.0     1000.0
# 969   7. Closing Balance--End of last DQ         3600.0    1100.0     1000.0
#      trx_family_code                     trx_type_desc  trx_stdtime_days_acc  \
# 1793          INFGRP  Borrowing from an informal Group                     0
# 3460          INFGRP  Borrowing from an informal Group                    63
# 1000          INFGRP  Borrowing from an informal Group                   119
# 2687          INFGRP  Borrowing from an informal Group                   119
# 2706          INFGRP  Borrowing from an informal Group                   151
# 861           INFGRP  Borrowing from an informal Group                   235
# 969           INFGRP  Borrowing from an informal Group                   238
#
#                          trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 1793                    2. New borrowing         3000.0    3000.0     3000.0
# 3460                         3. Payments          500.0    2500.0     3000.0
# 1000                5. Interest accruing         1680.0    2680.0     1000.0
# 2687                    2. New borrowing         1000.0    1000.0     1000.0
# 2706                         3. Payments         3000.0    -320.0     1000.0
# 861                 5. Interest accruing         1420.0    1100.0     1000.0
# 969   7. Closing Balance--End of last DQ         3600.0    1100.0     1000.0
# 59135825372200000.2
#      trx_family_code                     trx_type_desc  trx_stdtime_days_acc  \
# 255           INFGRP  Borrowing from an informal Group                     9
# 996           INFGRP  Borrowing from an informal Group                     9
# 3536          INFGRP  Borrowing from an informal Group                     9
# 3537          INFGRP  Borrowing from an informal Group                     9
#
#            trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 255   5. Interest accruing          200.0    1200.0     1000.0
# 996   5. Interest accruing          200.0    1400.0     1000.0
# 3536      2. New borrowing         1000.0    1000.0     1000.0
# 3537           3. Payments          200.0    1200.0     1000.0
#      trx_family_code                     trx_type_desc  trx_stdtime_days_acc  \
# 2554          INFGRP  Borrowing from an informal Group                     0
# 1075          INFGRP  Borrowing from an informal Group                     0
# 255           INFGRP  Borrowing from an informal Group                     9
# 3536          INFGRP  Borrowing from an informal Group                     9
# 3537          INFGRP  Borrowing from an informal Group                     9
# 996           INFGRP  Borrowing from an informal Group                     9
# 256           INFGRP  Borrowing from an informal Group                    32
# 3443          INFGRP  Borrowing from an informal Group                    32
# 1635          INFGRP  Borrowing from an informal Group                    60
# 1667          INFGRP  Borrowing from an informal Group                    60
# 257           INFGRP  Borrowing from an informal Group                    60
# 2442          INFGRP  Borrowing from an informal Group                    60
# 2655          INFGRP  Borrowing from an informal Group                   120
# 3138          INFGRP  Borrowing from an informal Group                   120
# 2393          INFGRP  Borrowing from an informal Group                   151
# 1022          INFGRP  Borrowing from an informal Group                   151
# 2381          INFGRP  Borrowing from an informal Group                   151
# 2593          INFGRP  Borrowing from an informal Group                   158
# 1412          INFGRP  Borrowing from an informal Group                   181
# 3435          INFGRP  Borrowing from an informal Group                   213
# 1124          INFGRP  Borrowing from an informal Group                   261
#
#                          trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 2554                    2. New borrowing         1000.0    1000.0     1000.0
# 1075                5. Interest accruing          200.0    1200.0     1000.0
# 255                 5. Interest accruing          200.0    1200.0     1000.0
# 3536                    2. New borrowing         1000.0    1000.0     1000.0
# 3537                         3. Payments          200.0    1200.0     1000.0
# 996                 5. Interest accruing          200.0    1400.0     1000.0
# 256                 5. Interest accruing          200.0    1200.0     1000.0
# 3443                    2. New borrowing         1000.0    1000.0     1000.0
# 1635                         3. Payments          200.0    1000.0     1000.0
# 1667                         3. Payments         1000.0       0.0     1000.0
# 257                 5. Interest accruing          200.0    1200.0     1000.0
# 2442                    2. New borrowing         1000.0    1000.0     1000.0
# 2655                5. Interest accruing          400.0    2400.0     2000.0
# 3138                    2. New borrowing         2000.0    2000.0     2000.0
# 2393                         3. Payments         1200.0       0.0     1000.0
# 1022                5. Interest accruing          200.0    1200.0     1000.0
# 2381                    2. New borrowing         1000.0    1000.0     1000.0
# 2593                         3. Payments         2600.0   -2600.0     1000.0
# 1412                         3. Payments         1000.0   -3600.0     1000.0
# 3435                         3. Payments         2200.0   -5800.0     1000.0
# 1124  7. Closing Balance--End of last DQ            0.0   -5800.0     1000.0
# 89137832443000000.1
#      trx_family_code                  trx_type_desc  trx_stdtime_days_acc  \
# 2818          INFP2P  Friends and family: Borrowing                     0
# 2658          INFP2P  Friends and family: Borrowing                    12
# 675           INFP2P  Friends and family: Borrowing                    91
# 1005          INFP2P  Friends and family: Borrowing                    91
#
#                          trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 2818                    2. New borrowing          500.0     500.0      500.0
# 2658                         3. Payments          500.0       0.0      500.0
# 675   7. Closing Balance--End of last DQ            0.0       0.0      500.0
# 1005  7. Closing Balance--End of last DQ            0.0       0.0      500.0
#      trx_family_code                  trx_type_desc  trx_stdtime_days_acc  \
# 2818          INFP2P  Friends and family: Borrowing                     0
# 2658          INFP2P  Friends and family: Borrowing                    12
# 675           INFP2P  Friends and family: Borrowing                    91
# 1005          INFP2P  Friends and family: Borrowing                    91
#
#                          trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 2818                    2. New borrowing          500.0     500.0      500.0
# 2658                         3. Payments          500.0       0.0      500.0
# 675   7. Closing Balance--End of last DQ            0.0       0.0      500.0
# 1005  7. Closing Balance--End of last DQ            0.0       0.0      500.0
# 105136612141800000.5
#      trx_family_code                     trx_type_desc  trx_stdtime_days_acc  \
# 2112          INFGRP  Borrowing from an informal Group                    90
# 2297          INFGRP  Borrowing from an informal Group                    90
# 2326          INFGRP  Borrowing from an informal Group                    90
#
#        trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 2112       3. Payments          300.0    1700.0     2000.0
# 2297  2. New borrowing         2000.0    2000.0     2000.0
# 2326       3. Payments         1700.0       0.0     2000.0
#      trx_family_code                     trx_type_desc  trx_stdtime_days_acc  \
# 2171          INFGRP  Borrowing from an informal Group                     0
# 1701          INFGRP  Borrowing from an informal Group                    10
# 2166          INFGRP  Borrowing from an informal Group                    10
# 2161          INFGRP  Borrowing from an informal Group                    17
# 1789          INFGRP  Borrowing from an informal Group                    17
# 2103          INFGRP  Borrowing from an informal Group                    17
# 1615          INFGRP  Borrowing from an informal Group                    32
# 1695          INFGRP  Borrowing from an informal Group                    32
# 2889          INFGRP  Borrowing from an informal Group                    75
# 1653          INFGRP  Borrowing from an informal Group                    75
# 2762          INFGRP  Borrowing from an informal Group                    75
# 2112          INFGRP  Borrowing from an informal Group                    90
# 2326          INFGRP  Borrowing from an informal Group                    90
# 2297          INFGRP  Borrowing from an informal Group                    90
# 2678          INFGRP  Borrowing from an informal Group                   110
# 3102          INFGRP  Borrowing from an informal Group                   110
# 1304          INFGRP  Borrowing from an informal Group                   110
# 2243          INFGRP  Borrowing from an informal Group                   110
# 3002          INFGRP  Borrowing from an informal Group                   159
# 1981          INFGRP  Borrowing from an informal Group                   159
# 79            INFGRP  Borrowing from an informal Group                   179
#
#                          trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 2171                    2. New borrowing         6000.0    6000.0     6000.0
# 1701                5. Interest accruing          600.0    6600.0     6000.0
# 2166                         3. Payments         6600.0       0.0     6000.0
# 2161                         3. Payments          200.0       0.0      600.0
# 1789                         3. Payments          400.0     200.0      600.0
# 2103                    2. New borrowing          600.0     600.0      600.0
# 1615                         3. Payments         1700.0       0.0     1700.0
# 1695                    2. New borrowing         1700.0    1700.0     1700.0
# 2889                         3. Payments          300.0       0.0     2000.0
# 1653                         3. Payments         1700.0     300.0     2000.0
# 2762                    2. New borrowing         2000.0    2000.0     2000.0
# 2112                         3. Payments          300.0    1700.0     2000.0
# 2326                         3. Payments         1700.0       0.0     2000.0
# 2297                    2. New borrowing         2000.0    2000.0     2000.0
# 2678                         3. Payments         3000.0       0.0     9000.0
# 3102                    2. New borrowing         9000.0    9000.0     9000.0
# 1304                5. Interest accruing          900.0    9900.0     9000.0
# 2243                         3. Payments         6900.0    3000.0     9000.0
# 3002                         3. Payments         3000.0     400.0     3400.0
# 1981                    2. New borrowing         3400.0    3400.0     3400.0
# 79    7. Closing Balance--End of last DQ          400.0     400.0     3400.0
# 105136867772400000.2
#      trx_family_code                     trx_type_desc  trx_stdtime_days_acc  \
# 2685          INFGRP  Borrowing from an informal Group                    64
# 2887          INFGRP  Borrowing from an informal Group                    66
# 1928          INFGRP  Borrowing from an informal Group                    73
# 2074          INFGRP  Borrowing from an informal Group                   103
# 1585          INFGRP  Borrowing from an informal Group                   138
#
#        trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 2685  2. New borrowing        30000.0   30000.0    30000.0
# 2887       3. Payments        13800.0   16200.0    30000.0
# 1928       3. Payments         7200.0    9000.0    30000.0
# 2074       3. Payments         7200.0    1800.0    30000.0
# 1585       3. Payments        12500.0  -10700.0    30000.0
#      trx_family_code                     trx_type_desc  trx_stdtime_days_acc  \
# 165           INFGRP  Borrowing from an informal Group                     0
# 1110          INFGRP  Borrowing from an informal Group                    35
# 2077          INFGRP  Borrowing from an informal Group                    35
# 2685          INFGRP  Borrowing from an informal Group                    64
# 2887          INFGRP  Borrowing from an informal Group                    66
# 1928          INFGRP  Borrowing from an informal Group                    73
# 2074          INFGRP  Borrowing from an informal Group                   103
# 1585          INFGRP  Borrowing from an informal Group                   138
# 3039          INFGRP  Borrowing from an informal Group                   164
# 1379          INFGRP  Borrowing from an informal Group                   178
#
#                          trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 165          1. Starting balance (today)        17000.0   17000.0    17000.0
# 1110                5. Interest accruing         2500.0   19500.0    17000.0
# 2077                         3. Payments         8000.0   11500.0    17000.0
# 2685                    2. New borrowing        30000.0   30000.0    30000.0
# 2887                         3. Payments        13800.0   16200.0    30000.0
# 1928                         3. Payments         7200.0    9000.0    30000.0
# 2074                         3. Payments         7200.0    1800.0    30000.0
# 1585                         3. Payments        12500.0  -10700.0    30000.0
# 3039                    2. New borrowing        30000.0   30000.0    30000.0
# 1379  7. Closing Balance--End of last DQ        30800.0   30000.0    30000.0

# %%
st_b=[]
print(st_b)
for acc in df["new_account_ids"].unique():
    if len(df[df["new_account_ids"]==acc]["start_bal"].unique())==1:
        st_b.append(df[df["new_account_ids"]==acc]["start_bal"].unique()[0])
    else:
        print("Error")
st_b[0:10]
# Out:
# []
# [3000.0,
#  100.0,
#  100000.0,
#  1000.0,
#  400.0,
#  16800.0,
#  8000.0,
#  500.0,
#  1000.0,
#  1200.0]

# %%
stats.percentileofscore(st_b,10)
# Out:
# 4.235090751944685

# %% [markdown]
# ### Let's look at some of the loans that are below 1000 KES.

# %%
count = 0
for i in range(0,10):
    acc=random.choice(df[df["start_bal"]<1000]["new_account_ids"].unique())
    df[df["new_account_ids"]==acc].sort_values("trx_stdtime_days_acc").plot(x="trx_stdtime_days_acc",y="bal_evol", title = acc,marker="o")
    plt.show()
    print(acc)
    display(df[df["new_account_ids"]==acc].sort_values("trx_stdtime_days_acc")[["trx_family_code","trx_type_desc","trx_stdtime_days_acc","trx_prx_purpose","trx_value_kes","bal_evol","start_bal"]])
    display(df[df["account_ids"]==acc[:-2]].sort_values("trx_stdtime_days_acc")[["trx_family_code","trx_type_desc","trx_stdtime_days_acc","trx_prx_purpose","trx_value_kes","bal_evol","start_bal"]])
# Out:
# 105138001256100000.1
#      trx_family_code                  trx_type_desc  trx_stdtime_days_acc  \
# 2038          INFP2P  Friends and family: Borrowing                     0
# 958           INFP2P  Friends and family: Borrowing                     4
#
#                          trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 2038                    2. New borrowing          550.0     550.0      550.0
# 958   7. Closing Balance--End of last DQ          550.0     550.0      550.0
#      trx_family_code                  trx_type_desc  trx_stdtime_days_acc  \
# 2038          INFP2P  Friends and family: Borrowing                     0
# 958           INFP2P  Friends and family: Borrowing                     4
#
#                          trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 2038                    2. New borrowing          550.0     550.0      550.0
# 958   7. Closing Balance--End of last DQ          550.0     550.0      550.0
# 57134676088100000.1
#      trx_family_code                  trx_type_desc  trx_stdtime_days_acc  \
# 743           INFP2P  Friends and family: Borrowing                     0
# 2105          INFP2P  Friends and family: Borrowing                    27
# 1926          INFP2P  Friends and family: Borrowing                   162
# 1288          INFP2P  Friends and family: Borrowing                   391
#
#                          trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 743          1. Starting balance (today)          500.0     500.0      500.0
# 2105                         3. Payments          300.0     200.0      500.0
# 1926                         3. Payments          200.0       0.0      500.0
# 1288  7. Closing Balance--End of last DQ            0.0       0.0      500.0
#      trx_family_code                  trx_type_desc  trx_stdtime_days_acc  \
# 743           INFP2P  Friends and family: Borrowing                     0
# 2105          INFP2P  Friends and family: Borrowing                    27
# 1926          INFP2P  Friends and family: Borrowing                   162
# 1288          INFP2P  Friends and family: Borrowing                   391
#
#                          trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 743          1. Starting balance (today)          500.0     500.0      500.0
# 2105                         3. Payments          300.0     200.0      500.0
# 1926                         3. Payments          200.0       0.0      500.0
# 1288  7. Closing Balance--End of last DQ            0.0       0.0      500.0
# 57137828400900000.0
#     trx_family_code                  trx_type_desc  trx_stdtime_days_acc  \
# 783          INFP2P  Friends and family: Borrowing                     0
#
#                         trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 783  7. Closing Balance--End of last DQ            0.0       0.0        0.0
#     trx_family_code                  trx_type_desc  trx_stdtime_days_acc  \
# 783          INFP2P  Friends and family: Borrowing                     0
#
#                         trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 783  7. Closing Balance--End of last DQ            0.0       0.0        0.0
# 60138558075900000.1
#     trx_family_code                            trx_type_desc  \
# 670           FRMLN  Individual Business or Agriculture Loan
# 404           FRMLN  Individual Business or Agriculture Loan
#
#      trx_stdtime_days_acc                     trx_prx_purpose  trx_value_kes  \
# 670                     0         1. Starting balance (today)            0.0
# 404                    87  6. Closing Balance--End of last DQ            0.0
#
#      bal_evol  start_bal
# 670       0.0        0.0
# 404       0.0        0.0
#     trx_family_code                            trx_type_desc  \
# 670           FRMLN  Individual Business or Agriculture Loan
# 404           FRMLN  Individual Business or Agriculture Loan
#
#      trx_stdtime_days_acc                     trx_prx_purpose  trx_value_kes  \
# 670                     0         1. Starting balance (today)            0.0
# 404                    87  6. Closing Balance--End of last DQ            0.0
#
#      bal_evol  start_bal
# 670       0.0        0.0
# 404       0.0        0.0
# 57136471645300000.0
#      trx_family_code                  trx_type_desc  trx_stdtime_days_acc  \
# 1023          INFP2P  Friends and family: Borrowing                     0
#
#                          trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 1023  7. Closing Balance--End of last DQ            0.0       0.0        0.0
#      trx_family_code                  trx_type_desc  trx_stdtime_days_acc  \
# 1023          INFP2P  Friends and family: Borrowing                     0
#
#                          trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 1023  7. Closing Balance--End of last DQ            0.0       0.0        0.0
# 59134692335200000.0
#     trx_family_code                  trx_type_desc  trx_stdtime_days_acc  \
# 210          INFP2P  Friends and family: Borrowing                     0
#
#                         trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 210  7. Closing Balance--End of last DQ            0.0       0.0        0.0
#     trx_family_code                  trx_type_desc  trx_stdtime_days_acc  \
# 210          INFP2P  Friends and family: Borrowing                     0
#
#                         trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 210  7. Closing Balance--End of last DQ            0.0       0.0        0.0
# 57137326394200000.1
#      trx_family_code                  trx_type_desc  trx_stdtime_days_acc  \
# 2582          INFP2P  Friends and family: Borrowing                     0
# 2148          INFP2P  Friends and family: Borrowing                     8
# 2610          INFP2P  Friends and family: Borrowing                    16
# 115           INFP2P  Friends and family: Borrowing                    98
#
#                          trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 2582                    2. New borrowing           80.0      80.0       80.0
# 2148                         3. Payments           50.0      30.0       80.0
# 2610                         3. Payments           30.0       0.0       80.0
# 115   7. Closing Balance--End of last DQ            0.0       0.0       80.0
#      trx_family_code                  trx_type_desc  trx_stdtime_days_acc  \
# 2582          INFP2P  Friends and family: Borrowing                     0
# 2148          INFP2P  Friends and family: Borrowing                     8
# 2610          INFP2P  Friends and family: Borrowing                    16
# 115           INFP2P  Friends and family: Borrowing                    98
#
#                          trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 2582                    2. New borrowing           80.0      80.0       80.0
# 2148                         3. Payments           50.0      30.0       80.0
# 2610                         3. Payments           30.0       0.0       80.0
# 115   7. Closing Balance--End of last DQ            0.0       0.0       80.0
# 89137049065100000.1
#      trx_family_code                  trx_type_desc  trx_stdtime_days_acc  \
# 3266          INFP2P  Friends and family: Borrowing                     0
# 1459          INFP2P  Friends and family: Borrowing                    25
# 615           INFP2P  Friends and family: Borrowing                   145
#
#                          trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 3266                    2. New borrowing          100.0     100.0      100.0
# 1459                         3. Payments          100.0       0.0      100.0
# 615   7. Closing Balance--End of last DQ            0.0       0.0      100.0
#      trx_family_code                  trx_type_desc  trx_stdtime_days_acc  \
# 3266          INFP2P  Friends and family: Borrowing                     0
# 1459          INFP2P  Friends and family: Borrowing                    25
# 615           INFP2P  Friends and family: Borrowing                   145
#
#                          trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 3266                    2. New borrowing          100.0     100.0      100.0
# 1459                         3. Payments          100.0       0.0      100.0
# 615   7. Closing Balance--End of last DQ            0.0       0.0      100.0
# 63137692650400000.1
#      trx_family_code                  trx_type_desc  trx_stdtime_days_acc  \
# 3093          INFP2P  Friends and family: Borrowing                     0
# 565           INFP2P  Friends and family: Borrowing                    41
#
#                          trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 3093                    2. New borrowing          400.0     400.0      400.0
# 565   7. Closing Balance--End of last DQ          400.0     400.0      400.0
#      trx_family_code                  trx_type_desc  trx_stdtime_days_acc  \
# 3093          INFP2P  Friends and family: Borrowing                     0
# 565           INFP2P  Friends and family: Borrowing                    41
#
#                          trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 3093                    2. New borrowing          400.0     400.0      400.0
# 565   7. Closing Balance--End of last DQ          400.0     400.0      400.0
# 61135780914500000.3
#      trx_family_code                  trx_type_desc  trx_stdtime_days_acc  \
# 3805          INFP2P  Friends and family: Borrowing                    39
#
#        trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 3805  2. New borrowing          100.0     100.0      100.0
#      trx_family_code                  trx_type_desc  trx_stdtime_days_acc  \
# 3804          INFP2P  Friends and family: Borrowing                     0
# 3806          INFP2P  Friends and family: Borrowing                    18
# 3805          INFP2P  Friends and family: Borrowing                    39
# 2525          INFP2P  Friends and family: Borrowing                    43
# 2206          INFP2P  Friends and family: Borrowing                   215
# 419           INFP2P  Friends and family: Borrowing                   280
#
#                          trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 3804                    2. New borrowing         1000.0    1000.0     1000.0
# 3806                    2. New borrowing          300.0     300.0      300.0
# 3805                    2. New borrowing          100.0     100.0      100.0
# 2525                    2. New borrowing          500.0     500.0      500.0
# 2206                    2. New borrowing          300.0     300.0      300.0
# 419   7. Closing Balance--End of last DQ         2200.0     300.0      300.0

# %%
df = df[df["start_bal"]>10]

# %%
df.to_csv("diaries_trx_trunc_loans_start_bal.csv")
