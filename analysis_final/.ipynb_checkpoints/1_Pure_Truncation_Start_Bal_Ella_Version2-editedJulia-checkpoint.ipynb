# %%
import pandas as pd
import numpy as np
import math as math
import matplotlib.pyplot as plt
import seaborn as sns
import random
# %matplotlib inline

# %%
# to see all the columns when using head() or describe()
pd.set_option('display.max_columns',60)

# %%
# df = pd.read_csv("kenya_data/diaries_transactions_all.csv", dtype={'account_startclose_balance': str})

# %%
df = pd.read_csv("../diaries_transactions_all.csv", dtype={'account_startclose_balance': str})

# %% [markdown]
# ## For now I keep only "business and agriculture loans", "joint liability loans", "personal loans", "borrowing from an informal group", "borrowing from family and friends", "shylock loans".

# %%
dfb = df[((df["trx_family_code"]=="FRMLN")&((df["trx_type_code"]==2760)|(df["trx_type_code"]==3247)|(df["trx_type_code"]==2762)))|((df["trx_family_code"]=="INFGRP")&(df["trx_type_code"]==3395))]

# %% [markdown]
# # 1. Get rid of loans of with unexplained balance adjustments

# %%
dfb["trx_prx_purpose"].unique()
# Out:
# array(['7. Closing Balance--End of last DQ',
#        '6. Closing Balance--End of last DQ',
#        '1. Starting balance (today)', '5. Interest accruing',
#        'DECREASE--Unexplained balance adjustment',
#        'INCREASE--Unexplained balance adjustment', '3. Payments',
#        '4. Any known fees', '2. New borrowinng (individual portion)',
#        '2. New borrowing', '7. Refund from lender'], dtype=object)

# %% [markdown]
# We insert a new column that is 0 if there is no unexplained balance adjustment for this account and a 1 if there is one. The column in 1 or 0 for all entries that correspond to that account.

# %%
dfb.insert(dfb.shape[1], "acc_unexplained_trx", np.zeros(dfb.shape[0]))

# %% [markdown]
# This program goes through all unique accounts, checks whether it has an unexplained balance adjustment and if yes sets the variable u to 1. Then it goes through another for-loop and sets the entries of that column 0 for all accounts that have an unexplained balance adjustment.

# %%
for acc in dfb["account_ids"].unique():
    u = 0
    for index,row in dfb[dfb["account_ids"]==acc].iterrows():
        if row["trx_prx_purpose"]=="DECREASE--Unexplained balance adjustment" or row["trx_prx_purpose"]=="INCREASE--Unexplained balance adjustment":
            u = 1
    for index,row in dfb[dfb["account_ids"]==acc].iterrows():
        dfb.at[index,"acc_unexplained_trx"] = u

# %% [markdown]
# ### Let us check if it worked.

# %%
s = set()
for acc in dfb[dfb["acc_unexplained_trx"]==0]["account_ids"].unique():
     for i in dfb[dfb["account_ids"]==acc]["trx_prx_purpose"].unique():
            s.add(i)
print(s)
# Out:
# {'7. Closing Balance--End of last DQ', '5. Interest accruing', '2. New borrowinng (individual portion)', '1. Starting balance (today)', '3. Payments', '7. Refund from lender', '2. New borrowing', '4. Any known fees', '6. Closing Balance--End of last DQ'}

# %% [markdown]
# ### "refund from lender" might be hard to deal with, but there are only 2 of those

# %%
dfb[dfb["trx_prx_purpose"]=="7. Refund from lender"]
# Out:
#          hh_ids  unique_hhs first_trx_date_hh last_trx_date_hh  \
# 38535   KVIHC30         NaN         14aug2012        25sep2013
# 177005  KVIHC13         NaN         08sep2012        30sep2013
#
#         tot_hh_daysofobs  tot_hh_monthsofobs  interview_designation  \
# 38535                407                  14  06=Cleaning interview
# 177005               387                  13  06=Cleaning interview
#
#          int_date  int_month  int_year int_yr_mo first_int_date  \
# 38535   24sep2013          9      2013   2013_09      12sep2012
# 177005  27sep2013          9      2013   2013_09      29aug2012
#
#               account_ids  unique_accnts        m_ids_owner  unique_hm_owner  \
# 38535   59136376033300000            NaN  59134381215900000              NaN
# 177005  59135288408400000            NaN                 HH              NaN
#
#        account_bsheet_desig account_startclose_balance account_formal  \
# 38535             Liability                        NaN         Formal
# 177005            Liability                        NaN         Formal
#
#        account_liquid first_trx_date_acc last_trx_date_acc  tot_acc_daysofobs  \
# 38535             NaN          15jan2013         23sep2013                251
# 177005            NaN          20dec2012         30sep2013                284
#
#         tot_acc_monthsofobs             trx_id          m_ids_trx   trx_date  \
# 38535                     8  34138708620100000  59134381215900000  01aug2013
# 177005                    9  60138608712700000  59134372493300000  16apr2013
#
#         trx_month  trx_year trx_yr_mo  trx_dq_round  trx_stdtime_days_hh  \
# 38535           8      2013   2013_08          19.0                  352
# 177005          4      2013   2013_04          20.0                  220
#
#         trx_stdtime_mnths_hh  trx_stdtime_days_acc  trx_stdtime_mnths_acc  \
# 38535                     12                   198                      6
# 177005                     7                   117                      4
#
#        trx_class_code                                     trx_class_desc  \
# 38535          findev  Borrowing, lending, savings or insurance media...
# 177005         findev  Borrowing, lending, savings or insurance media...
#
#        trx_family_code trx_family_desc  trx_type_code  \
# 38535            FRMLN     Formal loan           2760
# 177005           FRMLN     Formal loan           2760
#
#                                   trx_type_desc        trx_prx_purpose  \
# 38535   Individual Business or Agriculture Loan  7. Refund from lender
# 177005  Individual Business or Agriculture Loan  7. Refund from lender
#
#        trx_prx_purpose_fd  trx_fee trx_bsheet_direction  trx_mode_code  \
# 38535                 NaN      0.0                  NaN           10.0
# 177005                NaN      0.0                  NaN            1.0
#
#                                     trx_mode_desc  trx_place_incommunity  \
# 38535   In-kind (trade, good, service--NOT MONEY)                    1.0
# 177005                                       Cash                    1.0
#
#         trx_distance_km        trx_outlet trx_direction  trx_value_kes  \
# 38535               0.0  07=Group meeting        Inflow          300.0
# 177005              0.0  07=Group meeting        Inflow          200.0
#
#         trx_value_usd  ddd_gift trx_inkind_units  trx_inkind_value_usd  \
# 38535        3.529412         0            panga              3.529412
# 177005       2.352941         0              NaN                   NaN
#
#         trx_inkind_value_kes  trx_stdtime_mnths_hh_nr  acc_unexplained_trx
# 38535                  300.0                12.137930                  0.0
# 177005                   NaN                 7.586207                  1.0

# %% [markdown]
# # Let's now only use the loans that have no unexplained balance adjustments.

# %%
dfb = dfb[dfb["acc_unexplained_trx"]==0]

# %% [markdown]
# # 2. Truncation into chunks with no new borrowing

# %% [markdown]
# We first insert a column for the new account numbers. These will be like the old account numbers but with a .1 or .2 for each chunk after a new borrowing.

# %%
# this is sometimes necessary if we mess smt up
# del dfb["new_account_ids"]

# %%
# add column for new account ids
dfb.insert(df.columns.get_loc("account_ids")+1,"new_account_ids", ["-"]*(dfb.shape[0]))

# %%
#add balance evolution to original dataset
df.insert(df.shape[1],"bal_evol",np.zeros(df.shape[0]))

# %%
#add column for starting balance 
df.insert(df.shape[1],"start_bal",np.zeros(df.shape[0]))

# %% [markdown]
# ### Now let's adjust this such that new borrowings are always the first thing on one day, and then run the program that truncates into chunks with new borrowings.

# %%
exc=set()
accounts = []
for acc in dfb["account_ids"].unique():
    accounts.append(acc)
    i=0
    # we will use "indices" to save the reordered indices of the dataset for each unique loan
    indices = []
    # we will use "index_bor" to save the index of the new borrowing that happens on a given day,
    #whenever there were also other transactions (since we need that index to be first)
    index_bor = 0
    #only keep the rows of that account
    lna = dfb[dfb["account_ids"]==acc]
    # sort the dataset according to time
    lna = lna.sort_values("trx_stdtime_days_acc")
    # for each day in the dataset of the account, we check whether there was 
    # a new borrowing or starting balance and if yes reorder
    for d in lna["trx_stdtime_days_acc"].unique():
        # if only one entry that day we just add the index to indices
        if lna[lna["trx_stdtime_days_acc"]==d].shape[0]==1:
            indices.append(lna[lna["trx_stdtime_days_acc"]==d].index[0])
        # if there are more than 1 entry that day
        elif lna[lna["trx_stdtime_days_acc"]==d].shape[0]>1:
            # if there are more than one new borrowings or starting balances, we need to check manually
            if lna[(lna["trx_stdtime_days_acc"]==d)&((lna["trx_prx_purpose"]=="2. New borrowing")|(lna["trx_prx_purpose"]=="2. New borrowinng (individual portion)")|(lna["trx_prx_purpose"]=="1. Starting balance (today)"))].shape[0]>1:
                print("Several new borrowings on day " + str(d) +", check manually account " + acc + " in category "+ str(lna["trx_type_code"].unique()))
                for i in lna[lna["trx_stdtime_days_acc"]==d].index:
                            indices.append(i)
            #if there is exactly one new borrowing or starting balance that day (here we will need to check for each loan type what they exactly call new borrowings)
            elif lna[(lna["trx_stdtime_days_acc"]==d)&((lna["trx_prx_purpose"]=="2. New borrowing")|(lna["trx_prx_purpose"]=="2. New borrowinng (individual portion)")|(lna["trx_prx_purpose"]=="1. Starting balance (today)"))].shape[0]==1:
                #for each type of new borrowing if there is one that day, put that index first into indices
                for kind in ["2. New borrowing","2. New borrowinng (individual portion)","1. Starting balance (today)"]:
                    if kind in lna[lna["trx_stdtime_days_acc"]==d]["trx_prx_purpose"].unique():
                        index_bor = lna[(lna["trx_stdtime_days_acc"]==d) & (lna["trx_prx_purpose"]==kind)].index[0]
                        indices.append(index_bor)
                        #then add all other indices of that day
                        for i in lna[lna["trx_stdtime_days_acc"]==d].index.drop(index_bor):
                            indices.append(i)
            # if there are several entries for that day but none of them new borrowings just add all indices of that day            
            else:
                for i in lna[lna["trx_stdtime_days_acc"]==d].index:
                    indices.append(i)
    # here we reindex the lna dataset, so that each day the new borrowing is first
    lna = lna.loc[indices,]
    
    #add transaction with direction for account
    lna.insert(58, "trx_val_dir",np.zeros(lna.shape[0]))
    for index, row in lna.iterrows():
        if lna.loc[index,"trx_bsheet_direction"]=="Increase":
            lna.at[index,"trx_val_dir"] = lna.loc[index,"trx_value_kes"]
        elif lna.loc[index,"trx_bsheet_direction"]=="Decrease":
            lna.at[index,"trx_val_dir"] = -lna.loc[index,"trx_value_kes"]
        else:
            #save where there is neither increase nor decrease
            exc.add(row["trx_prx_purpose"])
    
    #add the balance evolution entries to df 
    s=0
    for index,row in lna.iterrows():
        s+=lna.loc[index,"trx_val_dir"]
        dfb.at[index,"bal_evol"]=s
    
    #truncating into chunks between new borrowings
    #v will be the index of the chunk we are currently at
    v=0
    # saving the old account number
    acc = lna["account_ids"].unique()[0]
    # a is the new account number for each chunk
    a = lna["account_ids"].unique()[0]+".0"
    #saving all account numbers we used
    accs = set()
    # we go through all rows of lna and change the entries of the column "new_account_ids" in the original dataset.
    for index, row in lna.iterrows():
        # if there is a new borrowing in the row, increase v by 1 and set a to acc.v
        if row["trx_prx_purpose"] == "1. Starting balance (today)" or row["trx_prx_purpose"] == "2. New borrowinng (individual portion)" or row["trx_prx_purpose"] == "2. New borrowing":
            v +=1
            a = acc+"."+str(v)
            dfb.at[index,"new_account_ids"]=a
            lna.at[index,"new_account_ids"]=a
            accs.add(a)
        # otherwise set the new account number in that row to a
        else:
            dfb.at[index,"new_account_ids"]=a
            lna.at[index,"new_account_ids"]=a
            accs.add(a)
            
    # adding starting balance to each new account
    # for each new account
    for a in accs:
        # restrict lna further to only that chunk
        lnaa = lna[lna["new_account_ids"]==a]
        #the starting balance is the first balance of that chunk
        st_bal = dfb.loc[lnaa.index[0],"bal_evol"]
        # assign that starting balance into each row corresponding to this accoun chunk
        for index in lnaa.index:
            dfb.at[index,"start_bal"]=st_bal
# Out:
# Several new borrowings on day 244, check manually account 61135946960100000 in category [3395]

# %% [markdown]
# Several borrowings on the same day.
#
# 61135946960100000

# %%
dfb[dfb["account_ids"]=="61135946960100000"].sort_values("trx_stdtime_days_acc")[["account_ids","new_account_ids","trx_stdtime_days_acc","trx_prx_purpose","trx_value_kes","trx_bsheet_direction","bal_evol","start_bal"]]
# Out:
#               account_ids      new_account_ids  trx_stdtime_days_acc  \
# 118905  61135946960100000  61135946960100000.1                     0
# 195059  61135946960100000  61135946960100000.1                     5
# 43429   61135946960100000  61135946960100000.2                   141
# 212855  61135946960100000  61135946960100000.3                   244
# 295268  61135946960100000  61135946960100000.4                   244
# 5052    61135946960100000  61135946960100000.4                   285
#
#                            trx_prx_purpose  trx_value_kes  \
# 118905                    2. New borrowing          500.0
# 195059                         3. Payments          500.0
# 43429                     2. New borrowing         2000.0
# 212855                    2. New borrowing         1300.0
# 295268                    2. New borrowing          500.0
# 5052    7. Closing Balance--End of last DQ         3800.0
#
#        trx_bsheet_direction  bal_evol  start_bal
# 118905             Increase     500.0      500.0
# 195059             Decrease       0.0      500.0
# 43429              Increase    2000.0     2000.0
# 212855             Increase    3300.0     3300.0
# 295268             Increase    3800.0     3800.0
# 5052                    NaN    3800.0     3800.0

# %% [markdown]
# The account 61135946960100000 seems to have several new borrowings on day 244.

# %% [markdown]
# With our new system we can still keep it.

# %% [markdown]
# ## Let's check if it worked.

# %% [markdown]
# Let's see if all accounts got a new name.

# %%
dfb[dfb["new_account_ids"]=="-"]
# Out:
# Empty DataFrame
# Columns: [hh_ids, unique_hhs, first_trx_date_hh, last_trx_date_hh, tot_hh_daysofobs, tot_hh_monthsofobs, interview_designation, int_date, int_month, int_year, int_yr_mo, first_int_date, account_ids, new_account_ids, unique_accnts, m_ids_owner, unique_hm_owner, account_bsheet_desig, account_startclose_balance, account_formal, account_liquid, first_trx_date_acc, last_trx_date_acc, tot_acc_daysofobs, tot_acc_monthsofobs, trx_id, m_ids_trx, trx_date, trx_month, trx_year, trx_yr_mo, trx_dq_round, trx_stdtime_days_hh, trx_stdtime_mnths_hh, trx_stdtime_days_acc, trx_stdtime_mnths_acc, trx_class_code, trx_class_desc, trx_family_code, trx_family_desc, trx_type_code, trx_type_desc, trx_prx_purpose, trx_prx_purpose_fd, trx_fee, trx_bsheet_direction, trx_mode_code, trx_mode_desc, trx_place_incommunity, trx_distance_km, trx_outlet, trx_direction, trx_value_kes, trx_value_usd, ddd_gift, trx_inkind_units, trx_inkind_value_usd, trx_inkind_value_kes, trx_stdtime_mnths_hh_nr, acc_unexplained_trx, bal_evol, start_bal]
# Index: []
#
# [0 rows x 62 columns]

# %% [markdown]
# ## Let's look at a few accounts to see if there are bugs.

# %%
for i in range(0,10):
    acc=random.choice(dfb["new_account_ids"].unique())
    dfb[dfb["new_account_ids"]==acc].sort_values("trx_stdtime_days_acc").plot(x="trx_stdtime_days_acc",y="bal_evol", title = acc,marker="o")
    plt.show()
    print(acc)
    display(dfb[dfb["new_account_ids"]==acc].sort_values("trx_stdtime_days_acc")[["trx_family_code","trx_type_desc","account_ids","new_account_ids","trx_stdtime_days_acc","trx_prx_purpose","trx_value_kes","bal_evol","start_bal"]])
    display(dfb[dfb["account_ids"]==acc[:-2]].sort_values("trx_stdtime_days_acc")[["trx_family_code","trx_type_desc","account_ids","new_account_ids","trx_stdtime_days_acc","trx_prx_purpose","trx_value_kes","bal_evol","start_bal"]])
# Out:
# 58134795341800000.1
#        trx_family_code                     trx_type_desc        account_ids  \
# 132819          INFGRP  Borrowing from an informal Group  58134795341800000
# 336793          INFGRP  Borrowing from an informal Group  58134795341800000
# 25140           INFGRP  Borrowing from an informal Group  58134795341800000
# 14131           INFGRP  Borrowing from an informal Group  58134795341800000
#
#             new_account_ids  trx_stdtime_days_acc  \
# 132819  58134795341800000.1                    84
# 336793  58134795341800000.1                   133
# 25140   58134795341800000.1                   174
# 14131   58134795341800000.1                   290
#
#                            trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 132819         1. Starting balance (today)         2750.0    1250.0     1250.0
# 336793                         3. Payments         2000.0    -750.0     1250.0
# 25140                 5. Interest accruing          600.0    -150.0     1250.0
# 14131   7. Closing Balance--End of last DQ         1350.0    -150.0     1250.0
#        trx_family_code                     trx_type_desc        account_ids  \
# 87136           INFGRP  Borrowing from an informal Group  58134795341800000
# 132819          INFGRP  Borrowing from an informal Group  58134795341800000
# 336793          INFGRP  Borrowing from an informal Group  58134795341800000
# 25140           INFGRP  Borrowing from an informal Group  58134795341800000
# 14131           INFGRP  Borrowing from an informal Group  58134795341800000
#
#             new_account_ids  trx_stdtime_days_acc  \
# 87136   58134795341800000.0                     0
# 132819  58134795341800000.1                    84
# 336793  58134795341800000.1                   133
# 25140   58134795341800000.1                   174
# 14131   58134795341800000.1                   290
#
#                            trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 87136                          3. Payments         1500.0   -1500.0    -1500.0
# 132819         1. Starting balance (today)         2750.0    1250.0     1250.0
# 336793                         3. Payments         2000.0    -750.0     1250.0
# 25140                 5. Interest accruing          600.0    -150.0     1250.0
# 14131   7. Closing Balance--End of last DQ         1350.0    -150.0     1250.0
# 63136740549700000.1
#        trx_family_code                              trx_type_desc  \
# 70               FRMLN  Consumer/ personal loan (not payday loan)
# 379932           FRMLN  Consumer/ personal loan (not payday loan)
# 274148           FRMLN  Consumer/ personal loan (not payday loan)
# 63462            FRMLN  Consumer/ personal loan (not payday loan)
# 379935           FRMLN  Consumer/ personal loan (not payday loan)
# 234660           FRMLN  Consumer/ personal loan (not payday loan)
# 202757           FRMLN  Consumer/ personal loan (not payday loan)
# 2157             FRMLN  Consumer/ personal loan (not payday loan)
#
#               account_ids      new_account_ids  trx_stdtime_days_acc  \
# 70      63136740549700000  63136740549700000.1                     0
# 379932  63136740549700000  63136740549700000.1                     0
# 274148  63136740549700000  63136740549700000.1                    30
# 63462   63136740549700000  63136740549700000.1                    60
# 379935  63136740549700000  63136740549700000.1                    91
# 234660  63136740549700000  63136740549700000.1                   122
# 202757  63136740549700000  63136740549700000.1                   152
# 2157    63136740549700000  63136740549700000.1                   155
#
#                            trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 70             1. Starting balance (today)        16800.0   16800.0    16800.0
# 379932                         3. Payments         2800.0   14000.0    16800.0
# 274148                         3. Payments         2800.0   11200.0    16800.0
# 63462                          3. Payments         2800.0    8400.0    16800.0
# 379935                         3. Payments         2800.0    5600.0    16800.0
# 234660                         3. Payments         2800.0    2800.0    16800.0
# 202757                         3. Payments         2800.0       0.0    16800.0
# 2157    6. Closing Balance--End of last DQ            0.0       0.0    16800.0
#        trx_family_code                              trx_type_desc  \
# 70               FRMLN  Consumer/ personal loan (not payday loan)
# 379932           FRMLN  Consumer/ personal loan (not payday loan)
# 274148           FRMLN  Consumer/ personal loan (not payday loan)
# 63462            FRMLN  Consumer/ personal loan (not payday loan)
# 379935           FRMLN  Consumer/ personal loan (not payday loan)
# 234660           FRMLN  Consumer/ personal loan (not payday loan)
# 202757           FRMLN  Consumer/ personal loan (not payday loan)
# 2157             FRMLN  Consumer/ personal loan (not payday loan)
#
#               account_ids      new_account_ids  trx_stdtime_days_acc  \
# 70      63136740549700000  63136740549700000.1                     0
# 379932  63136740549700000  63136740549700000.1                     0
# 274148  63136740549700000  63136740549700000.1                    30
# 63462   63136740549700000  63136740549700000.1                    60
# 379935  63136740549700000  63136740549700000.1                    91
# 234660  63136740549700000  63136740549700000.1                   122
# 202757  63136740549700000  63136740549700000.1                   152
# 2157    63136740549700000  63136740549700000.1                   155
#
#                            trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 70             1. Starting balance (today)        16800.0   16800.0    16800.0
# 379932                         3. Payments         2800.0   14000.0    16800.0
# 274148                         3. Payments         2800.0   11200.0    16800.0
# 63462                          3. Payments         2800.0    8400.0    16800.0
# 379935                         3. Payments         2800.0    5600.0    16800.0
# 234660                         3. Payments         2800.0    2800.0    16800.0
# 202757                         3. Payments         2800.0       0.0    16800.0
# 2157    6. Closing Balance--End of last DQ            0.0       0.0    16800.0
# /anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py:1001: UserWarning: Attempting to set identical left == right == 131.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(left, right)
# 59135754492000000.2
#        trx_family_code                     trx_type_desc        account_ids  \
# 154799          INFGRP  Borrowing from an informal Group  59135754492000000
#
#             new_account_ids  trx_stdtime_days_acc   trx_prx_purpose  \
# 154799  59135754492000000.2                   131  2. New borrowing
#
#         trx_value_kes  bal_evol  start_bal
# 154799         1200.0    1700.0     1700.0
#        trx_family_code                     trx_type_desc        account_ids  \
# 9888            INFGRP  Borrowing from an informal Group  59135754492000000
# 255855          INFGRP  Borrowing from an informal Group  59135754492000000
# 99234           INFGRP  Borrowing from an informal Group  59135754492000000
# 154799          INFGRP  Borrowing from an informal Group  59135754492000000
# 96345           INFGRP  Borrowing from an informal Group  59135754492000000
# 240949          INFGRP  Borrowing from an informal Group  59135754492000000
# 13901           INFGRP  Borrowing from an informal Group  59135754492000000
#
#             new_account_ids  trx_stdtime_days_acc  \
# 9888    59135754492000000.1                     0
# 255855  59135754492000000.1                    66
# 99234   59135754492000000.1                   100
# 154799  59135754492000000.2                   131
# 96345   59135754492000000.3                   252
# 240949  59135754492000000.3                   281
# 13901   59135754492000000.3                   353
#
#                            trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 9888           1. Starting balance (today)         2500.0    2500.0     2500.0
# 255855                         3. Payments         1500.0    1000.0     2500.0
# 99234                          3. Payments          500.0     500.0     2500.0
# 154799                    2. New borrowing         1200.0    1700.0     1700.0
# 96345                     2. New borrowing         1000.0    2700.0     2700.0
# 240949                         3. Payments          400.0    2300.0     2700.0
# 13901   7. Closing Balance--End of last DQ         2300.0    2300.0     2700.0
# 56134795644900000.1
#        trx_family_code                     trx_type_desc        account_ids  \
# 20072           INFGRP  Borrowing from an informal Group  56134795644900000
# 308088          INFGRP  Borrowing from an informal Group  56134795644900000
#
#             new_account_ids  trx_stdtime_days_acc  \
# 20072   56134795644900000.1                     0
# 308088  56134795644900000.1                    28
#
#                     trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 20072   1. Starting balance (today)        15000.0   15000.0    15000.0
# 308088                  3. Payments          100.0   14900.0    15000.0
#        trx_family_code                     trx_type_desc        account_ids  \
# 20072           INFGRP  Borrowing from an informal Group  56134795644900000
# 308088          INFGRP  Borrowing from an informal Group  56134795644900000
# 311021          INFGRP  Borrowing from an informal Group  56134795644900000
# 281384          INFGRP  Borrowing from an informal Group  56134795644900000
# 338697          INFGRP  Borrowing from an informal Group  56134795644900000
# 195826          INFGRP  Borrowing from an informal Group  56134795644900000
# 172321          INFGRP  Borrowing from an informal Group  56134795644900000
# 16108           INFGRP  Borrowing from an informal Group  56134795644900000
# 350634          INFGRP  Borrowing from an informal Group  56134795644900000
# 16608           INFGRP  Borrowing from an informal Group  56134795644900000
# 159230          INFGRP  Borrowing from an informal Group  56134795644900000
# 228796          INFGRP  Borrowing from an informal Group  56134795644900000
# 310502          INFGRP  Borrowing from an informal Group  56134795644900000
# 344690          INFGRP  Borrowing from an informal Group  56134795644900000
# 2888            INFGRP  Borrowing from an informal Group  56134795644900000
#
#             new_account_ids  trx_stdtime_days_acc  \
# 20072   56134795644900000.1                     0
# 308088  56134795644900000.1                    28
# 311021  56134795644900000.2                    31
# 281384  56134795644900000.2                    41
# 338697  56134795644900000.2                    48
# 195826  56134795644900000.2                    55
# 172321  56134795644900000.3                   115
# 16108   56134795644900000.4                   129
# 350634  56134795644900000.4                   129
# 16608   56134795644900000.5                   157
# 159230  56134795644900000.5                   157
# 228796  56134795644900000.5                   157
# 310502  56134795644900000.6                   254
# 344690  56134795644900000.6                   254
# 2888    56134795644900000.6                   388
#
#                            trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 20072          1. Starting balance (today)        15000.0   15000.0    15000.0
# 308088                         3. Payments          100.0   14900.0    15000.0
# 311021                    2. New borrowing           20.0   14920.0    14920.0
# 281384                         3. Payments         2500.0   12420.0    14920.0
# 338697                         3. Payments         3000.0    9420.0    14920.0
# 195826                         3. Payments         4000.0    5420.0    14920.0
# 172321                    2. New borrowing         3000.0    8420.0     8420.0
# 16108                 5. Interest accruing          100.0   18520.0    18420.0
# 350634                    2. New borrowing        10000.0   18420.0    18420.0
# 16608                 5. Interest accruing          100.0   28620.0    28520.0
# 159230                    2. New borrowing        10000.0   28520.0    28520.0
# 228796                         3. Payments        10100.0   18520.0    28520.0
# 310502                    2. New borrowing        24000.0   42520.0    42520.0
# 344690                         3. Payments        16500.0   26020.0    42520.0
# 2888    7. Closing Balance--End of last DQ        26020.0   26020.0    42520.0
# 50136912726500000.2
#        trx_family_code                     trx_type_desc        account_ids  \
# 13715           INFGRP  Borrowing from an informal Group  50136912726500000
# 225334          INFGRP  Borrowing from an informal Group  50136912726500000
# 174515          INFGRP  Borrowing from an informal Group  50136912726500000
# 24466           INFGRP  Borrowing from an informal Group  50136912726500000
#
#             new_account_ids  trx_stdtime_days_acc  \
# 13715   50136912726500000.2                    64
# 225334  50136912726500000.2                    64
# 174515  50136912726500000.2                    90
# 24466   50136912726500000.2                   177
#
#                            trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 13715                 5. Interest accruing          600.0    6600.0     6000.0
# 225334                    2. New borrowing         6000.0    6000.0     6000.0
# 174515                         3. Payments         6600.0       0.0     6000.0
# 24466   7. Closing Balance--End of last DQ            0.0       0.0     6000.0
#        trx_family_code                     trx_type_desc        account_ids  \
# 1033            INFGRP  Borrowing from an informal Group  50136912726500000
# 53319           INFGRP  Borrowing from an informal Group  50136912726500000
# 349837          INFGRP  Borrowing from an informal Group  50136912726500000
# 13715           INFGRP  Borrowing from an informal Group  50136912726500000
# 225334          INFGRP  Borrowing from an informal Group  50136912726500000
# 174515          INFGRP  Borrowing from an informal Group  50136912726500000
# 24466           INFGRP  Borrowing from an informal Group  50136912726500000
#
#             new_account_ids  trx_stdtime_days_acc  \
# 1033    50136912726500000.1                     0
# 53319   50136912726500000.1                     0
# 349837  50136912726500000.1                    29
# 13715   50136912726500000.2                    64
# 225334  50136912726500000.2                    64
# 174515  50136912726500000.2                    90
# 24466   50136912726500000.2                   177
#
#                            trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 1033                  5. Interest accruing          700.0    7700.0     7000.0
# 53319                     2. New borrowing         7000.0    7000.0     7000.0
# 349837                         3. Payments         7700.0       0.0     7000.0
# 13715                 5. Interest accruing          600.0    6600.0     6000.0
# 225334                    2. New borrowing         6000.0    6000.0     6000.0
# 174515                         3. Payments         6600.0       0.0     6000.0
# 24466   7. Closing Balance--End of last DQ            0.0       0.0     6000.0
# 89137408864000000.1
#        trx_family_code         trx_type_desc        account_ids  \
# 8751             FRMLN  Joint liability loan  89137408864000000
# 479661           FRMLN  Joint liability loan  89137408864000000
# 446541           FRMLN  Joint liability loan  89137408864000000
# 480647           FRMLN  Joint liability loan  89137408864000000
#
#             new_account_ids  trx_stdtime_days_acc  \
# 8751    89137408864000000.1                     0
# 479661  89137408864000000.1                     0
# 446541  89137408864000000.1                    88
# 480647  89137408864000000.1                   116
#
#                     trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 8751    1. Starting balance (today)         6590.0    6590.0     6590.0
# 479661                  3. Payments         3000.0    3590.0     6590.0
# 446541                  3. Payments         3000.0     590.0     6590.0
# 480647                  3. Payments         1500.0    -910.0     6590.0
#        trx_family_code         trx_type_desc        account_ids  \
# 8751             FRMLN  Joint liability loan  89137408864000000
# 479661           FRMLN  Joint liability loan  89137408864000000
# 446541           FRMLN  Joint liability loan  89137408864000000
# 480647           FRMLN  Joint liability loan  89137408864000000
#
#             new_account_ids  trx_stdtime_days_acc  \
# 8751    89137408864000000.1                     0
# 479661  89137408864000000.1                     0
# 446541  89137408864000000.1                    88
# 480647  89137408864000000.1                   116
#
#                     trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 8751    1. Starting balance (today)         6590.0    6590.0     6590.0
# 479661                  3. Payments         3000.0    3590.0     6590.0
# 446541                  3. Payments         3000.0     590.0     6590.0
# 480647                  3. Payments         1500.0    -910.0     6590.0
# 65134736606600000.4
#        trx_family_code                     trx_type_desc        account_ids  \
# 161039          INFGRP  Borrowing from an informal Group  65134736606600000
# 327763          INFGRP  Borrowing from an informal Group  65134736606600000
# 9153            INFGRP  Borrowing from an informal Group  65134736606600000
#
#             new_account_ids  trx_stdtime_days_acc  \
# 161039  65134736606600000.4                   336
# 327763  65134736606600000.4                   352
# 9153    65134736606600000.4                   366
#
#                            trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 161039                    2. New borrowing          200.0    1400.0     1400.0
# 327763                         3. Payments          400.0    1000.0     1400.0
# 9153    7. Closing Balance--End of last DQ         1000.0    1000.0     1400.0
#        trx_family_code                     trx_type_desc        account_ids  \
# 9329            INFGRP  Borrowing from an informal Group  65134736606600000
# 51860           INFGRP  Borrowing from an informal Group  65134736606600000
# 233553          INFGRP  Borrowing from an informal Group  65134736606600000
# 168765          INFGRP  Borrowing from an informal Group  65134736606600000
# 161039          INFGRP  Borrowing from an informal Group  65134736606600000
# 327763          INFGRP  Borrowing from an informal Group  65134736606600000
# 9153            INFGRP  Borrowing from an informal Group  65134736606600000
#
#             new_account_ids  trx_stdtime_days_acc  \
# 9329    65134736606600000.1                     0
# 51860   65134736606600000.2                   154
# 233553  65134736606600000.2                   182
# 168765  65134736606600000.3                   322
# 161039  65134736606600000.4                   336
# 327763  65134736606600000.4                   352
# 9153    65134736606600000.4                   366
#
#                            trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 9329           1. Starting balance (today)         1000.0    1000.0     1000.0
# 51860                     2. New borrowing          500.0    1500.0     1500.0
# 233553                         3. Payments          500.0    1000.0     1500.0
# 168765                    2. New borrowing          200.0    1200.0     1200.0
# 161039                    2. New borrowing          200.0    1400.0     1400.0
# 327763                         3. Payments          400.0    1000.0     1400.0
# 9153    7. Closing Balance--End of last DQ         1000.0    1000.0     1400.0
# 59134666385100000.3
#        trx_family_code                     trx_type_desc        account_ids  \
# 389065          INFGRP  Borrowing from an informal Group  59134666385100000
# 107077          INFGRP  Borrowing from an informal Group  59134666385100000
# 3262            INFGRP  Borrowing from an informal Group  59134666385100000
#
#             new_account_ids  trx_stdtime_days_acc  \
# 389065  59134666385100000.3                   245
# 107077  59134666385100000.3                   325
# 3262    59134666385100000.3                   332
#
#                            trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 389065                    2. New borrowing         5000.0    9000.0     9000.0
# 107077                         3. Payments         1600.0    7400.0     9000.0
# 3262    7. Closing Balance--End of last DQ         3400.0    7400.0     9000.0
#        trx_family_code                     trx_type_desc        account_ids  \
# 3261            INFGRP  Borrowing from an informal Group  59134666385100000
# 1701            INFGRP  Borrowing from an informal Group  59134666385100000
# 349128          INFGRP  Borrowing from an informal Group  59134666385100000
# 389065          INFGRP  Borrowing from an informal Group  59134666385100000
# 107077          INFGRP  Borrowing from an informal Group  59134666385100000
# 3262            INFGRP  Borrowing from an informal Group  59134666385100000
#
#             new_account_ids  trx_stdtime_days_acc  \
# 3261    59134666385100000.1                     0
# 1701    59134666385100000.2                    35
# 349128  59134666385100000.2                   193
# 389065  59134666385100000.3                   245
# 107077  59134666385100000.3                   325
# 3262    59134666385100000.3                   332
#
#                            trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 3261           1. Starting balance (today)         4000.0    4000.0     4000.0
# 1701           1. Starting balance (today)         2000.0    6000.0     6000.0
# 349128                         3. Payments         2000.0    4000.0     6000.0
# 389065                    2. New borrowing         5000.0    9000.0     9000.0
# 107077                         3. Payments         1600.0    7400.0     9000.0
# 3262    7. Closing Balance--End of last DQ         3400.0    7400.0     9000.0
# 56134691927000000.1
#       trx_family_code                     trx_type_desc        account_ids  \
# 23156          INFGRP  Borrowing from an informal Group  56134691927000000
# 1933           INFGRP  Borrowing from an informal Group  56134691927000000
#
#            new_account_ids  trx_stdtime_days_acc  \
# 23156  56134691927000000.1                     0
# 1933   56134691927000000.1                   348
#
#                           trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 23156         1. Starting balance (today)            0.0       0.0        0.0
# 1933   7. Closing Balance--End of last DQ            0.0       0.0        0.0
#       trx_family_code                     trx_type_desc        account_ids  \
# 23156          INFGRP  Borrowing from an informal Group  56134691927000000
# 1933           INFGRP  Borrowing from an informal Group  56134691927000000
#
#            new_account_ids  trx_stdtime_days_acc  \
# 23156  56134691927000000.1                     0
# 1933   56134691927000000.1                   348
#
#                           trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 23156         1. Starting balance (today)            0.0       0.0        0.0
# 1933   7. Closing Balance--End of last DQ            0.0       0.0        0.0
# 59135754492000000.3
#        trx_family_code                     trx_type_desc        account_ids  \
# 96345           INFGRP  Borrowing from an informal Group  59135754492000000
# 240949          INFGRP  Borrowing from an informal Group  59135754492000000
# 13901           INFGRP  Borrowing from an informal Group  59135754492000000
#
#             new_account_ids  trx_stdtime_days_acc  \
# 96345   59135754492000000.3                   252
# 240949  59135754492000000.3                   281
# 13901   59135754492000000.3                   353
#
#                            trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 96345                     2. New borrowing         1000.0    2700.0     2700.0
# 240949                         3. Payments          400.0    2300.0     2700.0
# 13901   7. Closing Balance--End of last DQ         2300.0    2300.0     2700.0
#        trx_family_code                     trx_type_desc        account_ids  \
# 9888            INFGRP  Borrowing from an informal Group  59135754492000000
# 255855          INFGRP  Borrowing from an informal Group  59135754492000000
# 99234           INFGRP  Borrowing from an informal Group  59135754492000000
# 154799          INFGRP  Borrowing from an informal Group  59135754492000000
# 96345           INFGRP  Borrowing from an informal Group  59135754492000000
# 240949          INFGRP  Borrowing from an informal Group  59135754492000000
# 13901           INFGRP  Borrowing from an informal Group  59135754492000000
#
#             new_account_ids  trx_stdtime_days_acc  \
# 9888    59135754492000000.1                     0
# 255855  59135754492000000.1                    66
# 99234   59135754492000000.1                   100
# 154799  59135754492000000.2                   131
# 96345   59135754492000000.3                   252
# 240949  59135754492000000.3                   281
# 13901   59135754492000000.3                   353
#
#                            trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 9888           1. Starting balance (today)         2500.0    2500.0     2500.0
# 255855                         3. Payments         1500.0    1000.0     2500.0
# 99234                          3. Payments          500.0     500.0     2500.0
# 154799                    2. New borrowing         1200.0    1700.0     1700.0
# 96345                     2. New borrowing         1000.0    2700.0     2700.0
# 240949                         3. Payments          400.0    2300.0     2700.0
# 13901   7. Closing Balance--End of last DQ         2300.0    2300.0     2700.0

# %% [markdown]
# # Add observation length

# %%
dfb.insert(dfb.shape[1],"obs_length",np.zeros(dfb.shape[0]))

# %%
for acc in dfb["new_account_ids"].unique():
    lna = dfb[dfb["new_account_ids"]==acc]
    days = lna["trx_stdtime_days_acc"].unique()
    l = days.max() - days.min()
    for index, row in dfb[dfb["new_account_ids"]==acc].iterrows():
        dfb.at[index,"obs_length"] = l

# %%
for i in range(0,10):
    acc=random.choice(dfb["new_account_ids"].unique())
    dfb[dfb["new_account_ids"]==acc].sort_values("trx_stdtime_days_acc").plot(x="trx_stdtime_days_acc",y="bal_evol", title = acc,marker="o")
    plt.show()
    print(acc)
    display(dfb[dfb["new_account_ids"]==acc].sort_values("trx_stdtime_days_acc")[["account_ids","new_account_ids","trx_stdtime_days_acc","trx_prx_purpose","trx_value_kes","bal_evol","start_bal","obs_length"]])
    display(dfb[dfb["account_ids"]==acc[:-2]].sort_values("trx_stdtime_days_acc")[["account_ids","new_account_ids","trx_stdtime_days_acc","trx_prx_purpose","trx_value_kes","bal_evol","start_bal","obs_length"]])
# Out:
# 60136681435900000.1
#               account_ids      new_account_ids  trx_stdtime_days_acc  \
# 340927  60136681435900000  60136681435900000.1                     0
# 25651   60136681435900000  60136681435900000.1                   160
#
#                            trx_prx_purpose  trx_value_kes  bal_evol  \
# 340927                    2. New borrowing          400.0     400.0
# 25651   7. Closing Balance--End of last DQ          400.0     400.0
#
#         start_bal  obs_length
# 340927      400.0       160.0
# 25651       400.0       160.0
#               account_ids      new_account_ids  trx_stdtime_days_acc  \
# 340927  60136681435900000  60136681435900000.1                     0
# 25651   60136681435900000  60136681435900000.1                   160
#
#                            trx_prx_purpose  trx_value_kes  bal_evol  \
# 340927                    2. New borrowing          400.0     400.0
# 25651   7. Closing Balance--End of last DQ          400.0     400.0
#
#         start_bal  obs_length
# 340927      400.0       160.0
# 25651       400.0       160.0
# 58134816929000000.3
#               account_ids      new_account_ids  trx_stdtime_days_acc  \
# 10917   58134816929000000  58134816929000000.3                   252
# 93256   58134816929000000  58134816929000000.3                   252
# 187493  58134816929000000  58134816929000000.3                   252
# 2808    58134816929000000  58134816929000000.3                   349
#
#                            trx_prx_purpose  trx_value_kes  bal_evol  \
# 10917                 5. Interest accruing          300.0     550.0
# 93256                     2. New borrowing         3000.0     250.0
# 187493                         3. Payments         2750.0   -2200.0
# 2808    7. Closing Balance--End of last DQ         3300.0   -2200.0
#
#         start_bal  obs_length
# 10917       250.0        97.0
# 93256       250.0        97.0
# 187493      250.0        97.0
# 2808        250.0        97.0
#               account_ids      new_account_ids  trx_stdtime_days_acc  \
# 205413  58134816929000000  58134816929000000.0                     0
# 66197   58134816929000000  58134816929000000.0                    33
# 226855  58134816929000000  58134816929000000.0                    61
# 204892  58134816929000000  58134816929000000.0                    91
# 154849  58134816929000000  58134816929000000.0                   115
# 20271   58134816929000000  58134816929000000.1                   190
# 22294   58134816929000000  58134816929000000.2                   224
# 248860  58134816929000000  58134816929000000.2                   224
# 248864  58134816929000000  58134816929000000.2                   224
# 10917   58134816929000000  58134816929000000.3                   252
# 93256   58134816929000000  58134816929000000.3                   252
# 187493  58134816929000000  58134816929000000.3                   252
# 2808    58134816929000000  58134816929000000.3                   349
#
#                            trx_prx_purpose  trx_value_kes  bal_evol  \
# 205413                         3. Payments         1100.0   -1100.0
# 66197                          3. Payments         1100.0   -2200.0
# 226855                         3. Payments         1100.0   -3300.0
# 204892                         3. Payments         1100.0   -4400.0
# 154849                         3. Payments         1100.0   -5500.0
# 20271          1. Starting balance (today)         2500.0   -3000.0
# 22294                 5. Interest accruing          250.0    -250.0
# 248860                         3. Payments         2500.0   -2750.0
# 248864                    2. New borrowing         2500.0    -500.0
# 10917                 5. Interest accruing          300.0     550.0
# 93256                     2. New borrowing         3000.0     250.0
# 187493                         3. Payments         2750.0   -2200.0
# 2808    7. Closing Balance--End of last DQ         3300.0   -2200.0
#
#         start_bal  obs_length
# 205413    -1100.0       115.0
# 66197     -1100.0       115.0
# 226855    -1100.0       115.0
# 204892    -1100.0       115.0
# 154849    -1100.0       115.0
# 20271     -3000.0         0.0
# 22294      -500.0         0.0
# 248860     -500.0         0.0
# 248864     -500.0         0.0
# 10917       250.0        97.0
# 93256       250.0        97.0
# 187493      250.0        97.0
# 2808        250.0        97.0
# 59134666321200000.3
#               account_ids      new_account_ids  trx_stdtime_days_acc  \
# 360810  59134666321200000  59134666321200000.3                   291
# 13193   59134666321200000  59134666321200000.3                   332
# 10503   59134666321200000  59134666321200000.3                   333
#
#                            trx_prx_purpose  trx_value_kes  bal_evol  \
# 360810                    2. New borrowing          100.0     600.0
# 13193   7. Closing Balance--End of last DQ          700.0     600.0
# 10503                 5. Interest accruing          400.0    1000.0
#
#         start_bal  obs_length
# 360810      600.0        42.0
# 13193       600.0        42.0
# 10503       600.0        42.0
#               account_ids      new_account_ids  trx_stdtime_days_acc  \
# 22871   59134666321200000  59134666321200000.1                     0
# 3260    59134666321200000  59134666321200000.2                    35
# 339570  59134666321200000  59134666321200000.2                    96
# 360810  59134666321200000  59134666321200000.3                   291
# 13193   59134666321200000  59134666321200000.3                   332
# 10503   59134666321200000  59134666321200000.3                   333
#
#                            trx_prx_purpose  trx_value_kes  bal_evol  \
# 22871          1. Starting balance (today)          500.0     500.0
# 3260           1. Starting balance (today)          600.0    1100.0
# 339570                         3. Payments          600.0     500.0
# 360810                    2. New borrowing          100.0     600.0
# 13193   7. Closing Balance--End of last DQ          700.0     600.0
# 10503                 5. Interest accruing          400.0    1000.0
#
#         start_bal  obs_length
# 22871       500.0         0.0
# 3260       1100.0        61.0
# 339570     1100.0        61.0
# 360810      600.0        42.0
# 13193       600.0        42.0
# 10503       600.0        42.0
# 61134804533700000.1
#               account_ids      new_account_ids  trx_stdtime_days_acc  \
# 5538    61134804533700000  61134804533700000.1                     7
# 335264  61134804533700000  61134804533700000.1                    42
# 125791  61134804533700000  61134804533700000.1                    70
# 5228    61134804533700000  61134804533700000.1                   398
#
#                            trx_prx_purpose  trx_value_kes  bal_evol  \
# 5538           1. Starting balance (today)         2400.0    1200.0
# 335264                         3. Payments         1500.0    -300.0
# 125791                         3. Payments          900.0   -1200.0
# 5228    6. Closing Balance--End of last DQ            0.0   -1200.0
#
#         start_bal  obs_length
# 5538       1200.0       391.0
# 335264     1200.0       391.0
# 125791     1200.0       391.0
# 5228       1200.0       391.0
#               account_ids      new_account_ids  trx_stdtime_days_acc  \
# 61236   61134804533700000  61134804533700000.0                     0
# 5538    61134804533700000  61134804533700000.1                     7
# 335264  61134804533700000  61134804533700000.1                    42
# 125791  61134804533700000  61134804533700000.1                    70
# 5228    61134804533700000  61134804533700000.1                   398
#
#                            trx_prx_purpose  trx_value_kes  bal_evol  \
# 61236                          3. Payments         1200.0   -1200.0
# 5538           1. Starting balance (today)         2400.0    1200.0
# 335264                         3. Payments         1500.0    -300.0
# 125791                         3. Payments          900.0   -1200.0
# 5228    6. Closing Balance--End of last DQ            0.0   -1200.0
#
#         start_bal  obs_length
# 61236     -1200.0         0.0
# 5538       1200.0       391.0
# 335264     1200.0       391.0
# 125791     1200.0       391.0
# 5228       1200.0       391.0
# /anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py:1001: UserWarning: Attempting to set identical left == right == 9.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(left, right)
# 59135825372200000.2
#               account_ids      new_account_ids  trx_stdtime_days_acc  \
# 3935    59135825372200000  59135825372200000.2                     9
# 18616   59135825372200000  59135825372200000.2                     9
# 455577  59135825372200000  59135825372200000.2                     9
# 455585  59135825372200000  59135825372200000.2                     9
#
#              trx_prx_purpose  trx_value_kes  bal_evol  start_bal  obs_length
# 3935    5. Interest accruing          200.0    2400.0     2200.0         0.0
# 18616   5. Interest accruing          200.0    2400.0     2200.0         0.0
# 455577      2. New borrowing         1000.0    2200.0     2200.0         0.0
# 455585           3. Payments          200.0    2200.0     2200.0         0.0
#               account_ids      new_account_ids  trx_stdtime_days_acc  \
# 285092  59135825372200000  59135825372200000.1                     0
# 19868   59135825372200000  59135825372200000.1                     0
# 3935    59135825372200000  59135825372200000.2                     9
# 455577  59135825372200000  59135825372200000.2                     9
# 455585  59135825372200000  59135825372200000.2                     9
# 18616   59135825372200000  59135825372200000.2                     9
# 3936    59135825372200000  59135825372200000.3                    32
# 443210  59135825372200000  59135825372200000.3                    32
# 84161   59135825372200000  59135825372200000.4                    60
# 93310   59135825372200000  59135825372200000.4                    60
# 3937    59135825372200000  59135825372200000.4                    60
# 265640  59135825372200000  59135825372200000.4                    60
# 298527  59135825372200000  59135825372200000.5                   120
# 387713  59135825372200000  59135825372200000.5                   120
# 256091  59135825372200000  59135825372200000.6                   151
# 18964   59135825372200000  59135825372200000.6                   151
# 253758  59135825372200000  59135825372200000.6                   151
# 290738  59135825372200000  59135825372200000.6                   158
# 35384   59135825372200000  59135825372200000.6                   181
# 443062  59135825372200000  59135825372200000.6                   213
# 20990   59135825372200000  59135825372200000.6                   261
#
#                            trx_prx_purpose  trx_value_kes  bal_evol  \
# 285092                    2. New borrowing         1000.0    1000.0
# 19868                 5. Interest accruing          200.0    1200.0
# 3935                  5. Interest accruing          200.0    2400.0
# 455577                    2. New borrowing         1000.0    2200.0
# 455585                         3. Payments          200.0    2200.0
# 18616                 5. Interest accruing          200.0    2400.0
# 3936                  5. Interest accruing          200.0    3600.0
# 443210                    2. New borrowing         1000.0    3400.0
# 84161                          3. Payments          200.0    4400.0
# 93310                          3. Payments         1000.0    3400.0
# 3937                  5. Interest accruing          200.0    3600.0
# 265640                    2. New borrowing         1000.0    4600.0
# 298527                5. Interest accruing          400.0    6000.0
# 387713                    2. New borrowing         2000.0    5600.0
# 256091                         3. Payments         1200.0    5800.0
# 18964                 5. Interest accruing          200.0    6000.0
# 253758                    2. New borrowing         1000.0    7000.0
# 290738                         3. Payments         2600.0    3400.0
# 35384                          3. Payments         1000.0    2400.0
# 443062                         3. Payments         2200.0     200.0
# 20990   7. Closing Balance--End of last DQ            0.0     200.0
#
#         start_bal  obs_length
# 285092     1000.0         0.0
# 19868      1000.0         0.0
# 3935       2200.0         0.0
# 455577     2200.0         0.0
# 455585     2200.0         0.0
# 18616      2200.0         0.0
# 3936       3400.0         0.0
# 443210     3400.0         0.0
# 84161      4600.0         0.0
# 93310      4600.0         0.0
# 3937       4600.0         0.0
# 265640     4600.0         0.0
# 298527     5600.0         0.0
# 387713     5600.0         0.0
# 256091     7000.0       110.0
# 18964      7000.0       110.0
# 253758     7000.0       110.0
# 290738     7000.0       110.0
# 35384      7000.0       110.0
# 443062     7000.0       110.0
# 20990      7000.0       110.0
# 59134874137900000.2
#               account_ids      new_account_ids  trx_stdtime_days_acc  \
# 277431  59134874137900000  59134874137900000.2                   112
# 216268  59134874137900000  59134874137900000.2                   170
# 3724    59134874137900000  59134874137900000.2                   348
#
#                            trx_prx_purpose  trx_value_kes  bal_evol  \
# 277431                    2. New borrowing         1200.0    7800.0
# 216268                         3. Payments         1700.0    6100.0
# 3724    7. Closing Balance--End of last DQ         6100.0    6100.0
#
#         start_bal  obs_length
# 277431     7800.0       236.0
# 216268     7800.0       236.0
# 3724       7800.0       236.0
#               account_ids      new_account_ids  trx_stdtime_days_acc  \
# 20186   59134874137900000  59134874137900000.1                     0
# 250271  59134874137900000  59134874137900000.1                    19
# 277431  59134874137900000  59134874137900000.2                   112
# 216268  59134874137900000  59134874137900000.2                   170
# 3724    59134874137900000  59134874137900000.2                   348
#
#                            trx_prx_purpose  trx_value_kes  bal_evol  \
# 20186          1. Starting balance (today)         8600.0    8600.0
# 250271                         3. Payments         2000.0    6600.0
# 277431                    2. New borrowing         1200.0    7800.0
# 216268                         3. Payments         1700.0    6100.0
# 3724    7. Closing Balance--End of last DQ         6100.0    6100.0
#
#         start_bal  obs_length
# 20186      8600.0        19.0
# 250271     8600.0        19.0
# 277431     7800.0       236.0
# 216268     7800.0       236.0
# 3724       7800.0       236.0
# 108136903834300000.1
#                account_ids       new_account_ids  trx_stdtime_days_acc  \
# 140677  108136903834300000  108136903834300000.1                     0
# 24186   108136903834300000  108136903834300000.1                    29
#
#                            trx_prx_purpose  trx_value_kes  bal_evol  \
# 140677                    2. New borrowing        30000.0   30000.0
# 24186   7. Closing Balance--End of last DQ        30000.0   30000.0
#
#         start_bal  obs_length
# 140677    30000.0        29.0
# 24186     30000.0        29.0
#                account_ids       new_account_ids  trx_stdtime_days_acc  \
# 140677  108136903834300000  108136903834300000.1                     0
# 24186   108136903834300000  108136903834300000.1                    29
#
#                            trx_prx_purpose  trx_value_kes  bal_evol  \
# 140677                    2. New borrowing        30000.0   30000.0
# 24186   7. Closing Balance--End of last DQ        30000.0   30000.0
#
#         start_bal  obs_length
# 140677    30000.0        29.0
# 24186     30000.0        29.0
# 57134683686000000.1
#               account_ids      new_account_ids  trx_stdtime_days_acc  \
# 24798   57134683686000000  57134683686000000.1                     0
# 470360  57134683686000000  57134683686000000.1                    24
# 470710  57134683686000000  57134683686000000.1                    55
# 476856  57134683686000000  57134683686000000.1                    86
#
#                     trx_prx_purpose  trx_value_kes  bal_evol  start_bal  \
# 24798   1. Starting balance (today)        21650.0   21650.0    21650.0
# 470360                  3. Payments         2850.0   18800.0    21650.0
# 470710                  3. Payments         2800.0   16000.0    21650.0
# 476856                  3. Payments        16000.0       0.0    21650.0
#
#         obs_length
# 24798         86.0
# 470360        86.0
# 470710        86.0
# 476856        86.0
#               account_ids      new_account_ids  trx_stdtime_days_acc  \
# 24798   57134683686000000  57134683686000000.1                     0
# 470360  57134683686000000  57134683686000000.1                    24
# 470710  57134683686000000  57134683686000000.1                    55
# 476856  57134683686000000  57134683686000000.1                    86
#
#                     trx_prx_purpose  trx_value_kes  bal_evol  start_bal  \
# 24798   1. Starting balance (today)        21650.0   21650.0    21650.0
# 470360                  3. Payments         2850.0   18800.0    21650.0
# 470710                  3. Payments         2800.0   16000.0    21650.0
# 476856                  3. Payments        16000.0       0.0    21650.0
#
#         obs_length
# 24798         86.0
# 470360        86.0
# 470710        86.0
# 476856        86.0
# 56134691927000000.1
#              account_ids      new_account_ids  trx_stdtime_days_acc  \
# 23156  56134691927000000  56134691927000000.1                     0
# 1933   56134691927000000  56134691927000000.1                   348
#
#                           trx_prx_purpose  trx_value_kes  bal_evol  start_bal  \
# 23156         1. Starting balance (today)            0.0       0.0        0.0
# 1933   7. Closing Balance--End of last DQ            0.0       0.0        0.0
#
#        obs_length
# 23156       348.0
# 1933        348.0
#              account_ids      new_account_ids  trx_stdtime_days_acc  \
# 23156  56134691927000000  56134691927000000.1                     0
# 1933   56134691927000000  56134691927000000.1                   348
#
#                           trx_prx_purpose  trx_value_kes  bal_evol  start_bal  \
# 23156         1. Starting balance (today)            0.0       0.0        0.0
# 1933   7. Closing Balance--End of last DQ            0.0       0.0        0.0
#
#        obs_length
# 23156       348.0
# 1933        348.0
# 105137145572000000.2
#                account_ids       new_account_ids  trx_stdtime_days_acc  \
# 251644  105137145572000000  105137145572000000.2                   203
# 386558  105137145572000000  105137145572000000.2                   203
# 301918  105137145572000000  105137145572000000.2                   210
#
#              trx_prx_purpose  trx_value_kes  bal_evol  start_bal  obs_length
# 251644  5. Interest accruing           20.0     520.0      500.0         7.0
# 386558      2. New borrowing          500.0     500.0      500.0         7.0
# 301918           3. Payments          520.0       0.0      500.0         7.0
#                account_ids       new_account_ids  trx_stdtime_days_acc  \
# 18438   105137145572000000  105137145572000000.1                     0
# 403962  105137145572000000  105137145572000000.1                     0
# 238703  105137145572000000  105137145572000000.1                     7
# 251644  105137145572000000  105137145572000000.2                   203
# 386558  105137145572000000  105137145572000000.2                   203
# 301918  105137145572000000  105137145572000000.2                   210
# 9979    105137145572000000  105137145572000000.3                   294
# 327916  105137145572000000  105137145572000000.3                   294
# 20338   105137145572000000  105137145572000000.4                   308
# 114059  105137145572000000  105137145572000000.4                   308
# 296582  105137145572000000  105137145572000000.4                   308
# 3528    105137145572000000  105137145572000000.4                   329
#
#                            trx_prx_purpose  trx_value_kes  bal_evol  \
# 18438                    4. Any known fees          120.0    1200.0
# 403962                    2. New borrowing         1080.0    1080.0
# 238703                         3. Payments         1200.0       0.0
# 251644                5. Interest accruing           20.0     520.0
# 386558                    2. New borrowing          500.0     500.0
# 301918                         3. Payments          520.0       0.0
# 9979                  5. Interest accruing           50.0     550.0
# 327916                    2. New borrowing          500.0     500.0
# 20338                    4. Any known fees          150.0    2200.0
# 114059                         3. Payments          550.0    1650.0
# 296582                    2. New borrowing         1500.0    2050.0
# 3528    7. Closing Balance--End of last DQ         1650.0    1650.0
#
#         start_bal  obs_length
# 18438      1080.0         7.0
# 403962     1080.0         7.0
# 238703     1080.0         7.0
# 251644      500.0         7.0
# 386558      500.0         7.0
# 301918      500.0         7.0
# 9979        500.0         0.0
# 327916      500.0         0.0
# 20338      2050.0        21.0
# 114059     2050.0        21.0
# 296582     2050.0        21.0
# 3528       2050.0        21.0

# %% [markdown]
# ## Seems ok, let's now save this dataset

# %%
dfb = dfb[dfb["start_bal"]>10]

# %%
dfb = dfb[dfb["obs_length"]>0]

# %%
dfb.to_csv("diaries_trx_trunc_loans_start_bal.csv")

# %% [markdown]
# ### Careful: the column "unique_accnts" is not accurate anymore.
