# %%
import pandas as pd
import numpy as np
import math as math
import matplotlib.pyplot as plt
import seaborn as sns
import random
# %matplotlib inline

# %%
# to see all the columns when using head() or describe()
pd.set_option('display.max_columns',60)

# %%
df = pd.read_csv("kenya_data/diaries_transactions_all.csv", dtype={'account_startclose_balance': str})

# %% [markdown]
# ## For now I keep only "business and agriculture loans", "joint liability loans", "personal loans", "borrowing from an informal group", "borrowing from family and friends", "shylock loans".

# %%
dfb = df[((df["trx_family_code"]=="FRMLN")&((df["trx_type_code"]==2760)|(df["trx_type_code"]==3247)|(df["trx_type_code"]==2762)))|((df["trx_family_code"]=="INFGRP")&(df["trx_type_code"]==3395))]

# %% [markdown]
# # 1. Get rid of loans of with unexplained balance adjustments

# %%
dfb["trx_prx_purpose"].unique()
# Out:
# array(['7. Closing Balance--End of last DQ',
#        '6. Closing Balance--End of last DQ',
#        '1. Starting balance (today)', '5. Interest accruing',
#        'DECREASE--Unexplained balance adjustment',
#        'INCREASE--Unexplained balance adjustment', '3. Payments',
#        '4. Any known fees', '2. New borrowinng (individual portion)',
#        '2. New borrowing', '7. Refund from lender'], dtype=object)

# %% [markdown]
# We insert a new column that is 0 if there is no unexplained balance adjustment for this account and a 1 if there is one. The column in 1 or 0 for all entries that correspond to that account.

# %%
dfb.insert(dfb.shape[1], "acc_unexplained_trx", np.zeros(dfb.shape[0]))

# %% [markdown]
# This program goes through all unique accounts, checks whether it has an unexplained balance adjustment and if yes sets the variable u to 1. Then it goes through another for-loop and sets the entries of that column 0 for all accounts that have an unexplained balance adjustment.

# %%
for acc in dfb["account_ids"].unique():
    u = 0
    for index,row in dfb[dfb["account_ids"]==acc].iterrows():
        if row["trx_prx_purpose"]=="DECREASE--Unexplained balance adjustment" or row["trx_prx_purpose"]=="INCREASE--Unexplained balance adjustment":
            u = 1
    for index,row in dfb[dfb["account_ids"]==acc].iterrows():
        dfb.at[index,"acc_unexplained_trx"] = u

# %% [markdown]
# ### Let us check if it worked.

# %%
s = set()
for acc in dfb[dfb["acc_unexplained_trx"]==0]["account_ids"].unique():
     for i in dfb[dfb["account_ids"]==acc]["trx_prx_purpose"].unique():
            s.add(i)
print(s)
# Out:
# {'2. New borrowinng (individual portion)', '5. Interest accruing', '4. Any known fees', '3. Payments', '2. New borrowing', '1. Starting balance (today)', '6. Closing Balance--End of last DQ', '7. Refund from lender', '7. Closing Balance--End of last DQ'}

# %% [markdown]
# ### "refund from lender" might be hard to deal with, but there are only 2 of those

# %%
dfb[dfb["trx_prx_purpose"]=="7. Refund from lender"]
# Out:
#          hh_ids  unique_hhs first_trx_date_hh last_trx_date_hh  \
# 38535   KVIHC30         NaN         14aug2012        25sep2013
# 177005  KVIHC13         NaN         08sep2012        30sep2013
#
#         tot_hh_daysofobs  tot_hh_monthsofobs  interview_designation  \
# 38535                407                  14  06=Cleaning interview
# 177005               387                  13  06=Cleaning interview
#
#          int_date  int_month  int_year int_yr_mo first_int_date  \
# 38535   24sep2013          9      2013   2013_09      12sep2012
# 177005  27sep2013          9      2013   2013_09      29aug2012
#
#               account_ids  unique_accnts        m_ids_owner  unique_hm_owner  \
# 38535   59136376033300000            NaN  59134381215900000              NaN
# 177005  59135288408400000            NaN                 HH              NaN
#
#        account_bsheet_desig account_startclose_balance account_formal  \
# 38535             Liability                        NaN         Formal
# 177005            Liability                        NaN         Formal
#
#        account_liquid first_trx_date_acc last_trx_date_acc  tot_acc_daysofobs  \
# 38535             NaN          15jan2013         23sep2013                251
# 177005            NaN          20dec2012         30sep2013                284
#
#         tot_acc_monthsofobs             trx_id          m_ids_trx   trx_date  \
# 38535                     8  34138708620100000  59134381215900000  01aug2013
# 177005                    9  60138608712700000  59134372493300000  16apr2013
#
#         trx_month  trx_year trx_yr_mo  trx_dq_round  trx_stdtime_days_hh  \
# 38535           8      2013   2013_08          19.0                  352
# 177005          4      2013   2013_04          20.0                  220
#
#         trx_stdtime_mnths_hh  trx_stdtime_days_acc  trx_stdtime_mnths_acc  \
# 38535                     12                   198                      6
# 177005                     7                   117                      4
#
#        trx_class_code                                     trx_class_desc  \
# 38535          findev  Borrowing, lending, savings or insurance media...
# 177005         findev  Borrowing, lending, savings or insurance media...
#
#        trx_family_code trx_family_desc  trx_type_code  \
# 38535            FRMLN     Formal loan           2760
# 177005           FRMLN     Formal loan           2760
#
#                                   trx_type_desc        trx_prx_purpose  \
# 38535   Individual Business or Agriculture Loan  7. Refund from lender
# 177005  Individual Business or Agriculture Loan  7. Refund from lender
#
#        trx_prx_purpose_fd  trx_fee trx_bsheet_direction  trx_mode_code  \
# 38535                 NaN      0.0                  NaN           10.0
# 177005                NaN      0.0                  NaN            1.0
#
#                                     trx_mode_desc  trx_place_incommunity  \
# 38535   In-kind (trade, good, service--NOT MONEY)                    1.0
# 177005                                       Cash                    1.0
#
#         trx_distance_km        trx_outlet trx_direction  trx_value_kes  \
# 38535               0.0  07=Group meeting        Inflow          300.0
# 177005              0.0  07=Group meeting        Inflow          200.0
#
#         trx_value_usd  ddd_gift trx_inkind_units  trx_inkind_value_usd  \
# 38535        3.529412         0            panga              3.529412
# 177005       2.352941         0              NaN                   NaN
#
#         trx_inkind_value_kes  trx_stdtime_mnths_hh_nr  acc_unexplained_trx
# 38535                  300.0                12.137930                  0.0
# 177005                   NaN                 7.586207                  1.0

# %% [markdown]
# # Let's now only use the loans that have no unexplained balance adjustments.

# %%
dfb = dfb[dfb["acc_unexplained_trx"]==0]

# %% [markdown]
# # 2. Truncation into chunks with no new borrowing

# %% [markdown]
# We first insert a column for the new account numbers. These will be like the old account numbers but with a .1 or .2 for each chunk after a new borrowing.

# %%
# this is sometimes necessary if we mess smt up
# del dfb["new_account_ids"]

# %%
# add column for new account ids
dfb.insert(df.columns.get_loc("account_ids")+1,"new_account_ids", ["-"]*(dfb.shape[0]))

# %%
#add balance evolution to original dataset
df.insert(df.shape[1],"bal_evol",np.zeros(df.shape[0]))

# %%
#add column for starting balance 
df.insert(df.shape[1],"start_bal",np.zeros(df.shape[0]))

# %% [markdown]
# ### Now let's adjust this such that new borrowings are always the first thing on one day, and then run the program that truncates into chunks with new borrowings.

# %%
exc=set()
accounts = []
for acc in dfb["account_ids"].unique():
    accounts.append(acc)
    i=0
    # we will use "indices" to save the reordered indices of the dataset for each unique loan
    indices = []
    # we will use "index_bor" to save the index of the new borrowing that happens on a given day,
    #whenever there were also other transactions (since we need that index to be first)
    index_bor = 0
    #only keep the rows of that account
    lna = dfb[dfb["account_ids"]==acc]
    # sort the dataset according to time
    lna = lna.sort_values("trx_stdtime_days_acc")
    # for each day in the dataset of the account, we check whether there was 
    # a new borrowing or starting balance and if yes reorder
    for d in lna["trx_stdtime_days_acc"].unique():
        # if only one entry that day we just add the index to indices
        if lna[lna["trx_stdtime_days_acc"]==d].shape[0]==1:
            indices.append(lna[lna["trx_stdtime_days_acc"]==d].index[0])
        # if there are more than 1 entry that day
        elif lna[lna["trx_stdtime_days_acc"]==d].shape[0]>1:
            # if there are more than one new borrowings or starting balances, we need to check manually
            if lna[(lna["trx_stdtime_days_acc"]==d)&((lna["trx_prx_purpose"]=="2. New borrowing")|(lna["trx_prx_purpose"]=="2. New borrowinng (individual portion)")|(lna["trx_prx_purpose"]=="1. Starting balance (today)"))].shape[0]>1:
                print("Several new borrowings on day " + str(d) +", check manually account " + acc + " in category "+ str(lna["trx_type_code"].unique()))
                for i in lna[lna["trx_stdtime_days_acc"]==d].index:
                            indices.append(i)
            #if there is exactly one new borrowing or starting balance that day (here we will need to check for each loan type what they exactly call new borrowings)
            elif lna[(lna["trx_stdtime_days_acc"]==d)&((lna["trx_prx_purpose"]=="2. New borrowing")|(lna["trx_prx_purpose"]=="2. New borrowinng (individual portion)")|(lna["trx_prx_purpose"]=="1. Starting balance (today)"))].shape[0]==1:
                #for each type of new borrowing if there is one that day, put that index first into indices
                for kind in ["2. New borrowing","2. New borrowinng (individual portion)","1. Starting balance (today)"]:
                    if kind in lna[lna["trx_stdtime_days_acc"]==d]["trx_prx_purpose"].unique():
                        index_bor = lna[(lna["trx_stdtime_days_acc"]==d) & (lna["trx_prx_purpose"]==kind)].index[0]
                        indices.append(index_bor)
                        #then add all other indices of that day
                        for i in lna[lna["trx_stdtime_days_acc"]==d].index.drop(index_bor):
                            indices.append(i)
            # if there are several entries for that day but none of them new borrowings just add all indices of that day            
            else:
                for i in lna[lna["trx_stdtime_days_acc"]==d].index:
                    indices.append(i)
    # here we reindex the lna dataset, so that each day the new borrowing is first
    lna = lna.loc[indices,]
    
    #add transaction with direction for account
    lna.insert(58, "trx_val_dir",np.zeros(lna.shape[0]))
    for index, row in lna.iterrows():
        if lna.loc[index,"trx_bsheet_direction"]=="Increase":
            lna.at[index,"trx_val_dir"] = lna.loc[index,"trx_value_kes"]
        elif lna.loc[index,"trx_bsheet_direction"]=="Decrease":
            lna.at[index,"trx_val_dir"] = -lna.loc[index,"trx_value_kes"]
        else:
            #save where there is neither increase nor decrease
            exc.add(row["trx_prx_purpose"])
    
    #add the balance evolution entries to df 
    s=0
    for index,row in lna.iterrows():
        s+=lna.loc[index,"trx_val_dir"]
        dfb.at[index,"bal_evol"]=s
    
    #truncating into chunks between new borrowings
    #v will be the index of the chunk we are currently at
    v=0
    # saving the old account number
    acc = lna["account_ids"].unique()[0]
    # a is the new account number for each chunk
    a = lna["account_ids"].unique()[0]+".0"
    #saving all account numbers we used
    accs = set()
    # we go through all rows of lna and change the entries of the column "new_account_ids" in the original dataset.
    for index, row in lna.iterrows():
        # if there is a new borrowing in the row, increase v by 1 and set a to acc.v
        if row["trx_prx_purpose"] == "1. Starting balance (today)" or row["trx_prx_purpose"] == "2. New borrowinng (individual portion)" or row["trx_prx_purpose"] == "2. New borrowing":
            v +=1
            a = acc+"."+str(v)
            dfb.at[index,"new_account_ids"]=a
            lna.at[index,"new_account_ids"]=a
            accs.add(a)
        # otherwise set the new account number in that row to a
        else:
            dfb.at[index,"new_account_ids"]=a
            lna.at[index,"new_account_ids"]=a
            accs.add(a)
            
    # adding starting balance to each new account
    # for each new account
    for a in accs:
        # restrict lna further to only that chunk
        lnaa = lna[lna["new_account_ids"]==a]
        #the starting balance is the first balance of that chunk
        st_bal = dfb.loc[lnaa.index[0],"bal_evol"]
        # assign that starting balance into each row corresponding to this accoun chunk
        for index in lnaa.index:
            dfb.at[index,"start_bal"]=st_bal
# Out:
# Several new borrowings on day 244, check manually account 61135946960100000 in category [3395]

# %%
accounts[-1]
# Out:
# '56134804374600000'

# %% [markdown]
# Several borrowings on the same day.
#
# 61135946960100000

# %%
dfb[dfb["account_ids"]=="61135946960100000"].sort_values("trx_stdtime_days_acc")[["account_ids","new_account_ids","trx_stdtime_days_acc","trx_prx_purpose","trx_value_kes","trx_bsheet_direction","bal_evol","start_bal"]]
# Out:
#               account_ids      new_account_ids  trx_stdtime_days_acc  \
# 118905  61135946960100000  61135946960100000.1                     0
# 195059  61135946960100000  61135946960100000.1                     5
# 43429   61135946960100000  61135946960100000.2                   141
# 212855  61135946960100000  61135946960100000.3                   244
# 295268  61135946960100000  61135946960100000.4                   244
# 5052    61135946960100000  61135946960100000.4                   285
#
#                            trx_prx_purpose  trx_value_kes  \
# 118905                    2. New borrowing          500.0
# 195059                         3. Payments          500.0
# 43429                     2. New borrowing         2000.0
# 212855                    2. New borrowing         1300.0
# 295268                    2. New borrowing          500.0
# 5052    7. Closing Balance--End of last DQ         3800.0
#
#        trx_bsheet_direction  bal_evol  start_bal
# 118905             Increase     500.0      500.0
# 195059             Decrease       0.0      500.0
# 43429              Increase    2000.0     2000.0
# 212855             Increase    3300.0     3300.0
# 295268             Increase    3800.0     3800.0
# 5052                    NaN    3800.0     3800.0

# %% [markdown]
# The account 61135946960100000 seems to have several new borrowings on day 244.

# %% [markdown]
# ### Should we just get rid of these accounts?

# %%
dfb = dfb[(dfb["account_ids"]!="61134787763500000")]

# %%
dfb[(dfb["account_ids"]=="56134804374600000")].sort_values("trx_stdtime_days_acc")[["account_ids","new_account_ids","trx_stdtime_days_acc","trx_prx_purpose","trx_value_kes","trx_bsheet_direction","bal_evol"]]
# Out:
#               account_ids      new_account_ids  trx_stdtime_days_acc  \
# 16212   56134804374600000  56134804374600000.1                     0
# 345760  56134804374600000  56134804374600000.1                    36
# 203475  56134804374600000  56134804374600000.2                    49
# 382054  56134804374600000  56134804374600000.2                    56
# 345765  56134804374600000  56134804374600000.2                   195
# 345766  56134804374600000  56134804374600000.3                   197
# 147030  56134804374600000  56134804374600000.3                   232
# 2       56134804374600000  56134804374600000.3                   350
#
#                            trx_prx_purpose  trx_value_kes  \
# 16212          1. Starting balance (today)        30000.0
# 345760                         3. Payments        30000.0
# 203475                    2. New borrowing         4000.0
# 382054                         3. Payments         1200.0
# 345765                         3. Payments         2800.0
# 345766                    2. New borrowing         3000.0
# 147030                         3. Payments         3000.0
# 2       7. Closing Balance--End of last DQ            0.0
#
#        trx_bsheet_direction  bal_evol
# 16212              Increase   30000.0
# 345760             Decrease       0.0
# 203475             Increase    4000.0
# 382054             Decrease    2800.0
# 345765             Decrease       0.0
# 345766             Increase    3000.0
# 147030             Decrease       0.0
# 2                       NaN       0.0

# %%
accs
# Out:
# {'56134804374600000.1', '56134804374600000.2', '56134804374600000.3'}

# %%
lnaa
# Out:
# Empty DataFrame
# Columns: [hh_ids, unique_hhs, first_trx_date_hh, last_trx_date_hh, tot_hh_daysofobs, tot_hh_monthsofobs, interview_designation, int_date, int_month, int_year, int_yr_mo, first_int_date, account_ids, new_account_ids, unique_accnts, m_ids_owner, unique_hm_owner, account_bsheet_desig, account_startclose_balance, account_formal, account_liquid, first_trx_date_acc, last_trx_date_acc, tot_acc_daysofobs, tot_acc_monthsofobs, trx_id, m_ids_trx, trx_date, trx_month, trx_year, trx_yr_mo, trx_dq_round, trx_stdtime_days_hh, trx_stdtime_mnths_hh, trx_stdtime_days_acc, trx_stdtime_mnths_acc, trx_class_code, trx_class_desc, trx_family_code, trx_family_desc, trx_type_code, trx_type_desc, trx_prx_purpose, trx_prx_purpose_fd, trx_fee, trx_bsheet_direction, trx_mode_code, trx_mode_desc, trx_place_incommunity, trx_distance_km, trx_outlet, trx_direction, trx_value_kes, trx_value_usd, ddd_gift, trx_inkind_units, trx_inkind_value_usd, trx_inkind_value_kes, trx_val_dir, trx_stdtime_mnths_hh_nr, acc_unexplained_trx]
# Index: []
#
# [0 rows x 61 columns]

# %%
a
# Out:
# '56134804374600000.3'

# %% [markdown]
# ## Let's check if it worked.

# %% [markdown]
# Let's see if all accounts got a new name.

# %%
dfb[dfb["new_account_ids"]=="-"]
# Out:
# Empty DataFrame
# Columns: [hh_ids, unique_hhs, first_trx_date_hh, last_trx_date_hh, tot_hh_daysofobs, tot_hh_monthsofobs, interview_designation, int_date, int_month, int_year, int_yr_mo, first_int_date, account_ids, unique_accnts, m_ids_owner, unique_hm_owner, account_bsheet_desig, account_startclose_balance, account_formal, account_liquid, first_trx_date_acc, last_trx_date_acc, tot_acc_daysofobs, tot_acc_monthsofobs, trx_id, m_ids_trx, trx_date, trx_month, trx_year, trx_yr_mo, trx_dq_round, trx_stdtime_days_hh, trx_stdtime_mnths_hh, trx_stdtime_days_acc, trx_stdtime_mnths_acc, trx_class_code, trx_class_desc, trx_family_code, trx_family_desc, trx_type_code, trx_type_desc, trx_prx_purpose, trx_prx_purpose_fd, trx_fee, trx_bsheet_direction, trx_mode_code, trx_mode_desc, trx_place_incommunity, trx_distance_km, trx_outlet, trx_direction, trx_value_kes, trx_value_usd, ddd_gift, trx_inkind_units, trx_inkind_value_usd, trx_inkind_value_kes, trx_stdtime_mnths_hh_nr, acc_unexplained_trx, new_account_ids]
# Index: []

# %% [markdown]
# ## Let's look at a few accounts to see if there are bugs.

# %%
for i in range(0,10):
    acc=random.choice(dfb["new_account_ids"].unique())
    dfb[dfb["new_account_ids"]==acc].sort_values("trx_stdtime_days_acc").plot(x="trx_stdtime_days_acc",y="bal_evol", title = acc,marker="o")
    plt.show()
    print(acc)
    display(dfb[dfb["new_account_ids"]==acc].sort_values("trx_stdtime_days_acc")[["trx_family_code","trx_type_desc","account_ids","new_account_ids","trx_stdtime_days_acc","trx_prx_purpose","trx_value_kes","bal_evol","start_bal"]])
    display(dfb[dfb["account_ids"]==acc[:-2]].sort_values("trx_stdtime_days_acc")[["trx_family_code","trx_type_desc","account_ids","new_account_ids","trx_stdtime_days_acc","trx_prx_purpose","trx_value_kes","bal_evol","start_bal"]])
# Out:
# 63134753070600000.1
#        trx_family_code                     trx_type_desc        account_ids  \
# 1497            INFGRP  Borrowing from an informal Group  63134753070600000
# 326473          INFGRP  Borrowing from an informal Group  63134753070600000
# 302519          INFGRP  Borrowing from an informal Group  63134753070600000
# 137277          INFGRP  Borrowing from an informal Group  63134753070600000
# 150450          INFGRP  Borrowing from an informal Group  63134753070600000
# 335081          INFGRP  Borrowing from an informal Group  63134753070600000
# 146579          INFGRP  Borrowing from an informal Group  63134753070600000
# 384009          INFGRP  Borrowing from an informal Group  63134753070600000
# 91055           INFGRP  Borrowing from an informal Group  63134753070600000
# 239635          INFGRP  Borrowing from an informal Group  63134753070600000
# 365268          INFGRP  Borrowing from an informal Group  63134753070600000
# 150254          INFGRP  Borrowing from an informal Group  63134753070600000
# 16290           INFGRP  Borrowing from an informal Group  63134753070600000
#
#             new_account_ids  trx_stdtime_days_acc  \
# 1497    63134753070600000.1                     0
# 326473  63134753070600000.1                    51
# 302519  63134753070600000.1                    72
# 137277  63134753070600000.1                   114
# 150450  63134753070600000.1                   142
# 335081  63134753070600000.1                   170
# 146579  63134753070600000.1                   198
# 384009  63134753070600000.1                   233
# 91055   63134753070600000.1                   261
# 239635  63134753070600000.1                   289
# 365268  63134753070600000.1                   324
# 150254  63134753070600000.1                   352
# 16290   63134753070600000.1                   357
#
#                            trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 1497           1. Starting balance (today)        15000.0   15000.0    15000.0
# 326473                         3. Payments          900.0   14100.0    15000.0
# 302519                         3. Payments          900.0   13200.0    15000.0
# 137277                         3. Payments          900.0   12300.0    15000.0
# 150450                         3. Payments          800.0   11500.0    15000.0
# 335081                         3. Payments          800.0   10700.0    15000.0
# 146579                         3. Payments          800.0    9900.0    15000.0
# 384009                         3. Payments          800.0    9100.0    15000.0
# 91055                          3. Payments          800.0    8300.0    15000.0
# 239635                         3. Payments          800.0    7500.0    15000.0
# 365268                         3. Payments          800.0    6700.0    15000.0
# 150254                         3. Payments          800.0    5900.0    15000.0
# 16290   7. Closing Balance--End of last DQ         5900.0    5900.0    15000.0
#        trx_family_code                     trx_type_desc        account_ids  \
# 1497            INFGRP  Borrowing from an informal Group  63134753070600000
# 326473          INFGRP  Borrowing from an informal Group  63134753070600000
# 302519          INFGRP  Borrowing from an informal Group  63134753070600000
# 137277          INFGRP  Borrowing from an informal Group  63134753070600000
# 150450          INFGRP  Borrowing from an informal Group  63134753070600000
# 335081          INFGRP  Borrowing from an informal Group  63134753070600000
# 146579          INFGRP  Borrowing from an informal Group  63134753070600000
# 384009          INFGRP  Borrowing from an informal Group  63134753070600000
# 91055           INFGRP  Borrowing from an informal Group  63134753070600000
# 239635          INFGRP  Borrowing from an informal Group  63134753070600000
# 365268          INFGRP  Borrowing from an informal Group  63134753070600000
# 150254          INFGRP  Borrowing from an informal Group  63134753070600000
# 16290           INFGRP  Borrowing from an informal Group  63134753070600000
#
#             new_account_ids  trx_stdtime_days_acc  \
# 1497    63134753070600000.1                     0
# 326473  63134753070600000.1                    51
# 302519  63134753070600000.1                    72
# 137277  63134753070600000.1                   114
# 150450  63134753070600000.1                   142
# 335081  63134753070600000.1                   170
# 146579  63134753070600000.1                   198
# 384009  63134753070600000.1                   233
# 91055   63134753070600000.1                   261
# 239635  63134753070600000.1                   289
# 365268  63134753070600000.1                   324
# 150254  63134753070600000.1                   352
# 16290   63134753070600000.1                   357
#
#                            trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 1497           1. Starting balance (today)        15000.0   15000.0    15000.0
# 326473                         3. Payments          900.0   14100.0    15000.0
# 302519                         3. Payments          900.0   13200.0    15000.0
# 137277                         3. Payments          900.0   12300.0    15000.0
# 150450                         3. Payments          800.0   11500.0    15000.0
# 335081                         3. Payments          800.0   10700.0    15000.0
# 146579                         3. Payments          800.0    9900.0    15000.0
# 384009                         3. Payments          800.0    9100.0    15000.0
# 91055                          3. Payments          800.0    8300.0    15000.0
# 239635                         3. Payments          800.0    7500.0    15000.0
# 365268                         3. Payments          800.0    6700.0    15000.0
# 150254                         3. Payments          800.0    5900.0    15000.0
# 16290   7. Closing Balance--End of last DQ         5900.0    5900.0    15000.0
# 59134942469700000.1
#        trx_family_code                            trx_type_desc  \
# 23025            FRMLN  Individual Business or Agriculture Loan
# 277437           FRMLN  Individual Business or Agriculture Loan
# 149656           FRMLN  Individual Business or Agriculture Loan
#
#               account_ids      new_account_ids  trx_stdtime_days_acc  \
# 23025   59134942469700000  59134942469700000.1                     0
# 277437  59134942469700000  59134942469700000.1                     9
# 149656  59134942469700000  59134942469700000.1                    40
#
#                     trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 23025   1. Starting balance (today)       108000.0  108000.0   108000.0
# 277437                  3. Payments        12000.0   96000.0   108000.0
# 149656                  3. Payments        12000.0   84000.0   108000.0
#        trx_family_code                            trx_type_desc  \
# 23025            FRMLN  Individual Business or Agriculture Loan
# 277437           FRMLN  Individual Business or Agriculture Loan
# 149656           FRMLN  Individual Business or Agriculture Loan
# 19200            FRMLN  Individual Business or Agriculture Loan
# 427271           FRMLN  Individual Business or Agriculture Loan
# 260728           FRMLN  Individual Business or Agriculture Loan
# 288513           FRMLN  Individual Business or Agriculture Loan
# 288508           FRMLN  Individual Business or Agriculture Loan
# 248010           FRMLN  Individual Business or Agriculture Loan
# 208412           FRMLN  Individual Business or Agriculture Loan
# 105122           FRMLN  Individual Business or Agriculture Loan
# 426300           FRMLN  Individual Business or Agriculture Loan
# 242426           FRMLN  Individual Business or Agriculture Loan
# 426114           FRMLN  Individual Business or Agriculture Loan
# 314426           FRMLN  Individual Business or Agriculture Loan
# 21202            FRMLN  Individual Business or Agriculture Loan
#
#               account_ids      new_account_ids  trx_stdtime_days_acc  \
# 23025   59134942469700000  59134942469700000.1                     0
# 277437  59134942469700000  59134942469700000.1                     9
# 149656  59134942469700000  59134942469700000.1                    40
# 19200   59134942469700000  59134942469700000.2                    67
# 427271  59134942469700000  59134942469700000.2                    67
# 260728  59134942469700000  59134942469700000.2                    72
# 288513  59134942469700000  59134942469700000.2                   100
# 288508  59134942469700000  59134942469700000.2                   135
# 248010  59134942469700000  59134942469700000.2                   163
# 208412  59134942469700000  59134942469700000.2                   191
# 105122  59134942469700000  59134942469700000.2                   219
# 426300  59134942469700000  59134942469700000.2                   254
# 242426  59134942469700000  59134942469700000.2                   282
# 426114  59134942469700000  59134942469700000.2                   313
# 314426  59134942469700000  59134942469700000.2                   345
# 21202   59134942469700000  59134942469700000.2                   346
#
#                            trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 23025          1. Starting balance (today)       108000.0  108000.0   108000.0
# 277437                         3. Payments        12000.0   96000.0   108000.0
# 149656                         3. Payments        12000.0   84000.0   108000.0
# 19200                 5. Interest accruing         2000.0   96000.0    94000.0
# 427271                    2. New borrowing        10000.0   94000.0    94000.0
# 260728                         3. Payments        12350.0   83650.0    94000.0
# 288513                         3. Payments        12350.0   71300.0    94000.0
# 288508                         3. Payments        13000.0   58300.0    94000.0
# 248010                         3. Payments        12000.0   46300.0    94000.0
# 208412                         3. Payments        12000.0   34300.0    94000.0
# 105122                         3. Payments        12000.0   22300.0    94000.0
# 426300                         3. Payments        12000.0   10300.0    94000.0
# 242426                         3. Payments         1700.0    8600.0    94000.0
# 426114                         3. Payments         1700.0    6900.0    94000.0
# 314426                         3. Payments         2250.0    4650.0    94000.0
# 21202   6. Closing Balance--End of last DQ         4650.0    4650.0    94000.0
# /anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py:1001: UserWarning: Attempting to set identical left == right == 110.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(left, right)
# 105136612141800000.6
#        trx_family_code                     trx_type_desc         account_ids  \
# 24780           INFGRP  Borrowing from an informal Group  105136612141800000
# 229979          INFGRP  Borrowing from an informal Group  105136612141800000
# 301360          INFGRP  Borrowing from an informal Group  105136612141800000
# 382412          INFGRP  Borrowing from an informal Group  105136612141800000
#
#              new_account_ids  trx_stdtime_days_acc       trx_prx_purpose  \
# 24780   105136612141800000.6                   110  5. Interest accruing
# 229979  105136612141800000.6                   110           3. Payments
# 301360  105136612141800000.6                   110           3. Payments
# 382412  105136612141800000.6                   110      2. New borrowing
#
#         trx_value_kes  bal_evol  start_bal
# 24780           900.0    6900.0     9000.0
# 229979         6900.0       0.0     9000.0
# 301360         3000.0    6000.0     9000.0
# 382412         9000.0    9000.0     9000.0
#        trx_family_code                     trx_type_desc         account_ids  \
# 215247          INFGRP  Borrowing from an informal Group  105136612141800000
# 104863          INFGRP  Borrowing from an informal Group  105136612141800000
# 214054          INFGRP  Borrowing from an informal Group  105136612141800000
# 213713          INFGRP  Borrowing from an informal Group  105136612141800000
# 125090          INFGRP  Borrowing from an informal Group  105136612141800000
# 200859          INFGRP  Borrowing from an informal Group  105136612141800000
# 80496           INFGRP  Borrowing from an informal Group  105136612141800000
# 102729          INFGRP  Borrowing from an informal Group  105136612141800000
# 342224          INFGRP  Borrowing from an informal Group  105136612141800000
# 89511           INFGRP  Borrowing from an informal Group  105136612141800000
# 315892          INFGRP  Borrowing from an informal Group  105136612141800000
# 202463          INFGRP  Borrowing from an informal Group  105136612141800000
# 246366          INFGRP  Borrowing from an informal Group  105136612141800000
# 242472          INFGRP  Borrowing from an informal Group  105136612141800000
# 301360          INFGRP  Borrowing from an informal Group  105136612141800000
# 382412          INFGRP  Borrowing from an informal Group  105136612141800000
# 24780           INFGRP  Borrowing from an informal Group  105136612141800000
# 229979          INFGRP  Borrowing from an informal Group  105136612141800000
# 365270          INFGRP  Borrowing from an informal Group  105136612141800000
# 169460          INFGRP  Borrowing from an informal Group  105136612141800000
# 1578            INFGRP  Borrowing from an informal Group  105136612141800000
#
#              new_account_ids  trx_stdtime_days_acc  \
# 215247  105136612141800000.1                     0
# 104863  105136612141800000.1                    10
# 214054  105136612141800000.1                    10
# 213713  105136612141800000.2                    17
# 125090  105136612141800000.2                    17
# 200859  105136612141800000.2                    17
# 80496   105136612141800000.3                    32
# 102729  105136612141800000.3                    32
# 342224  105136612141800000.4                    75
# 89511   105136612141800000.4                    75
# 315892  105136612141800000.4                    75
# 202463  105136612141800000.5                    90
# 246366  105136612141800000.5                    90
# 242472  105136612141800000.5                    90
# 301360  105136612141800000.6                   110
# 382412  105136612141800000.6                   110
# 24780   105136612141800000.6                   110
# 229979  105136612141800000.6                   110
# 365270  105136612141800000.7                   159
# 169460  105136612141800000.7                   159
# 1578    105136612141800000.7                   179
#
#                            trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 215247                    2. New borrowing         6000.0    6000.0     6000.0
# 104863                5. Interest accruing          600.0    6600.0     6000.0
# 214054                         3. Payments         6600.0       0.0     6000.0
# 213713                         3. Payments          200.0     400.0      600.0
# 125090                         3. Payments          400.0       0.0      600.0
# 200859                    2. New borrowing          600.0     600.0      600.0
# 80496                          3. Payments         1700.0       0.0     1700.0
# 102729                    2. New borrowing         1700.0    1700.0     1700.0
# 342224                         3. Payments          300.0    1700.0     2000.0
# 89511                          3. Payments         1700.0       0.0     2000.0
# 315892                    2. New borrowing         2000.0    2000.0     2000.0
# 202463                         3. Payments          300.0    1700.0     2000.0
# 246366                         3. Payments         1700.0       0.0     2000.0
# 242472                    2. New borrowing         2000.0    2000.0     2000.0
# 301360                         3. Payments         3000.0    6000.0     9000.0
# 382412                    2. New borrowing         9000.0    9000.0     9000.0
# 24780                 5. Interest accruing          900.0    6900.0     9000.0
# 229979                         3. Payments         6900.0       0.0     9000.0
# 365270                         3. Payments         3000.0     400.0     3400.0
# 169460                    2. New borrowing         3400.0    3400.0     3400.0
# 1578    7. Closing Balance--End of last DQ          400.0     400.0     3400.0
# /anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py:1001: UserWarning: Attempting to set identical left == right == 8.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(left, right)
# 63134734929000000.2
#        trx_family_code                     trx_type_desc        account_ids  \
# 7542            INFGRP  Borrowing from an informal Group  63134734929000000
# 26750           INFGRP  Borrowing from an informal Group  63134734929000000
# 302619          INFGRP  Borrowing from an informal Group  63134734929000000
# 360622          INFGRP  Borrowing from an informal Group  63134734929000000
#
#             new_account_ids  trx_stdtime_days_acc       trx_prx_purpose  \
# 7542    63134734929000000.2                     8  5. Interest accruing
# 26750   63134734929000000.2                     8           3. Payments
# 302619  63134734929000000.2                     8      2. New borrowing
# 360622  63134734929000000.2                     8           3. Payments
#
#         trx_value_kes  bal_evol  start_bal
# 7542            600.0    4600.0     4000.0
# 26750           600.0    4000.0     4000.0
# 302619         3500.0    4000.0     4000.0
# 360622          500.0    3500.0     4000.0
#        trx_family_code                     trx_type_desc        account_ids  \
# 9619            INFGRP  Borrowing from an informal Group  63134734929000000
# 7542            INFGRP  Borrowing from an informal Group  63134734929000000
# 26750           INFGRP  Borrowing from an informal Group  63134734929000000
# 302619          INFGRP  Borrowing from an informal Group  63134734929000000
# 360622          INFGRP  Borrowing from an informal Group  63134734929000000
# 149184          INFGRP  Borrowing from an informal Group  63134734929000000
# 204976          INFGRP  Borrowing from an informal Group  63134734929000000
# 23742           INFGRP  Borrowing from an informal Group  63134734929000000
# 39496           INFGRP  Borrowing from an informal Group  63134734929000000
# 229471          INFGRP  Borrowing from an informal Group  63134734929000000
# 344700          INFGRP  Borrowing from an informal Group  63134734929000000
# 283388          INFGRP  Borrowing from an informal Group  63134734929000000
# 5890            INFGRP  Borrowing from an informal Group  63134734929000000
#
#             new_account_ids  trx_stdtime_days_acc  \
# 9619    63134734929000000.1                     0
# 7542    63134734929000000.2                     8
# 26750   63134734929000000.2                     8
# 302619  63134734929000000.2                     8
# 360622  63134734929000000.2                     8
# 149184  63134734929000000.3                    76
# 204976  63134734929000000.3                    76
# 23742   63134734929000000.4                   139
# 39496   63134734929000000.4                   139
# 229471  63134734929000000.4                   139
# 344700  63134734929000000.4                   139
# 283388  63134734929000000.4                   159
# 5890    63134734929000000.4                   365
#
#                            trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 9619           1. Starting balance (today)          500.0     500.0      500.0
# 7542                  5. Interest accruing          600.0    4600.0     4000.0
# 26750                          3. Payments          600.0    4000.0     4000.0
# 302619                    2. New borrowing         3500.0    4000.0     4000.0
# 360622                         3. Payments          500.0    3500.0     4000.0
# 149184                    2. New borrowing         3500.0    7000.0     7000.0
# 204976                         3. Payments         3500.0    3500.0     7000.0
# 23742                 5. Interest accruing          600.0    7700.0     7100.0
# 39496                          3. Payments         3500.0    4200.0     7100.0
# 229471                         3. Payments          600.0    3600.0     7100.0
# 344700                    2. New borrowing         3600.0    7100.0     7100.0
# 283388                         3. Payments         3600.0       0.0     7100.0
# 5890    7. Closing Balance--End of last DQ            0.0       0.0     7100.0
# 61134728400700000.1
#        trx_family_code         trx_type_desc        account_ids  \
# 11086            FRMLN  Joint liability loan  61134728400700000
# 112931           FRMLN  Joint liability loan  61134728400700000
# 142243           FRMLN  Joint liability loan  61134728400700000
# 285007           FRMLN  Joint liability loan  61134728400700000
# 78232            FRMLN  Joint liability loan  61134728400700000
# 352436           FRMLN  Joint liability loan  61134728400700000
# 321935           FRMLN  Joint liability loan  61134728400700000
# 163814           FRMLN  Joint liability loan  61134728400700000
# 100373           FRMLN  Joint liability loan  61134728400700000
# 134322           FRMLN  Joint liability loan  61134728400700000
# 301761           FRMLN  Joint liability loan  61134728400700000
# 35728            FRMLN  Joint liability loan  61134728400700000
# 184401           FRMLN  Joint liability loan  61134728400700000
# 245038           FRMLN  Joint liability loan  61134728400700000
# 285018           FRMLN  Joint liability loan  61134728400700000
# 117802           FRMLN  Joint liability loan  61134728400700000
# 126423           FRMLN  Joint liability loan  61134728400700000
# 285022           FRMLN  Joint liability loan  61134728400700000
# 175127           FRMLN  Joint liability loan  61134728400700000
# 223037           FRMLN  Joint liability loan  61134728400700000
# 29624            FRMLN  Joint liability loan  61134728400700000
# 350705           FRMLN  Joint liability loan  61134728400700000
# 311236           FRMLN  Joint liability loan  61134728400700000
# 389656           FRMLN  Joint liability loan  61134728400700000
# 109049           FRMLN  Joint liability loan  61134728400700000
# 221291           FRMLN  Joint liability loan  61134728400700000
# 285031           FRMLN  Joint liability loan  61134728400700000
# 264966           FRMLN  Joint liability loan  61134728400700000
# 356289           FRMLN  Joint liability loan  61134728400700000
# 392746           FRMLN  Joint liability loan  61134728400700000
# 285035           FRMLN  Joint liability loan  61134728400700000
# 80164            FRMLN  Joint liability loan  61134728400700000
# 387963           FRMLN  Joint liability loan  61134728400700000
#
#             new_account_ids  trx_stdtime_days_acc  \
# 11086   61134728400700000.1                     0
# 112931  61134728400700000.1                     5
# 142243  61134728400700000.1                    19
# 285007  61134728400700000.1                    40
# 78232   61134728400700000.1                    47
# 352436  61134728400700000.1                    61
# 321935  61134728400700000.1                    68
# 163814  61134728400700000.1                    75
# 100373  61134728400700000.1                   103
# 134322  61134728400700000.1                   110
# 301761  61134728400700000.1                   117
# 35728   61134728400700000.1                   124
# 184401  61134728400700000.1                   131
# 245038  61134728400700000.1                   138
# 285018  61134728400700000.1                   145
# 117802  61134728400700000.1                   152
# 126423  61134728400700000.1                   159
# 285022  61134728400700000.1                   166
# 175127  61134728400700000.1                   173
# 223037  61134728400700000.1                   180
# 29624   61134728400700000.1                   187
# 350705  61134728400700000.1                   194
# 311236  61134728400700000.1                   201
# 389656  61134728400700000.1                   208
# 109049  61134728400700000.1                   299
# 221291  61134728400700000.1                   306
# 285031  61134728400700000.1                   313
# 264966  61134728400700000.1                   320
# 356289  61134728400700000.1                   327
# 392746  61134728400700000.1                   334
# 285035  61134728400700000.1                   341
# 80164   61134728400700000.1                   348
# 387963  61134728400700000.1                   355
#
#                     trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 11086   1. Starting balance (today)        22165.0   22165.0    22165.0
# 112931                  3. Payments          500.0   21665.0    22165.0
# 142243                  3. Payments          500.0   21165.0    22165.0
# 285007                  3. Payments          500.0   20665.0    22165.0
# 78232                   3. Payments          500.0   20165.0    22165.0
# 352436                  3. Payments          500.0   19665.0    22165.0
# 321935                  3. Payments          500.0   19165.0    22165.0
# 163814                  3. Payments          550.0   18615.0    22165.0
# 100373                  3. Payments          500.0   18115.0    22165.0
# 134322                  3. Payments          550.0   17565.0    22165.0
# 301761                  3. Payments          500.0   17065.0    22165.0
# 35728                   3. Payments          500.0   16565.0    22165.0
# 184401                  3. Payments          608.0   15957.0    22165.0
# 245038                  3. Payments          700.0   15257.0    22165.0
# 285018                  3. Payments          800.0   14457.0    22165.0
# 117802                  3. Payments          500.0   13957.0    22165.0
# 126423                  3. Payments         1050.0   12907.0    22165.0
# 285022                  3. Payments          500.0   12407.0    22165.0
# 175127                  3. Payments          700.0   11707.0    22165.0
# 223037                  3. Payments          600.0   11107.0    22165.0
# 29624                   3. Payments          750.0   10357.0    22165.0
# 350705                  3. Payments          500.0    9857.0    22165.0
# 311236                  3. Payments          700.0    9157.0    22165.0
# 389656                  3. Payments          600.0    8557.0    22165.0
# 109049                  3. Payments          500.0    8057.0    22165.0
# 221291                  3. Payments          500.0    7557.0    22165.0
# 285031                  3. Payments         1000.0    6557.0    22165.0
# 264966                  3. Payments          700.0    5857.0    22165.0
# 356289                  3. Payments          650.0    5207.0    22165.0
# 392746                  3. Payments         1000.0    4207.0    22165.0
# 285035                  3. Payments         1000.0    3207.0    22165.0
# 80164                   3. Payments          900.0    2307.0    22165.0
# 387963                  3. Payments          700.0    1607.0    22165.0
#        trx_family_code         trx_type_desc        account_ids  \
# 11086            FRMLN  Joint liability loan  61134728400700000
# 112931           FRMLN  Joint liability loan  61134728400700000
# 142243           FRMLN  Joint liability loan  61134728400700000
# 285007           FRMLN  Joint liability loan  61134728400700000
# 78232            FRMLN  Joint liability loan  61134728400700000
# 352436           FRMLN  Joint liability loan  61134728400700000
# 321935           FRMLN  Joint liability loan  61134728400700000
# 163814           FRMLN  Joint liability loan  61134728400700000
# 100373           FRMLN  Joint liability loan  61134728400700000
# 134322           FRMLN  Joint liability loan  61134728400700000
# 301761           FRMLN  Joint liability loan  61134728400700000
# 35728            FRMLN  Joint liability loan  61134728400700000
# 184401           FRMLN  Joint liability loan  61134728400700000
# 245038           FRMLN  Joint liability loan  61134728400700000
# 285018           FRMLN  Joint liability loan  61134728400700000
# 117802           FRMLN  Joint liability loan  61134728400700000
# 126423           FRMLN  Joint liability loan  61134728400700000
# 285022           FRMLN  Joint liability loan  61134728400700000
# 175127           FRMLN  Joint liability loan  61134728400700000
# 223037           FRMLN  Joint liability loan  61134728400700000
# 29624            FRMLN  Joint liability loan  61134728400700000
# 350705           FRMLN  Joint liability loan  61134728400700000
# 311236           FRMLN  Joint liability loan  61134728400700000
# 389656           FRMLN  Joint liability loan  61134728400700000
# 109049           FRMLN  Joint liability loan  61134728400700000
# 221291           FRMLN  Joint liability loan  61134728400700000
# 285031           FRMLN  Joint liability loan  61134728400700000
# 264966           FRMLN  Joint liability loan  61134728400700000
# 356289           FRMLN  Joint liability loan  61134728400700000
# 392746           FRMLN  Joint liability loan  61134728400700000
# 285035           FRMLN  Joint liability loan  61134728400700000
# 80164            FRMLN  Joint liability loan  61134728400700000
# 387963           FRMLN  Joint liability loan  61134728400700000
#
#             new_account_ids  trx_stdtime_days_acc  \
# 11086   61134728400700000.1                     0
# 112931  61134728400700000.1                     5
# 142243  61134728400700000.1                    19
# 285007  61134728400700000.1                    40
# 78232   61134728400700000.1                    47
# 352436  61134728400700000.1                    61
# 321935  61134728400700000.1                    68
# 163814  61134728400700000.1                    75
# 100373  61134728400700000.1                   103
# 134322  61134728400700000.1                   110
# 301761  61134728400700000.1                   117
# 35728   61134728400700000.1                   124
# 184401  61134728400700000.1                   131
# 245038  61134728400700000.1                   138
# 285018  61134728400700000.1                   145
# 117802  61134728400700000.1                   152
# 126423  61134728400700000.1                   159
# 285022  61134728400700000.1                   166
# 175127  61134728400700000.1                   173
# 223037  61134728400700000.1                   180
# 29624   61134728400700000.1                   187
# 350705  61134728400700000.1                   194
# 311236  61134728400700000.1                   201
# 389656  61134728400700000.1                   208
# 109049  61134728400700000.1                   299
# 221291  61134728400700000.1                   306
# 285031  61134728400700000.1                   313
# 264966  61134728400700000.1                   320
# 356289  61134728400700000.1                   327
# 392746  61134728400700000.1                   334
# 285035  61134728400700000.1                   341
# 80164   61134728400700000.1                   348
# 387963  61134728400700000.1                   355
#
#                     trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 11086   1. Starting balance (today)        22165.0   22165.0    22165.0
# 112931                  3. Payments          500.0   21665.0    22165.0
# 142243                  3. Payments          500.0   21165.0    22165.0
# 285007                  3. Payments          500.0   20665.0    22165.0
# 78232                   3. Payments          500.0   20165.0    22165.0
# 352436                  3. Payments          500.0   19665.0    22165.0
# 321935                  3. Payments          500.0   19165.0    22165.0
# 163814                  3. Payments          550.0   18615.0    22165.0
# 100373                  3. Payments          500.0   18115.0    22165.0
# 134322                  3. Payments          550.0   17565.0    22165.0
# 301761                  3. Payments          500.0   17065.0    22165.0
# 35728                   3. Payments          500.0   16565.0    22165.0
# 184401                  3. Payments          608.0   15957.0    22165.0
# 245038                  3. Payments          700.0   15257.0    22165.0
# 285018                  3. Payments          800.0   14457.0    22165.0
# 117802                  3. Payments          500.0   13957.0    22165.0
# 126423                  3. Payments         1050.0   12907.0    22165.0
# 285022                  3. Payments          500.0   12407.0    22165.0
# 175127                  3. Payments          700.0   11707.0    22165.0
# 223037                  3. Payments          600.0   11107.0    22165.0
# 29624                   3. Payments          750.0   10357.0    22165.0
# 350705                  3. Payments          500.0    9857.0    22165.0
# 311236                  3. Payments          700.0    9157.0    22165.0
# 389656                  3. Payments          600.0    8557.0    22165.0
# 109049                  3. Payments          500.0    8057.0    22165.0
# 221291                  3. Payments          500.0    7557.0    22165.0
# 285031                  3. Payments         1000.0    6557.0    22165.0
# 264966                  3. Payments          700.0    5857.0    22165.0
# 356289                  3. Payments          650.0    5207.0    22165.0
# 392746                  3. Payments         1000.0    4207.0    22165.0
# 285035                  3. Payments         1000.0    3207.0    22165.0
# 80164                   3. Payments          900.0    2307.0    22165.0
# 387963                  3. Payments          700.0    1607.0    22165.0
# 57134622151200000.1
#        trx_family_code                     trx_type_desc        account_ids  \
# 265254          INFGRP  Borrowing from an informal Group  57134622151200000
# 283328          INFGRP  Borrowing from an informal Group  57134622151200000
# 416581          INFGRP  Borrowing from an informal Group  57134622151200000
#
#             new_account_ids  trx_stdtime_days_acc   trx_prx_purpose  \
# 265254  57134622151200000.1                     0       3. Payments
# 283328  57134622151200000.1                     0  2. New borrowing
# 416581  57134622151200000.1                     7       3. Payments
#
#         trx_value_kes  bal_evol  start_bal
# 265254          500.0    4500.0     5000.0
# 283328         5000.0    5000.0     5000.0
# 416581         3000.0    1500.0     5000.0
#        trx_family_code                     trx_type_desc        account_ids  \
# 265254          INFGRP  Borrowing from an informal Group  57134622151200000
# 283328          INFGRP  Borrowing from an informal Group  57134622151200000
# 416581          INFGRP  Borrowing from an informal Group  57134622151200000
# 124346          INFGRP  Borrowing from an informal Group  57134622151200000
# 129110          INFGRP  Borrowing from an informal Group  57134622151200000
# 400201          INFGRP  Borrowing from an informal Group  57134622151200000
# 223802          INFGRP  Borrowing from an informal Group  57134622151200000
# 3381            INFGRP  Borrowing from an informal Group  57134622151200000
#
#             new_account_ids  trx_stdtime_days_acc  \
# 265254  57134622151200000.1                     0
# 283328  57134622151200000.1                     0
# 416581  57134622151200000.1                     7
# 124346  57134622151200000.2                    44
# 129110  57134622151200000.2                    77
# 400201  57134622151200000.3                   194
# 223802  57134622151200000.3                   339
# 3381    57134622151200000.3                   366
#
#                            trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 265254                         3. Payments          500.0    4500.0     5000.0
# 283328                    2. New borrowing         5000.0    5000.0     5000.0
# 416581                         3. Payments         3000.0    1500.0     5000.0
# 124346                    2. New borrowing         2000.0    3500.0     3500.0
# 129110                         3. Payments         3500.0       0.0     3500.0
# 400201                    2. New borrowing        75000.0   75000.0    75000.0
# 223802                         3. Payments         5000.0   70000.0    75000.0
# 3381    7. Closing Balance--End of last DQ        70000.0   70000.0    75000.0
# 63137182523900000.1
#        trx_family_code                     trx_type_desc        account_ids  \
# 211             INFGRP  Borrowing from an informal Group  63137182523900000
# 286074          INFGRP  Borrowing from an informal Group  63137182523900000
# 372657          INFGRP  Borrowing from an informal Group  63137182523900000
# 23695           INFGRP  Borrowing from an informal Group  63137182523900000
#
#             new_account_ids  trx_stdtime_days_acc  \
# 211     63137182523900000.1                     0
# 286074  63137182523900000.1                     0
# 372657  63137182523900000.1                     0
# 23695   63137182523900000.1                   113
#
#                            trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 211                   5. Interest accruing          200.0    1200.0     1000.0
# 286074                    2. New borrowing         1000.0    1000.0     1000.0
# 372657                         3. Payments          200.0    1000.0     1000.0
# 23695   7. Closing Balance--End of last DQ         1000.0    1000.0     1000.0
#        trx_family_code                     trx_type_desc        account_ids  \
# 211             INFGRP  Borrowing from an informal Group  63137182523900000
# 286074          INFGRP  Borrowing from an informal Group  63137182523900000
# 372657          INFGRP  Borrowing from an informal Group  63137182523900000
# 23695           INFGRP  Borrowing from an informal Group  63137182523900000
#
#             new_account_ids  trx_stdtime_days_acc  \
# 211     63137182523900000.1                     0
# 286074  63137182523900000.1                     0
# 372657  63137182523900000.1                     0
# 23695   63137182523900000.1                   113
#
#                            trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 211                   5. Interest accruing          200.0    1200.0     1000.0
# 286074                    2. New borrowing         1000.0    1000.0     1000.0
# 372657                         3. Payments          200.0    1000.0     1000.0
# 23695   7. Closing Balance--End of last DQ         1000.0    1000.0     1000.0
# 105137101304000000.2
#        trx_family_code                     trx_type_desc         account_ids  \
# 322738          INFGRP  Borrowing from an informal Group  105137101304000000
# 384189          INFGRP  Borrowing from an informal Group  105137101304000000
#
#              new_account_ids  trx_stdtime_days_acc   trx_prx_purpose  \
# 322738  105137101304000000.2                    49  2. New borrowing
# 384189  105137101304000000.2                    63       3. Payments
#
#         trx_value_kes  bal_evol  start_bal
# 322738         1500.0    1500.0     1500.0
# 384189         1500.0       0.0     1500.0
#        trx_family_code                     trx_type_desc         account_ids  \
# 201726          INFGRP  Borrowing from an informal Group  105137101304000000
# 203404          INFGRP  Borrowing from an informal Group  105137101304000000
# 322738          INFGRP  Borrowing from an informal Group  105137101304000000
# 384189          INFGRP  Borrowing from an informal Group  105137101304000000
# 311367          INFGRP  Borrowing from an informal Group  105137101304000000
# 386346          INFGRP  Borrowing from an informal Group  105137101304000000
# 1780            INFGRP  Borrowing from an informal Group  105137101304000000
#
#              new_account_ids  trx_stdtime_days_acc  \
# 201726  105137101304000000.1                     0
# 203404  105137101304000000.1                    21
# 322738  105137101304000000.2                    49
# 384189  105137101304000000.2                    63
# 311367  105137101304000000.3                    70
# 386346  105137101304000000.3                    84
# 1780    105137101304000000.3                   124
#
#                            trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 201726                    2. New borrowing         1500.0    1500.0     1500.0
# 203404                         3. Payments         1500.0       0.0     1500.0
# 322738                    2. New borrowing         1500.0    1500.0     1500.0
# 384189                         3. Payments         1500.0       0.0     1500.0
# 311367                    2. New borrowing          500.0     500.0      500.0
# 386346                         3. Payments          500.0       0.0      500.0
# 1780    7. Closing Balance--End of last DQ            0.0       0.0      500.0
# /anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py:1001: UserWarning: Attempting to set identical left == right == 190.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(left, right)
# 58134816929000000.1
#       trx_family_code                     trx_type_desc        account_ids  \
# 20271          INFGRP  Borrowing from an informal Group  58134816929000000
#
#            new_account_ids  trx_stdtime_days_acc              trx_prx_purpose  \
# 20271  58134816929000000.1                   190  1. Starting balance (today)
#
#        trx_value_kes  bal_evol  start_bal
# 20271         2500.0   -3000.0    -3000.0
#        trx_family_code                     trx_type_desc        account_ids  \
# 205413          INFGRP  Borrowing from an informal Group  58134816929000000
# 66197           INFGRP  Borrowing from an informal Group  58134816929000000
# 226855          INFGRP  Borrowing from an informal Group  58134816929000000
# 204892          INFGRP  Borrowing from an informal Group  58134816929000000
# 154849          INFGRP  Borrowing from an informal Group  58134816929000000
# 20271           INFGRP  Borrowing from an informal Group  58134816929000000
# 22294           INFGRP  Borrowing from an informal Group  58134816929000000
# 248860          INFGRP  Borrowing from an informal Group  58134816929000000
# 248864          INFGRP  Borrowing from an informal Group  58134816929000000
# 10917           INFGRP  Borrowing from an informal Group  58134816929000000
# 93256           INFGRP  Borrowing from an informal Group  58134816929000000
# 187493          INFGRP  Borrowing from an informal Group  58134816929000000
# 2808            INFGRP  Borrowing from an informal Group  58134816929000000
#
#             new_account_ids  trx_stdtime_days_acc  \
# 205413  58134816929000000.0                     0
# 66197   58134816929000000.0                    33
# 226855  58134816929000000.0                    61
# 204892  58134816929000000.0                    91
# 154849  58134816929000000.0                   115
# 20271   58134816929000000.1                   190
# 22294   58134816929000000.2                   224
# 248860  58134816929000000.2                   224
# 248864  58134816929000000.2                   224
# 10917   58134816929000000.3                   252
# 93256   58134816929000000.3                   252
# 187493  58134816929000000.3                   252
# 2808    58134816929000000.3                   349
#
#                            trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 205413                         3. Payments         1100.0   -1100.0    -1100.0
# 66197                          3. Payments         1100.0   -2200.0    -1100.0
# 226855                         3. Payments         1100.0   -3300.0    -1100.0
# 204892                         3. Payments         1100.0   -4400.0    -1100.0
# 154849                         3. Payments         1100.0   -5500.0    -1100.0
# 20271          1. Starting balance (today)         2500.0   -3000.0    -3000.0
# 22294                 5. Interest accruing          250.0    -250.0     -500.0
# 248860                         3. Payments         2500.0   -2750.0     -500.0
# 248864                    2. New borrowing         2500.0    -500.0     -500.0
# 10917                 5. Interest accruing          300.0     550.0      250.0
# 93256                     2. New borrowing         3000.0     250.0      250.0
# 187493                         3. Payments         2750.0   -2200.0      250.0
# 2808    7. Closing Balance--End of last DQ         3300.0   -2200.0      250.0
# /anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py:1001: UserWarning: Attempting to set identical left == right == 75.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(left, right)
# 105136612141800000.4
#        trx_family_code                     trx_type_desc         account_ids  \
# 89511           INFGRP  Borrowing from an informal Group  105136612141800000
# 315892          INFGRP  Borrowing from an informal Group  105136612141800000
# 342224          INFGRP  Borrowing from an informal Group  105136612141800000
#
#              new_account_ids  trx_stdtime_days_acc   trx_prx_purpose  \
# 89511   105136612141800000.4                    75       3. Payments
# 315892  105136612141800000.4                    75  2. New borrowing
# 342224  105136612141800000.4                    75       3. Payments
#
#         trx_value_kes  bal_evol  start_bal
# 89511          1700.0       0.0     2000.0
# 315892         2000.0    2000.0     2000.0
# 342224          300.0    1700.0     2000.0
#        trx_family_code                     trx_type_desc         account_ids  \
# 215247          INFGRP  Borrowing from an informal Group  105136612141800000
# 104863          INFGRP  Borrowing from an informal Group  105136612141800000
# 214054          INFGRP  Borrowing from an informal Group  105136612141800000
# 213713          INFGRP  Borrowing from an informal Group  105136612141800000
# 125090          INFGRP  Borrowing from an informal Group  105136612141800000
# 200859          INFGRP  Borrowing from an informal Group  105136612141800000
# 80496           INFGRP  Borrowing from an informal Group  105136612141800000
# 102729          INFGRP  Borrowing from an informal Group  105136612141800000
# 342224          INFGRP  Borrowing from an informal Group  105136612141800000
# 89511           INFGRP  Borrowing from an informal Group  105136612141800000
# 315892          INFGRP  Borrowing from an informal Group  105136612141800000
# 202463          INFGRP  Borrowing from an informal Group  105136612141800000
# 246366          INFGRP  Borrowing from an informal Group  105136612141800000
# 242472          INFGRP  Borrowing from an informal Group  105136612141800000
# 301360          INFGRP  Borrowing from an informal Group  105136612141800000
# 382412          INFGRP  Borrowing from an informal Group  105136612141800000
# 24780           INFGRP  Borrowing from an informal Group  105136612141800000
# 229979          INFGRP  Borrowing from an informal Group  105136612141800000
# 365270          INFGRP  Borrowing from an informal Group  105136612141800000
# 169460          INFGRP  Borrowing from an informal Group  105136612141800000
# 1578            INFGRP  Borrowing from an informal Group  105136612141800000
#
#              new_account_ids  trx_stdtime_days_acc  \
# 215247  105136612141800000.1                     0
# 104863  105136612141800000.1                    10
# 214054  105136612141800000.1                    10
# 213713  105136612141800000.2                    17
# 125090  105136612141800000.2                    17
# 200859  105136612141800000.2                    17
# 80496   105136612141800000.3                    32
# 102729  105136612141800000.3                    32
# 342224  105136612141800000.4                    75
# 89511   105136612141800000.4                    75
# 315892  105136612141800000.4                    75
# 202463  105136612141800000.5                    90
# 246366  105136612141800000.5                    90
# 242472  105136612141800000.5                    90
# 301360  105136612141800000.6                   110
# 382412  105136612141800000.6                   110
# 24780   105136612141800000.6                   110
# 229979  105136612141800000.6                   110
# 365270  105136612141800000.7                   159
# 169460  105136612141800000.7                   159
# 1578    105136612141800000.7                   179
#
#                            trx_prx_purpose  trx_value_kes  bal_evol  start_bal
# 215247                    2. New borrowing         6000.0    6000.0     6000.0
# 104863                5. Interest accruing          600.0    6600.0     6000.0
# 214054                         3. Payments         6600.0       0.0     6000.0
# 213713                         3. Payments          200.0     400.0      600.0
# 125090                         3. Payments          400.0       0.0      600.0
# 200859                    2. New borrowing          600.0     600.0      600.0
# 80496                          3. Payments         1700.0       0.0     1700.0
# 102729                    2. New borrowing         1700.0    1700.0     1700.0
# 342224                         3. Payments          300.0    1700.0     2000.0
# 89511                          3. Payments         1700.0       0.0     2000.0
# 315892                    2. New borrowing         2000.0    2000.0     2000.0
# 202463                         3. Payments          300.0    1700.0     2000.0
# 246366                         3. Payments         1700.0       0.0     2000.0
# 242472                    2. New borrowing         2000.0    2000.0     2000.0
# 301360                         3. Payments         3000.0    6000.0     9000.0
# 382412                    2. New borrowing         9000.0    9000.0     9000.0
# 24780                 5. Interest accruing          900.0    6900.0     9000.0
# 229979                         3. Payments         6900.0       0.0     9000.0
# 365270                         3. Payments         3000.0     400.0     3400.0
# 169460                    2. New borrowing         3400.0    3400.0     3400.0
# 1578    7. Closing Balance--End of last DQ          400.0     400.0     3400.0

# %% [markdown]
# ## Seems ok, let's now save this dataset

# %%
dfb = dfb[dfb["start_bal"]>10]

# %%
dfb.to_csv("diaries_trx_trunc_loans_start_bal.csv")

# %% [markdown]
# ### Careful: the column "unique_accnts" is not accurate anymore.

# %%
df.sample(5)
# Out:
#          hh_ids  unique_hhs first_trx_date_hh last_trx_date_hh  \
# 87136   KELDS26         NaN         08sep2012        23oct2013
# 346438  KMAKE05         NaN         30sep2012        25sep2013
# 130520  KELDK28         NaN         04sep2012        01nov2013
# 379935  KMAKE06         NaN         02oct2012        30sep2013
# 404964  KMAKE07         NaN         17sep2012        02oct2013
#
#         tot_hh_daysofobs  tot_hh_monthsofobs  interview_designation  \
# 87136                410                  14   04=Diaries Interview
# 346438               360                  12   04=Diaries Interview
# 130520               423                  14  06=Cleaning interview
# 379935               363                  12   04=Diaries Interview
# 404964               380                  13   04=Diaries Interview
#
#          int_date  int_month  int_year int_yr_mo first_int_date  \
# 87136   15jan2013          1      2013   2013_01      04sep2012
# 346438  19mar2013          3      2013   2013_03      03sep2012
# 130520  04oct2013         10      2013   2013_10      29aug2012
# 379935  01aug2013          8      2013   2013_08      04sep2012
# 404964  28jan2013          1      2013   2013_01      28aug2012
#
#                account_ids       new_account_ids  unique_accnts  \
# 87136    58134795341800000   58134795341800000.0            1.0
# 346438   63136377011000000   63136377011000000.1            1.0
# 130520  105136954984100000  105136954984100000.1            NaN
# 379935   63136740549700000   63136740549700000.1            NaN
# 404964   63134734844700000   63134734844700000.1            NaN
#
#               m_ids_owner  unique_hm_owner account_bsheet_desig  \
# 87136   58134466180200000              NaN            Liability
# 346438  63134449728600000              NaN            Liability
# 130520  65134432603700000              NaN            Liability
# 379935  63134425702500000              NaN            Liability
# 404964  63134363237200000              NaN            Liability
#
#        account_startclose_balance account_formal account_liquid  \
# 87136                         NaN       Informal            NaN
# 346438                        NaN       Informal            NaN
# 130520                        NaN       Informal            NaN
# 379935                        NaN         Formal            NaN
# 404964                        NaN         Formal            NaN
#
#        first_trx_date_acc last_trx_date_acc  tot_acc_daysofobs  \
# 87136           06jan2013         23oct2013                290
# 346438          11mar2013         24sep2013                197
# 130520          11may2013         03oct2013                145
# 379935          22apr2013         24sep2013                155
# 404964          25sep2012         02oct2013                372
#
#         tot_acc_monthsofobs              trx_id          m_ids_trx   trx_date  \
# 87136                    10   58135939495900000  58134466180200000  06jan2013
# 346438                    6   63136377033100000  63134449728600000  11mar2013
# 130520                    5  105138441583700000  65134432603700000  11sep2013
# 379935                    5   63137543716300000  63134425702500000  22jul2013
# 404964                   12   63135935583500000  63134363237200000  14jan2013
#
#         trx_month  trx_year  ... trx_stdtime_days_hh  trx_stdtime_mnths_hh  \
# 87136           1      2013  ...                 120                     4
# 346438          3      2013  ...                 162                     5
# 130520          9      2013  ...                 372                    12
# 379935          7      2013  ...                 293                    10
# 404964          1      2013  ...                 119                     4
#
#         trx_stdtime_days_acc  trx_stdtime_mnths_acc  trx_class_code  \
# 87136                      0                      0          findev
# 346438                     0                      0          findev
# 130520                   123                      4          findev
# 379935                    91                      3          findev
# 404964                   111                      3          findev
#
#                                            trx_class_desc trx_family_code  \
# 87136   Borrowing, lending, savings or insurance media...          INFGRP
# 346438  Borrowing, lending, savings or insurance media...          INFGRP
# 130520  Borrowing, lending, savings or insurance media...          INFGRP
# 379935  Borrowing, lending, savings or insurance media...           FRMLN
# 404964  Borrowing, lending, savings or insurance media...           FRMLN
#
#        trx_family_desc trx_type_code  \
# 87136   Informal group          3395
# 346438  Informal group          3395
# 130520  Informal group          3395
# 379935     Formal loan          2762
# 404964     Formal loan          2762
#
#                                     trx_type_desc  trx_prx_purpose  \
# 87136            Borrowing from an informal Group      3. Payments
# 346438           Borrowing from an informal Group      3. Payments
# 130520           Borrowing from an informal Group      3. Payments
# 379935  Consumer/ personal loan (not payday loan)      3. Payments
# 404964  Consumer/ personal loan (not payday loan)      3. Payments
#
#                       trx_prx_purpose_fd trx_fee trx_bsheet_direction  \
# 87136   Repayment on financial liability     0.0             Decrease
# 346438  Repayment on financial liability     0.0             Decrease
# 130520  Repayment on financial liability     0.0             Decrease
# 379935  Repayment on financial liability     0.0             Decrease
# 404964  Repayment on financial liability     0.0             Decrease
#
#         trx_mode_code trx_mode_desc  trx_place_incommunity trx_distance_km  \
# 87136             1.0          Cash                    1.0             0.0
# 346438            1.0          Cash                    1.0             0.0
# 130520            1.0          Cash                    1.0             0.0
# 379935            1.0          Cash                    1.0             0.0
# 404964            1.0          Cash                    1.0             0.0
#
#                                           trx_outlet  trx_direction  \
# 87136                               07=Group meeting        Outflow
# 346438                              07=Group meeting        Outflow
# 130520                              07=Group meeting        Outflow
# 379935                              07=Group meeting        Outflow
# 404964  09=At home or work (self or collector/agent)        Outflow
#
#        trx_value_kes trx_value_usd  ddd_gift  trx_inkind_units  \
# 87136         1500.0     17.647060         0               NaN
# 346438         600.0      7.058824         0               NaN
# 130520        3000.0     35.294120         0               NaN
# 379935        2800.0     32.941180         0               NaN
# 404964        1525.0     17.941180         0               NaN
#
#         trx_inkind_value_usd trx_inkind_value_kes  trx_stdtime_mnths_hh_nr  \
# 87136                    NaN                  NaN                 4.137931
# 346438                   NaN                  NaN                 5.586207
# 130520                   NaN                  NaN                12.827590
# 379935                   NaN                  NaN                10.103450
# 404964                   NaN                  NaN                 4.103448
#
#         acc_unexplained_trx  bal_evol  start_bal
# 87136                   0.0   -1500.0     1500.0
# 346438                  0.0    3600.0     3600.0
# 130520                  0.0   12000.0    20000.0
# 379935                  0.0    5600.0    16800.0
# 404964                  0.0    1525.0     8600.0
#
# [5 rows x 62 columns]
