# %%
import pandas as pd
import numpy as np
import math as math
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df_house = pd.read_csv('../housing_conditions_ownership.csv')
df_house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 54 columns):
# hh_ids                           301 non-null object
# hh_int_situation                 295 non-null object
# hh_circ_move_why                 288 non-null object
# hh_circ_move_when                291 non-null object
# hh_circ_problems                 292 non-null object
# hh_inf_wall_material             293 non-null object
# hh_inf_roof_material             293 non-null object
# hh_inf_floor_material            294 non-null object
# hh_inf_cookfuel_source           298 non-null object
# hh_inf_lighting_source           294 non-null object
# hh_inf_water_source              297 non-null object
# hh_inf_rooms_habitable           296 non-null float64
# hh_inf_rooms_other               296 non-null float64
# hh_inf_toilet_type               296 non-null object
# hh_inf_toilet_shared             286 non-null object
# hh_inf_housing_type              292 non-null object
# ...

# %%
df_house.head()
# Out:
#     hh_ids          hh_int_situation  \
# 0  KNBOK31                       NaN
# 1  KNBOK01  01=Initial questionnaire
# 2  KNBOK02  01=Initial questionnaire
# 3  KNBOK04  01=Initial questionnaire
# 4  KNBOK05  01=Initial questionnaire
#
#                                     hh_circ_move_why hh_circ_move_when  \
# 0                                                NaN               NaN
# 1                          05=To be closer to family          7/1/1997
# 2                      12=Wanted better neighborhood          2/1/2011
# 3  17=Private displacement (owner moved into unit...         2/19/2006
# 4                     13=Change from renter to owner          1/1/1993
#
#                                     hh_circ_problems   hh_inf_wall_material  \
# 0                                                NaN                    NaN
# 1  01=Leaky roof or ceilling,04=Pests: mice, rats...                  Stone
# 2                          01=Leaky roof or ceilling                  Stone
# ...

# %%
df_house.columns
# Out:
# Index(['hh_ids', 'hh_int_situation', 'hh_circ_move_why', 'hh_circ_move_when',
#        'hh_circ_problems', 'hh_inf_wall_material', 'hh_inf_roof_material',
#        'hh_inf_floor_material', 'hh_inf_cookfuel_source',
#        'hh_inf_lighting_source', 'hh_inf_water_source',
#        'hh_inf_rooms_habitable', 'hh_inf_rooms_other', 'hh_inf_toilet_type',
#        'hh_inf_toilet_shared', 'hh_inf_housing_type',
#        'hh_inf_electricity_access', 'hh_inf_interiorcond',
#        'hh_inf_exteriorcond', 'hh_asset_internet_access', 'hh_asset_iron_any',
#        'hh_asset_mosqnets_N', 'hh_asset_towels_N', 'hh_asset_fryingpan_N',
#        'hh_env_settingdesc', 'hh_env_desc', 'hh_env_dilapbuildings',
#        'hh_env_streets', 'hh_env_trash', 'hh_ownership_type',
#        'hh_ownership_plotacquisition', 'hh_ownership_houseacquisition',
#        'hh_ownership_docu', 'hh_otherprop_any', 'hh_otherprop_N',
#        'hh_otherprop1_docu', 'hh_otherprop1_use', 'hh_otherprop1_value',
# ...

# %%
df_house.sample(3)
# Out:
#       hh_ids          hh_int_situation  \
# 290  KVIHK33  01=Initial questionnaire
# 238  KVIHC06  01=Initial questionnaire
# 153  KMAKL40  01=Initial questionnaire
#
#                              hh_circ_move_why hh_circ_move_when  \
# 290       15=Needed larger house or apartment         7/28/1997
# 238  08=Seeking better business opportunities          7/1/2011
# 153                  03=Started own household          8/1/2004
#
#                                       hh_circ_problems hh_inf_wall_material  \
# 290                                            09=None          Brick/block
# 238  04=Pests: mice, rats, roaches, bedbugs, other ...          Brick/block
# 153                                            09=None          Brick/block
#
#         hh_inf_roof_material hh_inf_floor_material hh_inf_cookfuel_source  \
# 290  Corrugated iron, mabati  Cement/Concrete/Slab     Collected firewood
# 238  Corrugated iron, mabati  Cement/Concrete/Slab               Charcoal
# ...

# %%
df_house.describe()
# Out:
#        hh_inf_rooms_habitable  hh_inf_rooms_other  hh_asset_mosqnets_N  \
# count              296.000000          296.000000           295.000000
# mean                 2.486486            1.425676             2.196610
# std                  1.345357            1.491632             1.888559
# min                  1.000000            0.000000             0.000000
# 25%                  1.000000            1.000000             1.000000
# 50%                  2.000000            1.000000             2.000000
# 75%                  3.000000            2.000000             3.000000
# max                  8.000000           21.000000            10.000000
#
#        hh_asset_towels_N  hh_asset_fryingpan_N  hh_ownership_type  \
# count         296.000000            294.000000         295.000000
# mean            1.510135              0.755102           2.149153
# std             1.667201              0.793247           1.479379
# ...

# %%
df_house.shape
# Out:
# (301, 54)

# %%
df_house['hh_inf_rooms_habitable'].mean()
# Out:
# 2.4864864864864864

# %%
df_house['hh_inf_rooms_other'].mean()
# Out:
# 1.4256756756756757
